# %%
import pandas as pd
import scanpy as sc
import numpy as np

# %%
datasets = ['HumanBoneMarrow', 'MouseBoneMarrow', 'MouseErythroid', 'Pancreas_with_cc', 'DentateGyrus']
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'

# %%
comparison = ['scVelo', 'scVelo_stochastic', 'VeloVI', 'cell2fate', 'VeloVAE', 'DeepVelo', 'UniTVelo_unified',
             'UniTVelo_independent', 'pyroVelocity_model1', 'pyroVelocity_model2', 'CellDancer']
tab_summary = pd.DataFrame(columns = datasets, index = comparison)

# %%
for dataset in datasets:
    print(dataset)
    tab = pd.read_csv(save_dir + dataset + '_CBDC_scores1.csv', index_col = 0)
    tab_summary.loc[:,dataset] = tab.loc[comparison, 'Mean']
tab_summary.loc[:, 'Mean Across All Data'] = np.mean(tab_summary, axis = 1)
# Out:
# HumanBoneMarrow
# MouseBoneMarrow
# MouseErythroid
# Pancreas_with_cc
# DentateGyrus

# %%
tab = pd.read_csv(save_dir + dataset + '_CBDC_scores1.csv', index_col = 0)

# %%
tab
# Out:
#                       ('nIPC', 'Neuroblast')  \
# cell2fate                           0.271872
# VeloVI                              0.890016
# scVelo                              0.899306
# VeloVAE                             0.900370
# UniTVelo_independent                0.900003
# UniTVelo_unified                   -0.897451
# scVelo_stochastic                   0.900370
# DeepVelo                            0.762181
# pyroVelocity_model1                 0.880160
# pyroVelocity_model2                 0.912278
# CellDancer                          0.885312
#
#                       ('Neuroblast', 'Granule immature')  \
# cell2fate                                       0.654140
# VeloVI                                          0.573103
# scVelo                                         -0.051741
# VeloVAE                                         0.587496
# UniTVelo_independent                            0.298959
# UniTVelo_unified                               -0.562276
# scVelo_stochastic                               0.587493
# DeepVelo                                        0.552295
# pyroVelocity_model1                             0.434894
# pyroVelocity_model2                            -0.157438
# CellDancer                                      0.061026
#
#                       ('Granule immature', 'Granule mature')  \
# cell2fate                                           0.600624
# VeloVI                                             -0.177543
# scVelo                                             -0.189949
# VeloVAE                                             0.021749
# UniTVelo_independent                               -0.036748
# UniTVelo_unified                                    0.183850
# scVelo_stochastic                                   0.021740
# DeepVelo                                            0.235566
# pyroVelocity_model1                                 0.112269
# pyroVelocity_model2                                 0.112992
# CellDancer                                         -0.060430
#
#                       ('Radial Glia-like', 'Astrocytes')  ('OPC', 'OL')  \
# cell2fate                                       0.530908       0.639907
# VeloVI                                          0.735627       0.416491
# scVelo                                          0.828443       0.157301
# VeloVAE                                         0.854610      -0.834056
# UniTVelo_independent                            0.845762       0.796332
# UniTVelo_unified                                0.820815       0.809826
# scVelo_stochastic                               0.854610      -0.834055
# DeepVelo                                       -0.836790      -0.554259
# pyroVelocity_model1                            -0.708074      -0.971520
# pyroVelocity_model2                            -0.746838       0.893880
# CellDancer                                      0.853115       0.155512
#
#                           Mean
# cell2fate             0.539490
# VeloVI                0.487539
# scVelo                0.328672
# VeloVAE               0.306034
# UniTVelo_independent  0.560862
# UniTVelo_unified      0.070953
# scVelo_stochastic     0.306031
# DeepVelo              0.031799
# pyroVelocity_model1  -0.050454
# pyroVelocity_model2   0.202975
# CellDancer            0.378907

# %%
tab.loc[comparison]
# Out:
#                       ('nIPC', 'Neuroblast')  \
# scVelo                              0.899306
# scVelo_stochastic                   0.900370
# VeloVI                              0.890016
# cell2fate                           0.271872
# VeloVAE                             0.900370
# DeepVelo                            0.762181
# UniTVelo_unified                   -0.897451
# UniTVelo_independent                0.900003
# pyroVelocity_model1                 0.880160
# pyroVelocity_model2                 0.912278
# CellDancer                          0.885312
#
#                       ('Neuroblast', 'Granule immature')  \
# scVelo                                         -0.051741
# scVelo_stochastic                               0.587493
# VeloVI                                          0.573103
# cell2fate                                       0.654140
# VeloVAE                                         0.587496
# DeepVelo                                        0.552295
# UniTVelo_unified                               -0.562276
# UniTVelo_independent                            0.298959
# pyroVelocity_model1                             0.434894
# pyroVelocity_model2                            -0.157438
# CellDancer                                      0.061026
#
#                       ('Granule immature', 'Granule mature')  \
# scVelo                                             -0.189949
# scVelo_stochastic                                   0.021740
# VeloVI                                             -0.177543
# cell2fate                                           0.600624
# VeloVAE                                             0.021749
# DeepVelo                                            0.235566
# UniTVelo_unified                                    0.183850
# UniTVelo_independent                               -0.036748
# pyroVelocity_model1                                 0.112269
# pyroVelocity_model2                                 0.112992
# CellDancer                                         -0.060430
#
#                       ('Radial Glia-like', 'Astrocytes')  ('OPC', 'OL')  \
# scVelo                                          0.828443       0.157301
# scVelo_stochastic                               0.854610      -0.834055
# VeloVI                                          0.735627       0.416491
# cell2fate                                       0.530908       0.639907
# VeloVAE                                         0.854610      -0.834056
# DeepVelo                                       -0.836790      -0.554259
# UniTVelo_unified                                0.820815       0.809826
# UniTVelo_independent                            0.845762       0.796332
# pyroVelocity_model1                            -0.708074      -0.971520
# pyroVelocity_model2                            -0.746838       0.893880
# CellDancer                                      0.853115       0.155512
#
#                           Mean
# scVelo                0.328672
# scVelo_stochastic     0.306031
# VeloVI                0.487539
# cell2fate             0.539490
# VeloVAE               0.306034
# DeepVelo              0.031799
# UniTVelo_unified      0.070953
# UniTVelo_independent  0.560862
# pyroVelocity_model1  -0.050454
# pyroVelocity_model2   0.202975
# CellDancer            0.378907

# %%
tab_summary
# Out:
#                       HumanBoneMarrow  MouseBoneMarrow  MouseErythroid  \
# scVelo                      -0.834022         0.019869       -0.245178
# scVelo_stochastic           -0.809160         0.624083        0.103058
# VeloVI                      -0.231157         0.644327        0.043375
# cell2fate                    0.547267         0.666890        0.753383
# VeloVAE                     -0.809161         0.618357        0.109266
# DeepVelo                    -0.014238         0.527266        0.311707
# UniTVelo_unified             0.810154        -0.823446        0.836053
# UniTVelo_independent        -0.592724         0.642935       -0.308906
# pyroVelocity_model1         -0.474476         0.862794       -0.730905
# pyroVelocity_model2          0.071976         0.163992        0.847454
# CellDancer                  -0.769573         0.025511        0.155512
#
#                       Pancreas_with_cc  DentateGyrus  Mean Across All Data
# scVelo                        0.501404      0.328672             -0.045851
# scVelo_stochastic             0.558253      0.306031              0.156453
# VeloVI                        0.595003      0.487539              0.307817
# cell2fate                     0.592413      0.539490              0.619889
# VeloVAE                       0.559883      0.306034              0.156876
# DeepVelo                      0.237521      0.031799              0.218811
# UniTVelo_unified              0.549499      0.070953              0.288643
# UniTVelo_independent          0.482571      0.560862              0.156948
# pyroVelocity_model1           0.569911     -0.050454              0.035374
# pyroVelocity_model2           0.575739      0.202975              0.372427
# CellDancer                    0.400666      0.378907              0.038205

# %%
tab
# Out:
#                       ('nIPC', 'Neuroblast')  \
# cell2fate                           0.271872
# VeloVI                              0.890016
# scVelo                              0.899306
# VeloVAE                             0.900370
# UniTVelo_independent                0.900003
# UniTVelo_unified                   -0.897451
# scVelo_stochastic                   0.900370
# DeepVelo                            0.762181
# pyroVelocity_model1                 0.880160
# pyroVelocity_model2                 0.912278
# CellDancer                          0.885312
#
#                       ('Neuroblast', 'Granule immature')  \
# cell2fate                                       0.654140
# VeloVI                                          0.573103
# scVelo                                         -0.051741
# VeloVAE                                         0.587496
# UniTVelo_independent                            0.298959
# UniTVelo_unified                               -0.562276
# scVelo_stochastic                               0.587493
# DeepVelo                                        0.552295
# pyroVelocity_model1                             0.434894
# pyroVelocity_model2                            -0.157438
# CellDancer                                      0.061026
#
#                       ('Granule immature', 'Granule mature')  \
# cell2fate                                           0.600624
# VeloVI                                             -0.177543
# scVelo                                             -0.189949
# VeloVAE                                             0.021749
# UniTVelo_independent                               -0.036748
# UniTVelo_unified                                    0.183850
# scVelo_stochastic                                   0.021740
# DeepVelo                                            0.235566
# pyroVelocity_model1                                 0.112269
# pyroVelocity_model2                                 0.112992
# CellDancer                                         -0.060430
#
#                       ('Radial Glia-like', 'Astrocytes')  ('OPC', 'OL')  \
# cell2fate                                       0.530908       0.639907
# VeloVI                                          0.735627       0.416491
# scVelo                                          0.828443       0.157301
# VeloVAE                                         0.854610      -0.834056
# UniTVelo_independent                            0.845762       0.796332
# UniTVelo_unified                                0.820815       0.809826
# scVelo_stochastic                               0.854610      -0.834055
# DeepVelo                                       -0.836790      -0.554259
# pyroVelocity_model1                            -0.708074      -0.971520
# pyroVelocity_model2                            -0.746838       0.893880
# CellDancer                                      0.853115       0.155512
#
#                           Mean
# cell2fate             0.539490
# VeloVI                0.487539
# scVelo                0.328672
# VeloVAE               0.306034
# UniTVelo_independent  0.560862
# UniTVelo_unified      0.070953
# scVelo_stochastic     0.306031
# DeepVelo              0.031799
# pyroVelocity_model1  -0.050454
# pyroVelocity_model2   0.202975
# CellDancer            0.378907

# %%
tab_summary
# Out:
#                       HumanBoneMarrow  MouseBoneMarrow  MouseErythroid  \
# scVelo                      -0.834022         0.019869       -0.245178
# scVelo_stochastic           -0.809160         0.624083        0.103058
# VeloVI                      -0.231157         0.644327        0.043375
# cell2fate                    0.547267         0.666890        0.753383
# VeloVAE                     -0.809161         0.618357        0.109266
# DeepVelo                    -0.014238         0.527266        0.311707
# UniTVelo_unified             0.810154        -0.823446        0.836053
# UniTVelo_independent        -0.592724         0.642935       -0.308906
# pyroVelocity_model1         -0.474476         0.862794       -0.730905
# pyroVelocity_model2          0.071976         0.163992        0.847454
# CellDancer                  -0.769573         0.025511        0.155512
#
#                       Pancreas_with_cc  DentateGyrus  Mean Across All Data
# scVelo                        0.501404      0.328672             -0.045851
# scVelo_stochastic             0.558253      0.306031              0.156453
# VeloVI                        0.595003      0.487539              0.307817
# cell2fate                     0.592413      0.539490              0.619889
# VeloVAE                       0.559883      0.306034              0.156876
# DeepVelo                      0.237521      0.031799              0.218811
# UniTVelo_unified              0.549499      0.070953              0.288643
# UniTVelo_independent          0.482571      0.560862              0.156948
# pyroVelocity_model1           0.569911     -0.050454              0.035374
# pyroVelocity_model2           0.575739      0.202975              0.372427
# CellDancer                    0.400666      0.378907              0.038205

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1, figsize=(4,7))
ax.axvline(ymin = 0, ymax = len(tab_summary.columns), color = 'black', linestyle = '--')
ax.scatter(np.array(tab_summary.loc['scVelo',:]), list(range(len(tab_summary.columns))),
           label = 'scvelo_dynamical', color = 'red', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['scVelo_stochastic',:]), list(range(len(tab_summary.columns))),
           label = 'scvelo_stochastic', color = 'orange', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['VeloVI',:]), list(range(len(tab_summary.columns))),
           label = 'veloVI', color = 'blue', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['VeloVAE',:]), list(range(len(tab_summary.columns))),
           label = 'veloVAE', color = 'grey', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['DeepVelo',:]), list(range(len(tab_summary.columns))),
           label = 'DeepVelo', color = 'brown', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['cell2fate',:]), list(range(len(tab_summary.columns))),
           label = 'cell2fate', color = 'yellow', alpha = 0.8, s = 300)
ax.set_xlabel('In-Cluster Coherence')
ax.set_yticks(list(range(len(tab_summary.columns))))
# ax.set_yticklabels(tab_summary.columns)
ax.set_yticklabels(['Human Bone Marrow', 'Mouse Bone Marrow', 'Mouse Erythroid', 'Mouse Pancreas', 'Mouse Dentate Gyrus', 'Mean Across All Datasets'])
ax.set_xlim(-1,1)
ax.legend(frameon=False)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('/nfs/team283/aa16/cell2fate_paper_results/ICC_benchmarking.pdf', bbox_inches='tight')

# %%
for dataset in datasets:
    print(dataset)
    tab = pd.read_csv(save_dir + dataset + '_CBDC_scores1.csv', index_col = 0)
    tab_summary.loc[:,dataset] = tab.loc[comparison, 'Mean']
tab_summary.loc[:, 'Mean Across All Data'] = np.mean(tab_summary, axis = 1)
# Out:
# HumanBoneMarrow
# MouseBoneMarrow
# MouseErythroid
# Pancreas_with_cc
# DentateGyrus

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1, figsize=(4,7))
ax.axvline(ymin = 0, ymax = len(tab_summary.columns), color = 'black', linestyle = '--')
ax.scatter(np.array(tab_summary.loc['scVelo',:]), list(range(len(tab_summary.columns))),
           label = 'scvelo_dynamical', color = 'red', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['scVelo_stochastic',:]), list(range(len(tab_summary.columns))),
           label = 'scvelo_stochastic', color = 'orange', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['VeloVI',:]), list(range(len(tab_summary.columns))),
           label = 'veloVI', color = 'blue', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['VeloVAE',:]), list(range(len(tab_summary.columns))),
           label = 'veloVAE', color = 'grey', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['DeepVelo',:]), list(range(len(tab_summary.columns))),
           label = 'DeepVelo', color = 'brown', alpha = 0.8, s = 300)
ax.scatter(np.array(tab_summary.loc['cell2fate',:]), list(range(len(tab_summary.columns))),
           label = 'cell2fate', color = 'yellow', alpha = 0.8, s = 300)
ax.set_xlabel('Cross Boundary Direction Correctness')
ax.set_yticks(list(range(len(tab_summary.columns))))
# ax.set_yticklabels(tab_summary.columns)
ax.set_yticklabels(['Human Bone Marrow', 'Mouse Bone Marrow', 'Mouse Erythroid', 'Mouse Pancreas', 'Mouse Dentate Gyrus', 'Mean Across All Datasets'])
ax.set_xlim(-1,1)
ax.legend(frameon=False)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('/nfs/team283/aa16/cell2fate_paper_results/CBDC_benchmarking.pdf', bbox_inches='tight')

# %%
tab_summary = tab_summary.sort_values('Mean Across All Data')

# %%
import seaborn as sns

# %%
tab_long = pd.melt(tab_summary, ignore_index = False)

# %%
tab_long['method'] = tab_long.index

# %%
tab_long['variable'][tab_long['variable'] == 'Pancreas_with_cc'] = 'MousePancreas'
tab_long['variable'][tab_long['variable'] == 'DentateGyrus'] = 'MouseDentateGyrus'
# Out:
# /tmp/ipykernel_43215/3656990627.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tab_long['variable'][tab_long['variable'] == 'Pancreas_with_cc'] = 'MousePancreas'
# /tmp/ipykernel_43215/3656990627.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tab_long['variable'][tab_long['variable'] == 'DentateGyrus'] = 'MouseDentateGyrus'

# %%
tab_long['method'][tab_long['method'] == 'scVelo'] = 'scVelo_dynamical'
# Out:
# /tmp/ipykernel_43215/686541083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tab_long['method'][tab_long['method'] == 'scVelo'] = 'scVelo_dynamical'

# %%
tab_long
# Out:
#                                  variable     value               method
# scVelo                    HumanBoneMarrow -0.834022     scVelo_dynamical
# pyroVelocity_model1       HumanBoneMarrow -0.474476  pyroVelocity_model1
# CellDancer                HumanBoneMarrow -0.769573           CellDancer
# scVelo_stochastic         HumanBoneMarrow -0.809160    scVelo_stochastic
# VeloVAE                   HumanBoneMarrow -0.809161              VeloVAE
# ...                                   ...       ...                  ...
# DeepVelo             Mean Across All Data  0.218811             DeepVelo
# UniTVelo_unified     Mean Across All Data  0.288643     UniTVelo_unified
# VeloVI               Mean Across All Data  0.307817               VeloVI
# pyroVelocity_model2  Mean Across All Data  0.372427  pyroVelocity_model2
# cell2fate            Mean Across All Data  0.619889            cell2fate
#
# [66 rows x 3 columns]

# %%
fig, ax = plt.subplots(1,1, figsize = (15, 5))
sns.barplot(data=tab_long, x="method", y="value", hue="variable", ax = ax,
           order= ['scVelo_dynamical', 'pyroVelocity_model1', 'scVelo_stochastic', 'VeloVAE', 'UniTVelo_independent', 
                   'DeepVelo', 'UniTVelo_unified', 'VeloVI', 'pyroVelocity_model2', 'cell2fate', 'CellDancer'])
plt.xticks(rotation = 45)
ax.set(xlabel='Method', ylabel='Cross Boundary Direction Correctness')
plt.gca().legend().set_title('')
plt.savefig('/nfs/team283/aa16/cell2fate_paper_results/CBDC_benchmarking.pdf', bbox_inches='tight')

# %%
# tab_long = tab_long[tab_long['variable'] != 'Mean Across All Data']

# %%
fig, ax = plt.subplots(1,1, figsize = (15, 5))
sns.barplot(data=tab_long, x="variable", y="value", hue="method", ax = ax,
           order = ['Mean Across All Data', 'MousePancreas', 'MouseDentateGyrus', 'MouseBoneMarrow', 'MouseErythroid',
                   'HumanBoneMarrow'])
plt.xticks(rotation = 45)
ax.set(xlabel='Dataset', ylabel='Cross Boundary Direction Correctness')
plt.gca().legend().set_title('')
plt.legend(ncol=2)
plt.savefig('/nfs/team283/aa16/cell2fate_paper_results/CBDC_benchmarking_reversed.pdf', bbox_inches='tight')
# Out:
# /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/seaborn/_base.py:1006: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_data.insert(0, var, comp_col)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 fig, ax = plt.subplots(1,1, figsize = (15, 5))
# ----> 2 sns.barplot(data=tab_long, x="variable", y="value", hue="method", ax = ax,
#       3            order = ['MousePancreas', 'MouseDentateGyrus', 'MouseBoneMarrow', 'MouseErythroid',
#       4                    'HumanBoneMarrow'])
#       5 plt.xticks(rotation = 45)
#       6 ax.set(xlabel='Dataset', ylabel='Cross Boundary Direction Correctness')
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/seaborn/categorical.py:2364, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2361 # Deprecations to remove in v0.15.0.
#    2362 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2364 p.plot_bars(
#    2365     aggregator=aggregator,
#    2366     dodge=dodge,
#    2367     width=width,
#    2368     gap=gap,
#    2369     color=color,
#    2370     fill=fill,
#    2371     capsize=capsize,
#    2372     err_kws=err_kws,
#    2373     plot_kws=kwargs,
#    2374 )
#    2376 p._add_axis_labels(ax)
#    2377 p._adjust_cat_axis(ax, axis=p.orient)
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/seaborn/categorical.py:1264, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1260     plot_kws.setdefault("linewidth", 1.5 * mpl.rcParams["lines.linewidth"])
#    1262 err_kws.setdefault("linewidth", 1.5 * mpl.rcParams["lines.linewidth"])
# -> 1264 for sub_vars, sub_data in self.iter_data(iter_vars,
#    1265                                          from_comp_data=True,
#    1266                                          allow_empty=True):
#    1268     ax = self._get_axes(sub_vars)
#    1270     agg_data = sub_data if sub_data.empty else (
#    1271         sub_data
#    1272         .groupby(self.orient)
#    1273         .apply(aggregator, agg_var)
#    1274         .reset_index()
#    1275     )
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/seaborn/_base.py:902, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#     899 grouping_vars = [var for var in grouping_vars if var in self.variables]
#     901 if from_comp_data:
# --> 902     data = self.comp_data
#     903 else:
#     904     data = self.plot_data
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/seaborn/_base.py:1006, in VectorPlotter.comp_data(self)
#    1004         else:
#    1005             comp_col = pd.Series(dtype=float, name=var)
# -> 1006         comp_data.insert(0, var, comp_col)
#    1008     self._comp_data = comp_data
#    1010 return self._comp_data
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/frame.py:4444, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
# -> 4444 value = self._sanitize_column(value)
#    4445 self._mgr.insert(loc, column, value)
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/frame.py:4532, in DataFrame._sanitize_column(self, value)
#    4530 # We should never get here with DataFrame value
#    4531 if isinstance(value, Series):
# -> 4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
#    4535     com.require_length_match(value, self.index)
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/frame.py:10999, in _reindex_for_setitem(value, index)
#   10995 except ValueError as err:
#   10996     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   10997     if not value.index.is_unique:
#   10998         # duplicate axis
# > 10999         raise err
#   11001     raise TypeError(
#   11002         "incompatible index of inserted column with frame index"
#   11003     ) from err
#   11004 return reindexed_value
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/frame.py:10994, in _reindex_for_setitem(value, index)
#   10992 # GH#4107
#   10993 try:
# > 10994     reindexed_value = value.reindex(index)._values
#   10995 except ValueError as err:
#   10996     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   10997     if not value.index.is_unique:
#   10998         # duplicate axis
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/series.py:4672, in Series.reindex(self, *args, **kwargs)
#    4668         raise TypeError(
#    4669             "'index' passed as both positional and keyword argument"
#    4670         )
#    4671     kwargs.update({"index": index})
# -> 4672 return super().reindex(**kwargs)
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/generic.py:4966, in NDFrame.reindex(self, *args, **kwargs)
#    4963     return self._reindex_multi(axes, copy, fill_value)
#    4965 # perform the reindex on the axes
# -> 4966 return self._reindex_axes(
#    4967     axes, level, limit, tolerance, method, fill_value, copy
#    4968 ).__finalize__(self, method="reindex")
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/generic.py:4986, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4981 new_index, indexer = ax.reindex(
#    4982     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    4983 )
#    4985 axis = self._get_axis_number(a)
# -> 4986 obj = obj._reindex_with_indexers(
#    4987     {axis: [new_index, indexer]},
#    4988     fill_value=fill_value,
#    4989     copy=copy,
#    4990     allow_dups=False,
#    4991 )
#    4992 # If we've made a copy once, no need to make another one
#    4993 copy = False
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/generic.py:5032, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5029     indexer = ensure_platform_int(indexer)
#    5031 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032 new_data = new_data.reindex_indexer(
#    5033     index,
#    5034     indexer,
#    5035     axis=baxis,
#    5036     fill_value=fill_value,
#    5037     allow_dups=allow_dups,
#    5038     copy=copy,
#    5039 )
#    5040 # If we've made a copy once, no need to make another one
#    5041 copy = False
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/internals/managers.py:679, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
# --> 679     self.axes[axis]._validate_can_reindex(indexer)
#     681 if axis >= self.ndim:
#     682     raise IndexError("Requested axis not found in manager")
#
# File /nfs/team283/aa16/software/miniconda3/envs/cell2fate_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:4107, in Index._validate_can_reindex(self, indexer)
#    4105 # trying to reindex on an axis with duplicates
#    4106 if not self._index_as_unique and len(indexer):
# -> 4107     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels
