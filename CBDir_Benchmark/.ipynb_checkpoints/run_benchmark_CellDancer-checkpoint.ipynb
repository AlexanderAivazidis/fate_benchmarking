# %%
import anndata
import numpy as np
import scvelo as scv
import scanpy as sc
import sys
import torch
import os.path
import celldancer as cd
import pickle5 as pickle
import matplotlib.pyplot as plt
import pandas as pd
import unitvelo as utv
from os.path import exists
import celldancer.cdplt as cdplt
from celldancer.cdplt import colormap
method = 'CellDancer'
import time
from celldancer.utilities import export_velocity_to_dynamo
import celldancer.utilities as cdutil
# Out:
# (Running UniTVelo 0.2.5.2)
# 2024-02-07 16:58:00

# %%
datasets = ['MouseErythroid', 'Pancreas_with_cc', 'DentateGyrus' , 'MouseBoneMarrow', 'HumanBoneMarrow', 'HumanDevelopingBrain']
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results_revision/'

# %%
for i in range(0, len(datasets)):
    # for dataset in datasets:
    dataset = datasets[i]
    print(dataset)
    adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
    start = time.time()
    scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=3000)
    scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
    input_data = cdutil.adata_to_df_with_embed(adata,
                                  us_para=['Mu','Ms'],
                                  cell_type_para='clusters',
                                  embed_para='X_umap',
                                  save_path='cell_type_u_s.csv')
    loss_df, cellDancer_df=cd.velocity(input_data,
                                       gene_list= np.array(input_data['gene_name']),
                                       permutation_ratio=0.125,
                                       n_jobs=1)
    # compute cell velocity
    cellDancer_df=cd.compute_cell_velocity(cellDancer_df=cellDancer_df, projection_neighbor_choice='gene', 
                                           expression_scale='power10', projection_neighbor_size=10, speed_up=(100,100))
    adata = export_velocity_to_dynamo(cellDancer_df,adata)
    end = time.time()
    adata.layers['velocity'] = np.array(adata.layers['velocity_S'].todense())
    del adata.layers['velocity_S']
    scv.pp.neighbors(adata)
    scv.tl.velocity_graph(adata, vkey = 'velocity')
    scv.tl.velocity_embedding(adata, vkey = 'velocity')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_CellDancer.svg')
    # Calculate performance metrics:
    file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
    ground_truth = pickle.load(file)
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_CBDC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_CBDC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(metrics['Cross-Boundary Direction Correctness (A->B)'].keys()) + ['Mean', 'Time'],
                 index = [method])
    cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
    tab.loc[method,:] = cb_score + [np.mean(cb_score), end-start]
    tab.to_csv(save_dir + dataset + '_CBDC_scores.csv')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_' + method + '.svg')
    adata.write_h5ad('/nfs/team283/aa16/data/fate_benchmarking/' + method + dataset + 'AnnDataForCellRank.h5ad')
# Out:
# MouseErythroid
# Filtered out 47456 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:39) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:02) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#  31%|████████████████████████████████████▌                                                                                | 938/3000 [01:37<03:34,  9.61it/s]
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_15524/362253435.py", line 13, in <module>
#     save_path='cell_type_u_s.csv')
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/celldancer/utilities.py", line 214, in adata_to_df_with_embed
#     data_onegene.to_csv(save_path,mode='a',header=False,index=False)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/core/generic.py", line 3482, in to_csv
#     storage_options=storage_options,
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/format.py", line 1105, in to_csv
#     csv_formatter.save()
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/csvs.py", line 257, in save
#     self._save()
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/csvs.py", line 262, in _save
#     self._save_body()
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/csvs.py", line 300, in _save_body
#     self._save_chunk(start_i, end_i)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/csvs.py", line 310, in _save_chunk
#     ix = self.data_index[slicer]._format_native_types(**self._number_format)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/core/indexes/numeric.py", line 324, in _format_native_types
#     **kwargs,
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 1268, in _format_native_types
#     values = np.asarray(self).astype(str)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_15524/362253435.py in <module>
#      12                                   embed_para='X_umap',
# ---> 13                                   save_path='cell_type_u_s.csv')
#      14     loss_df, cellDancer_df=cd.velocity(input_data,
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/celldancer/utilities.py in adata_to_df_with_embed(adata, us_para, cell_type_para, embed_para, save_path, gene_list)
#     213         else:
# --> 214             data_onegene.to_csv(save_path,mode='a',header=False,index=False)
#     215
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     256
# --> 257             self._save()
#     258
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save(self)
#     261             self._save_header()
# --> 262         self._save_body()
#     263
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save_body(self)
#     299                 break
# --> 300             self._save_chunk(start_i, end_i)
#     301
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     309
# --> 310         ix = self.data_index[slicer]._format_native_types(**self._number_format)
#     311         libwriters.write_csv_rows(
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/core/indexes/numeric.py in _format_native_types(self, na_rep, float_format, decimal, quoting, **kwargs)
#     323             quoting=quoting,
# --> 324             **kwargs,
#     325         )
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/pandas/core/indexes/base.py in _format_native_types(self, na_rep, quoting, **kwargs)
#    1267         if not self.is_object() and not quoting:
# -> 1268             values = np.asarray(self).astype(str)
#    1269         else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2098                         # in the engines. This should return a list of strings.
# -> 2099                         stb = value._render_traceback_()
#    2100                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2100                     except Exception:
#    2101                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2102                                             value, tb, tb_offset=tb_offset)
#    2103
#    2104                     self._showtraceback(etype, value, stb)
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /nfs/team283/aa16/software/miniconda3/envs/cellDancer/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
