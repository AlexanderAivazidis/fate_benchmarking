# %%
import pandas as pd

# %%
# 'Cell2fateDynamicalModel_250epochsbatchSize128lr0005_10samples',
model_list = ('Cell2fateDynamicalModel_pyroVelocityTrainingPlan',
    'Cell2fateDynamicalModel_earlyStopping_Patience5MinDelta0005_10samples',
    'Cell2fateDynamicalModel_earlyStopping_Patience45_10samples',
    'Cell2fateDynamicalModel_earlyStopping_10samples',
              'Cell2fateDynamicalModel_400epochs_10samples',
    'Cell2fateDynamicalModel_300epochs_10samples', 
    'Cell2fateDynamicalModelLambda1_400epochs_10samples',
                 'Cell2fateDynamicalModelLambda1_500epochs_10samples',
                  'Cell2fateDynamicalModelLambda1_600epochs_10samples',    
    'Cell2fateDynamicalModel_TimeMixtureNew',
    'Cell2fateDynamicalModel_VeryRobustOptimization2',
    'Cell2fateDynamicalModel_VeryRobustOptimization',
    'Cell2fateDynamicalModel_robustOptimization',
    'Cell2fateDynamicalModel_FreeModules_750epochs_10samples',
        'Cell2fateDynamicalModel_1000epochs_10samples_seed9',
              'Cell2fateDynamicalModel_1000epochs_10samples_seed99',
              'Cell2fateDynamicalModel_1000epochs_10samples_seed999',
                            'Cell2fateDynamicalModel_250epochsbatchSize128lr0005_10samples',
                  'Cell2fateDynamicalModelLambda1_400epochs_10samples',
                 'Cell2fateDynamicalModelLambda1_500epochs_10samples',
                  'Cell2fateDynamicalModelLambda1_600epochs_10samples',
    'Cell2fateDynamicalModel_250epochsbatchSize128_10samples',
              'Cell2fateDynamicalModel_400epochs_10samples',
    'Cell2fateDynamicalModelGamma15_400epochs_10samples',
              'Cell2fateDynamicalModelTmax150Gamma05Lambda1_Init-tdelta0_400epochs_10samples',
              'Cell2fateDynamicalModel_FreeModules_300epochs_10samples',
    'Cell2fateDynamicalModelTmax150Gamma05Lambda1_400epochs_10samples_400epochs_10samples',
    'Cell2fateDynamicalModelTmax250_400epochs_10samples',
    'Cell2fateDynamicalModelGamma05_400epochs_10samples',
    'Cell2fateDynamicalModelTimeAsParam_400epochs_10samples',
    'Cell2fateDynamicalModel_400epochs', 'Cell2fateDynamicalModel_400epochs_10samples',
              'Cell2fateDynamicalModel_400epochs_100samples',
              'Cell2fateDynamicalModel_400epochs_10samples_posteriorBatches',
             'Cell2fateDynamicalModel_500epochs_10samples', 'Cell2fateDynamicalModel_epochs2500lr000210samples',
             'Cell2fateDynamicalModel_epochs1000lr000210samples', 'Cell2fateDynamicalModel_600epochs_10samples',
             'Cell2fateDynamicalModel_batchSize2000epochs2000_10samples')

# %%
res_list = []
for i in range(len(model_list)):
    res= pd.read_csv('/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/' +
                model_list[i]
                + '__CBDC_fullBenchmark.csv', index_col=0)
    res_list += [res.iloc[:,0]]
    tab = pd.concat(res_list, axis = 1)
tab.columns = [m[22:] for m in model_list]
tab
# Out:
#          l_pyroVelocityTrainingPlan  \
# 0-0-2                      0.668894
# 0-0-0                      0.197397
# 0-0-1                      0.294410
# 0-0-3                      0.512998
# 0-0-4                      0.184023
# 0-1-2                     -0.441505
# 0-1-0                      0.201495
# 0-1-1                      0.106631
# 0-1-3                      0.545378
# 0-1-4                      0.373145
# 1-0-2                      0.621618
# 1-0-0                     -0.435349
# 1-0-1                      0.432870
# 1-0-3                      0.570624
# 1-0-4                      0.339831
# 1-1-2                      0.645214
# 1-1-0                     -0.191421
# 1-1-1                      0.261459
# 1-1-3                     -0.647545
# 1-1-4                      0.161724
# AVERAGE                    0.220095
#
#          l_earlyStopping_Patience5MinDelta0005_10samples  \
# 0-0-2                                          -0.649056
# 0-0-0                                          -0.525781
# 0-0-1                                           0.170550
# 0-0-3                                           0.578345
# 0-0-4                                           0.134596
# 0-1-2                                          -0.247974
# 0-1-0                                          -0.506317
# 0-1-1                                           0.261126
# 0-1-3                                           0.720781
# 0-1-4                                          -0.417978
# 1-0-2                                           0.797065
# 1-0-0                                          -0.547092
# 1-0-1                                           0.093834
# 1-0-3                                           0.709381
# 1-0-4                                           0.310441
# 1-1-2                                           0.824895
# 1-1-0                                          -0.501318
# 1-1-1                                           0.230424
# 1-1-3                                          -0.689445
# 1-1-4                                           0.347520
# AVERAGE                                         0.054700
#
#          l_earlyStopping_Patience45_10samples  l_earlyStopping_10samples  \
# 0-0-2                                0.735632                   0.771082
# 0-0-0                               -0.502780                   0.577247
# 0-0-1                                0.156179                   0.372810
# 0-0-3                                0.619530                   0.532615
# 0-0-4                               -0.093917                   0.339517
# 0-1-2                                0.578436                   0.751949
# 0-1-0                                0.056573                  -0.499455
# 0-1-1                                0.074078                   0.364883
# 0-1-3                                0.566268                   0.603272
# 0-1-4                                0.199456                   0.381112
# 1-0-2                                0.596912                   0.796568
# 1-0-0                               -0.429012                  -0.417068
# 1-0-1                                0.281426                   0.456208
# 1-0-3                               -0.726776                   0.540205
# 1-0-4                                0.323127                   0.303790
# 1-1-2                               -0.654676                   0.631484
# 1-1-0                               -0.480723                   0.315538
# 1-1-1                                0.324861                   0.015870
# 1-1-3                                0.069645                  -0.759517
# 1-1-4                               -0.400592                  -0.368863
# AVERAGE                              0.064682                   0.285462
#
#          l_400epochs_10samples  l_300epochs_10samples  \
# 0-0-2                -0.681916               0.672400
# 0-0-0                 0.605134              -0.537085
# 0-0-1                 0.354592               0.134586
# 0-0-3                 0.619194               0.673443
# 0-0-4                 0.306717               0.407781
# 0-1-2                 0.730862               0.731607
# 0-1-0                 0.576238              -0.538785
# 0-1-1                 0.335564               0.473432
# 0-1-3                 0.655279               0.115273
# 0-1-4                -0.449201               0.311848
# 1-0-2                 0.661847              -0.745092
# 1-0-0                 0.565487              -0.515454
# 1-0-1                 0.211187               0.087059
# 1-0-3                 0.632821               0.675812
# 1-0-4                 0.295859              -0.303962
# 1-1-2                 0.665855               0.763541
# 1-1-0                -0.519356              -0.187510
# 1-1-1                 0.538459               0.284643
# 1-1-3                 0.539381               0.710916
# 1-1-4                 0.204492               0.379536
# AVERAGE               0.342425               0.179700
#
#          lLambda1_400epochs_10samples  lLambda1_500epochs_10samples  \
# 0-0-2                       -0.693640                      0.654685
# 0-0-0                        0.568736                      0.346174
# 0-0-1                       -0.055737                      0.193081
# 0-0-3                        0.662562                      0.659105
# 0-0-4                       -0.355310                      0.085578
# 0-1-2                        0.677422                      0.646357
# 0-1-0                       -0.130337                     -0.543851
# 0-1-1                        0.154929                      0.487239
# 0-1-3                       -0.770111                      0.610319
# 0-1-4                        0.256319                      0.276864
# 1-0-2                        0.652962                      0.647458
# 1-0-0                        0.555488                      0.287170
# 1-0-1                        0.170213                      0.029235
# 1-0-3                        0.688684                      0.602179
# 1-0-4                       -0.671670                      0.348136
# 1-1-2                        0.688207                      0.680120
# 1-1-0                       -0.327199                     -0.445933
# 1-1-1                        0.531223                     -0.307314
# 1-1-3                        0.616818                     -0.741396
# 1-1-4                        0.415198                      0.261677
# AVERAGE                      0.181738                      0.238844
#
#          lLambda1_600epochs_10samples  l_TimeMixtureNew  ...  \
# 0-0-2                       -0.598949         -0.611250  ...
# 0-0-0                       -0.387944          0.580626  ...
# 0-0-1                        0.277994         -0.067858  ...
# 0-0-3                        0.581249         -0.830091  ...
# 0-0-4                       -0.335993          0.544157  ...
# 0-1-2                             NaN          0.198628  ...
# 0-1-0                             NaN          0.572322  ...
# 0-1-1                             NaN         -0.093304  ...
# 0-1-3                             NaN         -0.827800  ...
# 0-1-4                             NaN          0.532052  ...
# 1-0-2                             NaN         -0.787108  ...
# 1-0-0                             NaN          0.608022  ...
# 1-0-1                             NaN         -0.299600  ...
# 1-0-3                             NaN         -0.838879  ...
# 1-0-4                             NaN          0.638407  ...
# 1-1-2                             NaN          0.451414  ...
# 1-1-0                             NaN          0.584722  ...
# 1-1-1                             NaN         -0.118609  ...
# 1-1-3                             NaN         -0.836007  ...
# 1-1-4                             NaN          0.460123  ...
# AVERAGE                           NaN         -0.007002  ...
#
#          lTimeAsParam_400epochs_10samples  l_400epochs  l_400epochs_10samples  \
# 0-0-2                            0.634958    -0.712021              -0.681916
# 0-0-0                           -0.523965     0.586732               0.605134
# 0-0-1                            0.098848     0.359557               0.354592
# 0-0-3                                 NaN    -0.735798               0.619194
# 0-0-4                            0.030934     0.111207               0.306717
# 0-1-2                           -0.750370     0.481294               0.730862
# 0-1-0                           -0.500851    -0.408628               0.576238
# 0-1-1                            0.202778     0.218145               0.335564
# 0-1-3                                 NaN     0.627341               0.655279
# 0-1-4                            0.211421    -0.479306              -0.449201
# 1-0-2                                 NaN     0.683047               0.661847
# 1-0-0                                 NaN     0.365940               0.565487
# 1-0-1                                 NaN     0.276947               0.211187
# 1-0-3                                 NaN    -0.507948               0.632821
# 1-0-4                                 NaN    -0.461924               0.295859
# 1-1-2                                 NaN    -0.466571               0.665855
# 1-1-0                                 NaN    -0.523098              -0.519356
# 1-1-1                                 NaN     0.332432               0.538459
# 1-1-3                                 NaN    -0.316521               0.539381
# 1-1-4                                 NaN     0.262790               0.204492
# AVERAGE                               NaN    -0.015319               0.342425
#
#          l_400epochs_100samples  l_400epochs_10samples_posteriorBatches  \
# 0-0-2                  0.688303                                0.709900
# 0-0-0                 -0.489337                               -0.508409
# 0-0-1                 -0.038269                                0.271409
# 0-0-3                  0.610908                                0.463010
# 0-0-4                  0.354259                               -0.443985
# 0-1-2                  0.705848                                0.686606
# 0-1-0                  0.576641                               -0.198404
# 0-1-1                  0.479599                                0.145942
# 0-1-3                  0.632332                                0.281487
# 0-1-4                  0.366432                                0.353539
# 1-0-2                       NaN                                0.699379
# 1-0-0                       NaN                                0.532413
# 1-0-1                       NaN                                0.034586
# 1-0-3                       NaN                                0.564050
# 1-0-4                       NaN                               -0.463673
# 1-1-2                       NaN                                0.683796
# 1-1-0                       NaN                               -0.520912
# 1-1-1                       NaN                                0.123067
# 1-1-3                       NaN                                0.525454
# 1-1-4                       NaN                               -0.477800
# AVERAGE                     NaN                                0.173073
#
#          l_500epochs_10samples  l_epochs2500lr000210samples  \
# 0-0-2                -0.647153                     0.657396
# 0-0-0                 0.608764                    -0.476776
# 0-0-1                -0.043170                     0.220734
# 0-0-3                 0.610381                     0.555310
# 0-0-4                 0.375893                    -0.339804
# 0-1-2                -0.638009                     0.674220
# 0-1-0                 0.552989                    -0.440107
# 0-1-1                 0.195721                     0.056359
# 0-1-3                 0.617698                     0.527965
# 0-1-4                -0.392954                    -0.454324
# 1-0-2                -0.641287                     0.632046
# 1-0-0                 0.551872                    -0.546744
# 1-0-1                 0.383836                     0.156805
# 1-0-3                -0.632344                     0.531710
# 1-0-4                 0.290575                    -0.392341
# 1-1-2                -0.653182                     0.609886
# 1-1-0                -0.483570                    -0.485559
# 1-1-1                 0.248191                    -0.006447
# 1-1-3                -0.228103                     0.503233
# 1-1-4                 0.183674                    -0.362075
# AVERAGE               0.011734                     0.081074
#
#          l_epochs1000lr000210samples  l_600epochs_10samples  \
# 0-0-2                       0.738638              -0.633816
# 0-0-0                      -0.579913              -0.542854
# 0-0-1                       0.138556               0.061533
# 0-0-3                       0.587036               0.591861
# 0-0-4                      -0.393742              -0.466328
# 0-1-2                       0.731270               0.604150
# 0-1-0                      -0.285313               0.553058
# 0-1-1                       0.033358               0.280605
# 0-1-3                       0.556867              -0.647683
# 0-1-4                      -0.331750               0.247480
# 1-0-2                       0.773741               0.710462
# 1-0-0                      -0.547105              -0.502971
# 1-0-1                      -0.029849               0.507915
# 1-0-3                       0.599591               0.594354
# 1-0-4                      -0.341409              -0.444234
# 1-1-2                       0.499984               0.595899
# 1-1-0                      -0.553827              -0.462910
# 1-1-1                       0.187518               0.321058
# 1-1-3                       0.538339              -0.710113
# 1-1-4                      -0.401428              -0.482910
# AVERAGE                     0.096028               0.008728
#
#          l_batchSize2000epochs2000_10samples
# 0-0-2                               0.112797
# 0-0-0                              -0.327242
# 0-0-1                              -0.026760
# 0-0-3                              -0.293895
# 0-0-4                              -0.492223
# 0-1-2                              -0.012225
# 0-1-0                              -0.499488
# 0-1-1                              -0.298488
# 0-1-3                               0.475129
# 0-1-4                               0.531508
# 1-0-2                               0.062934
# 1-0-0                              -0.508628
# 1-0-1                              -0.001388
# 1-0-3                               0.360367
# 1-0-4                              -0.458398
# 1-1-2                              -0.055640
# 1-1-0                              -0.513430
# 1-1-1                              -0.075361
# 1-1-3                              -0.641584
# 1-1-4                               0.320485
# AVERAGE                            -0.117077
#
# [21 rows x 39 columns]
