# %%
import os
os.chdir('..')
os.chdir('..')
import scvelo as scv
import scanpy as sc
import scvi
scvi.settings.seed = 1
import cell2fate as c2f
import pickle as pickle
from eval_utils import cross_boundary_correctness
from datetime import datetime
import pandas as pd
import numpy as np
from os.path import exists
import matplotlib.pyplot as plt
import torch
import unitvelo as utv
method = 'Cell2fateDynamicalModel_earlyStopping_Patience5MinDelta0005_10samples'
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'
datasets = ['Pancreas_with_cc',  'DentateGyrus' , 'MouseBoneMarrow', 'MouseErythroid', 'HumanBoneMarrow']
n_genes_list = np.array((2000, 3000))
n_counts_list = np.array((10, 20))

for i in range(len(n_genes_list)):
    for j in range(len(n_counts_list)):
        for k in (2,0,1,3,4):
            print(i)
            print(j)
            print(k)
            dataset = datasets[k]
            n_genes = n_genes_list[i]
            min_counts = n_counts_list[j]
            model_index = str(i) + '-' + str(j) + '-' + str(k)
            save_name = method + '_'
            if exists(save_dir + save_name + '_CBDC_fullBenchmark.csv'):
                tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
                if model_index in tab.index:
                    continue
            adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
            adata = c2f.utils.get_training_data(adata, cells_per_cluster = 10**6, cluster_column = 'clusters',
                                            remove_clusters = [], min_shared_counts = min_counts, n_var_genes= n_genes)
            c2f.Cell2fate_DynamicalModel.setup_anndata(adata, spliced_label='spliced', unspliced_label='unspliced')    
            n_modules = c2f.utils.get_max_modules(adata)
            mod = c2f.Cell2fate_DynamicalModel(adata,
                                               n_modules = n_modules)   
            mod.train(max_epochs = 1000, lr = 0.01, early_stopping = True, early_stopping_min_delta = 0.005,
            early_stopping_monitor = 'elbo_train', early_stopping_patience = 5)
            sample_kwarg = {"num_samples": 10, "batch_size" : adata.n_obs,
                 "use_gpu" : True, 'return_samples': False}
            adata = mod.export_posterior(adata, sample_kwargs = sample_kwarg)
            mod.compute_and_plot_total_velocity_scvelo(adata, save = False, delete = False)
            # Calculate performance metrics:
            file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
            ground_truth = pickle.load(file)
            metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
            cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                        for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
            if exists(save_dir + save_name + '_CBDC_fullBenchmark.csv'):
                tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
            else:
                c_names = ['CBDC']
                tab = pd.DataFrame(columns = c_names)
            tab.loc[model_index, 'CBDC'] = np.mean(cb_score)
            tab.to_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv')
tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
tab.loc['AVERAGE', 'CBDC'] = np.mean(tab['CBDC'])
tab.to_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv')
# Out:
# Global seed set to 0
# Global seed set to 1
# (Running UniTVelo 0.2.5.2)
# 2023-11-16 13:00:33
# 2023-11-16 13:00:34.255547: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-16 13:00:34.255601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-16 13:00:34.257210: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 0
# 0
# 2
# Keeping at most 1000000 cells per cluster
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Filtered out 19601 genes that are detected 10 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 152/1000:  15%|███████████████▊                                                                                        | 152/1000 [01:33<08:40,  1.63it/s, v_num=1, elbo_train=3.79e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 3782999.250. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.22s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:01<00:00,  6.08it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.7034968487735339, ('progenitors', 'activating'): -0.5946154974838188}
# Total Mean: -0.6490561731286764
# # In-cluster Coherence
# {'B cell lineage': 0.78724277, 'activating': 0.8998989, 'dividing': 0.90948755, 'macrophages': 0.8702293, 'progenitors': 0.80900013}
# Total Mean: 0.8551716804504395
# 0
# 0
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 19641 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 160/1000:  16%|████████████████▋                                                                                       | 160/1000 [02:45<14:30,  1.04s/it, v_num=1, elbo_train=7.08e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 7069583.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.62s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.64it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): -0.5394087246371992, ('Pre-endocrine', 'Alpha'): -0.7052053979066042, ('Pre-endocrine', 'Beta'): -0.762455212669556, ('Pre-endocrine', 'Delta'): -0.4013507478073508, ('Pre-endocrine', 'Epsilon'): -0.22048473671265797}
# Total Mean: -0.5257809639466735
# # In-cluster Coherence
# {'Alpha': 0.93275386, 'Beta': 0.938235, 'Delta': 0.93575954, 'Ductal': 0.9102856, 'Epsilon': 0.9096155, 'Ngn3 high EP': 0.8905882, 'Ngn3 low EP': 0.8917375, 'Pre-endocrine': 0.9197433}
# Total Mean: 0.9160897731781006
# 0
# 0
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 9174 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 368 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 175/1000:  18%|██████████████████▏                                                                                     | 175/1000 [02:15<10:39,  1.29it/s, v_num=1, elbo_train=3.93e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 3931031.750. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.96s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  4.45it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.711687239873483, ('Neuroblast', 'Granule immature'): 0.6585553905233316, ('Granule immature', 'Granule mature'): 0.19715797634199753, ('Radial Glia-like', 'Astrocytes'): -0.27369678014462867, ('OPC', 'OL'): -0.4409517923819376}
# Total Mean: 0.17055040684244915
# # In-cluster Coherence
# {'Astrocytes': 0.5820646, 'Cajal Retzius': 0.9036319, 'Cck-Tox': 0.93720734, 'Endothelial': 0.72371227, 'GABA': 0.9393329, 'Granule immature': 0.9402219, 'Granule mature': 0.9523861, 'Microglia': 0.6211248, 'Mossy': 0.936841, 'Neuroblast': 0.9127487, 'OL': 0.6836005, 'OPC': 0.58178705, 'Radial Glia-like': 0.58918357, 'nIPC': 0.8749516}
# Total Mean: 0.798485279083252
# 0
# 0
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 46616 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Epoch 247/1000:  25%|█████████████████████████▉                                                                               | 247/1000 [08:34<26:09,  2.08s/it, v_num=1, elbo_train=2.2e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 21954810.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.81s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.77it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.41682563236313586, ('Blood progenitors 2', 'Erythroid1'): 0.5411351162581163, ('Erythroid1', 'Erythroid2'): 0.5884265726778736, ('Erythroid2', 'Erythroid3'): 0.76699394514963}
# Total Mean: 0.5783453166121889
# # In-cluster Coherence
# {'Blood progenitors 1': 0.9226628, 'Blood progenitors 2': 0.9456505, 'Erythroid1': 0.9687967, 'Erythroid2': 0.9439835, 'Erythroid3': 0.98969203}
# Total Mean: 0.9541571736335754
# 0
# 0
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 6962 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 312 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 10
# Maximal Number of Modules: 11
# Epoch 154/1000:  15%|████████████████                                                                                        | 154/1000 [03:30<19:19,  1.37s/it, v_num=1, elbo_train=9.96e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 9963969.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.13s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.70it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.4656415925656951, ('HSC_1', 'HSC_2'): -0.4455749654035416, ('Ery_1', 'Ery_2'): 0.3837223138445461}
# Total Mean: 0.13459631366889988
# # In-cluster Coherence
# {'CLP': 0.9199016, 'DCs': 0.7408627, 'Ery_1': 0.8215801, 'Ery_2': 0.841643, 'HSC_1': 0.8625836, 'HSC_2': 0.86473715, 'Mega': 0.91946006, 'Mono_1': 0.7492499, 'Mono_2': 0.7957175, 'Precursors': 0.8189411}
# Total Mean: 0.8334676623344421
# 0
# 1
# 2
# Keeping at most 1000000 cells per cluster
# Filtered out 20300 genes that are detected 20 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 71/1000:   7%|███████▌                                                                                                  | 71/1000 [00:41<09:04,  1.71it/s, v_num=1, elbo_train=3.05e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 3042580.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.42s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 13.13it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.13343821960879776, ('progenitors', 'activating'): -0.3625090080957569}
# Total Mean: -0.24797361385227734
# # In-cluster Coherence
# {'B cell lineage': 0.9216554, 'activating': 0.9131486, 'dividing': 0.9448093, 'macrophages': 0.91032964, 'progenitors': 0.9373193}
# Total Mean: 0.9254524111747742
# 0
# 1
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 20801 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 151/1000:  15%|███████████████▋                                                                                        | 151/1000 [02:35<14:32,  1.03s/it, v_num=1, elbo_train=7.76e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 7746813.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.56s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.69it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): -0.4684973845467057, ('Pre-endocrine', 'Alpha'): -0.7079342165665157, ('Pre-endocrine', 'Beta'): -0.7778455257925082, ('Pre-endocrine', 'Delta'): -0.35546965785407875, ('Pre-endocrine', 'Epsilon'): -0.22183727513008747}
# Total Mean: -0.5063168119779792
# # In-cluster Coherence
# {'Alpha': 0.93602574, 'Beta': 0.93087983, 'Delta': 0.92667866, 'Ductal': 0.8502493, 'Epsilon': 0.90292627, 'Ngn3 high EP': 0.83600986, 'Ngn3 low EP': 0.7628843, 'Pre-endocrine': 0.9116255}
# Total Mean: 0.882159948348999
# 0
# 1
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 10340 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 327 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 14
# Maximal Number of Modules: 16
# Epoch 189/1000:  19%|███████████████████▋                                                                                    | 189/1000 [02:32<10:54,  1.24it/s, v_num=1, elbo_train=4.65e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 4649956.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  4.32it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.2650367499317425, ('Neuroblast', 'Granule immature'): 0.5007860693802928, ('Granule immature', 'Granule mature'): 0.27086427367976623, ('Radial Glia-like', 'Astrocytes'): 0.44763533846875564, ('OPC', 'OL'): 0.3513793532514563}
# Total Mean: 0.2611256569697057
# # In-cluster Coherence
# {'Astrocytes': 0.63500786, 'Cajal Retzius': 0.3043573, 'Cck-Tox': 0.957707, 'Endothelial': 0.3862153, 'GABA': 0.94789475, 'Granule immature': 0.90748113, 'Granule mature': 0.90750504, 'Microglia': 0.35273588, 'Mossy': 0.9540241, 'Neuroblast': 0.57407564, 'OL': 0.68480194, 'OPC': 0.5311436, 'Radial Glia-like': 0.542736, 'nIPC': 0.41803417}
# Total Mean: 0.6502656936645508
# 0
# 1
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 47456 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Epoch 203/1000:  20%|█████████████████████                                                                                   | 203/1000 [07:03<27:44,  2.09s/it, v_num=1, elbo_train=2.36e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 23602986.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.11s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.77it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.672487531254154, ('Blood progenitors 2', 'Erythroid1'): 0.6208672336770646, ('Erythroid1', 'Erythroid2'): 0.8086607763896115, ('Erythroid2', 'Erythroid3'): 0.7811084167043623}
# Total Mean: 0.7207809895062981
# # In-cluster Coherence
# {'Blood progenitors 1': 0.9697542, 'Blood progenitors 2': 0.9790712, 'Erythroid1': 0.9815495, 'Erythroid2': 0.9856955, 'Erythroid3': 0.98985094}
# Total Mean: 0.9811843037605286
# 0
# 1
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 7837 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 303 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 10
# Maximal Number of Modules: 11
# Epoch 187/1000:  19%|███████████████████▍                                                                                    | 187/1000 [04:17<18:37,  1.37s/it, v_num=1, elbo_train=1.09e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 10880080.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.01s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.69it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): -0.6951750573521643, ('HSC_1', 'HSC_2'): -0.14924904328491112, ('Ery_1', 'Ery_2'): -0.40951007563515407}
# Total Mean: -0.4179780587574098
# # In-cluster Coherence
# {'CLP': 0.6142035, 'DCs': 0.672258, 'Ery_1': 0.6424694, 'Ery_2': 0.7179059, 'HSC_1': 0.80885756, 'HSC_2': 0.6999048, 'Mega': 0.7774835, 'Mono_1': 0.8319725, 'Mono_2': 0.7656293, 'Precursors': 0.7145817}
# Total Mean: 0.724526584148407
# 1
# 0
# 2
# Keeping at most 1000000 cells per cluster
# Filtered out 19601 genes that are detected 10 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 148/1000:  15%|███████████████▌                                                                                         | 148/1000 [01:28<08:28,  1.67it/s, v_num=1, elbo_train=3.8e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 3795347.750. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.23s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:01<00:00,  6.08it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): 0.7978896368934714, ('progenitors', 'activating'): 0.7962399647584788}
# Total Mean: 0.7970648008259751
# # In-cluster Coherence
# {'B cell lineage': 0.7884878, 'activating': 0.9568907, 'dividing': 0.94009024, 'macrophages': 0.8734717, 'progenitors': 0.9389656}
# Total Mean: 0.899581253528595
# 1
# 0
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 19641 genes that are detected 10 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 173/1000:  17%|█████████████████▉                                                                                      | 173/1000 [03:18<15:49,  1.15s/it, v_num=1, elbo_train=1.05e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 10522416.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.26s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.55it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): -0.7327938773566276, ('Pre-endocrine', 'Alpha'): -0.7069031411720313, ('Pre-endocrine', 'Beta'): -0.7350854756203893, ('Pre-endocrine', 'Delta'): -0.3522316522710451, ('Pre-endocrine', 'Epsilon'): -0.20844695236479052}
# Total Mean: -0.5470922197569767
# # In-cluster Coherence
# {'Alpha': 0.81535935, 'Beta': 0.8255866, 'Delta': 0.83127666, 'Ductal': 0.9816829, 'Epsilon': 0.8438972, 'Ngn3 high EP': 0.91564345, 'Ngn3 low EP': 0.96301806, 'Pre-endocrine': 0.9103833}
# Total Mean: 0.8858559727668762
# 1
# 0
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 9174 genes that are detected 10 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 524 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 247/1000:  25%|█████████████████████████▋                                                                              | 247/1000 [03:35<10:58,  1.14it/s, v_num=1, elbo_train=5.99e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 5984505.500. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.23s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.13it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.032803980792079857, ('Neuroblast', 'Granule immature'): 0.4634830241992006, ('Granule immature', 'Granule mature'): 0.22822306708483905, ('Radial Glia-like', 'Astrocytes'): -0.4839881874145248, ('OPC', 'OL'): 0.22864970685196379}
# Total Mean: 0.09383431830271169
# # In-cluster Coherence
# {'Astrocytes': 0.6931764, 'Cajal Retzius': 0.70475054, 'Cck-Tox': 0.93203354, 'Endothelial': 0.6880806, 'GABA': 0.88099074, 'Granule immature': 0.92193675, 'Granule mature': 0.9408028, 'Microglia': 0.873978, 'Mossy': 0.9245371, 'Neuroblast': 0.6882928, 'OL': 0.77767235, 'OPC': 0.60244185, 'Radial Glia-like': 0.81541353, 'nIPC': 0.7508042}
# Total Mean: 0.7996364831924438
# 1
# 0
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 46616 genes that are detected 10 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Epoch 203/1000:  20%|█████████████████████                                                                                   | 203/1000 [07:47<30:34,  2.30s/it, v_num=1, elbo_train=3.09e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 30904624.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.98s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:07<00:00,  1.20it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.5037616987253414, ('Blood progenitors 2', 'Erythroid1'): 0.7562537871235822, ('Erythroid1', 'Erythroid2'): 0.8122903186412912, ('Erythroid2', 'Erythroid3'): 0.7652182383815512}
# Total Mean: 0.7093810107179415
# # In-cluster Coherence
# {'Blood progenitors 1': 0.91669184, 'Blood progenitors 2': 0.94388455, 'Erythroid1': 0.9306036, 'Erythroid2': 0.9403107, 'Erythroid3': 0.9717254}
# Total Mean: 0.9406431913375854
# 1
# 0
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 6962 genes that are detected 10 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 453 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 11
# Maximal Number of Modules: 12
# Epoch 135/1000:  14%|██████████████                                                                                          | 135/1000 [03:34<22:56,  1.59s/it, v_num=1, elbo_train=1.49e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 14922016.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.52s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.77it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.515059269204883, ('HSC_1', 'HSC_2'): -0.30772647802883657, ('Ery_1', 'Ery_2'): 0.7239900847930818}
# Total Mean: 0.31044095865637605
# # In-cluster Coherence
# {'CLP': 0.59730834, 'DCs': 0.5322616, 'Ery_1': 0.88995856, 'Ery_2': 0.85885125, 'HSC_1': 0.8597408, 'HSC_2': 0.84598225, 'Mega': 0.90812415, 'Mono_1': 0.86661035, 'Mono_2': 0.8446974, 'Precursors': 0.8321557}
# Total Mean: 0.8035690188407898
# 1
# 1
# 2
# Keeping at most 1000000 cells per cluster
# Filtered out 20300 genes that are detected 20 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 127/1000:  13%|█████████████▏                                                                                          | 127/1000 [01:13<08:25,  1.73it/s, v_num=1, elbo_train=2.93e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 2921413.250. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.46s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:01<00:00,  8.49it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): 0.857616447725756, ('progenitors', 'activating'): 0.7921733812582856}
# Total Mean: 0.8248949144920208
# # In-cluster Coherence
# {'B cell lineage': 0.69511485, 'activating': 0.9491353, 'dividing': 0.94887614, 'macrophages': 0.88905954, 'progenitors': 0.92416054}
# Total Mean: 0.8812692761421204
# 1
# 1
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 20801 genes that are detected 20 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 188/1000:  19%|███████████████████▌                                                                                    | 188/1000 [03:34<15:27,  1.14s/it, v_num=1, elbo_train=1.15e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 11455447.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.29s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.54it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): -0.5004166253771228, ('Pre-endocrine', 'Alpha'): -0.7124195422965094, ('Pre-endocrine', 'Beta'): -0.747465656480362, ('Pre-endocrine', 'Delta'): -0.3175665796547612, ('Pre-endocrine', 'Epsilon'): -0.22872028220705973}
# Total Mean: -0.501317737203163
# # In-cluster Coherence
# {'Alpha': 0.952226, 'Beta': 0.94481516, 'Delta': 0.9330147, 'Ductal': 0.9513388, 'Epsilon': 0.9262955, 'Ngn3 high EP': 0.8984942, 'Ngn3 low EP': 0.83840984, 'Pre-endocrine': 0.9384504}
# Total Mean: 0.9228805303573608
# 1
# 1
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 10340 genes that are detected 20 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 507 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 14
# Maximal Number of Modules: 16
# Epoch 124/1000:  12%|████████████▉                                                                                           | 124/1000 [01:53<13:20,  1.09it/s, v_num=1, elbo_train=6.98e+6]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 6973631.500. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.34s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.03it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.4634608843866426, ('Neuroblast', 'Granule immature'): -0.10151037305146647, ('Granule immature', 'Granule mature'): 0.275890282335673, ('Radial Glia-like', 'Astrocytes'): 0.5235975984932828, ('OPC', 'OL'): 0.917604343943486}
# Total Mean: 0.23042419346686654
# # In-cluster Coherence
# {'Astrocytes': 0.8910961, 'Cajal Retzius': 0.89823294, 'Cck-Tox': 0.8912772, 'Endothelial': 0.78337324, 'GABA': 0.7912957, 'Granule immature': 0.8132094, 'Granule mature': 0.8219544, 'Microglia': 0.9611719, 'Mossy': 0.7237666, 'Neuroblast': 0.6496877, 'OL': 0.9230259, 'OPC': 0.8676167, 'Radial Glia-like': 0.84777033, 'nIPC': 0.6880078}
# Total Mean: 0.825106143951416
# 1
# 1
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 47456 genes that are detected 20 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Epoch 227/1000:  23%|███████████████████████▊                                                                                 | 227/1000 [08:44<29:44,  2.31s/it, v_num=1, elbo_train=3.3e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 32962378.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.86s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:07<00:00,  1.20it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): -0.5937278706131637, ('Blood progenitors 2', 'Erythroid1'): -0.5932317087978184, ('Erythroid1', 'Erythroid2'): -0.8068046449705917, ('Erythroid2', 'Erythroid3'): -0.7640176044113178}
# Total Mean: -0.6894454571982229
# # In-cluster Coherence
# {'Blood progenitors 1': 0.9609535, 'Blood progenitors 2': 0.92627746, 'Erythroid1': 0.95994335, 'Erythroid2': 0.94264525, 'Erythroid3': 0.8821764}
# Total Mean: 0.9343992471694946
# 1
# 1
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 7837 genes that are detected 20 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 435 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 10
# Maximal Number of Modules: 11
# Epoch 184/1000:  18%|███████████████████▏                                                                                    | 184/1000 [04:45<21:06,  1.55s/it, v_num=1, elbo_train=1.62e+7]
# Monitored metric elbo_train did not improve in the last 5 records. Best score: 16227963.000. Signaling Trainer to stop.
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.99s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:04<00:00,  1.85it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.5486252379505221, ('HSC_1', 'HSC_2'): -0.23896759270407417, ('Ery_1', 'Ery_2'): 0.7329018144476246}
# Total Mean: 0.3475198198980241
# # In-cluster Coherence
# {'CLP': 0.63310665, 'DCs': 0.836498, 'Ery_1': 0.85886204, 'Ery_2': 0.90169793, 'HSC_1': 0.76365834, 'HSC_2': 0.7232154, 'Mega': 0.8931363, 'Mono_1': 0.8264526, 'Mono_2': 0.83405596, 'Precursors': 0.70985144}
# Total Mean: 0.7980534434318542
