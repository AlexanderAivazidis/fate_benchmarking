# %%
import os
os.chdir('..')
os.chdir('..')
import scvelo as scv
import scanpy as sc
import cell2fate as c2f
import pickle as pickle
from eval_utils import cross_boundary_correctness
from datetime import datetime
import pandas as pd
import numpy as np
from os.path import exists
import matplotlib.pyplot as plt
import torch
import unitvelo as utv
method = 'Cell2fateDynamicalModelLambda1_600epochs_10samples'
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'
datasets = ['Pancreas_with_cc',  'DentateGyrus' , 'MouseBoneMarrow', 'MouseErythroid', 'HumanBoneMarrow']
n_genes_list = np.array((2000, 3000))
n_counts_list = np.array((10, 20))

for i in range(len(n_genes_list)):
    for j in range(len(n_counts_list)):
        for k in (3,0,1,2,4):
            print(i)
            print(j)
            print(k)
            dataset = datasets[k]
            n_genes = n_genes_list[i]
            min_counts = n_counts_list[j]
            model_index = str(i) + '-' + str(j) + '-' + str(k)
            save_name = method + '_'
            if exists(save_dir + save_name + '_CBDC_fullBenchmark.csv'):
                tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
                if model_index in tab.index:
                    continue
            adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
            adata = c2f.utils.get_training_data(adata, cells_per_cluster = 10**6, cluster_column = 'clusters',
                                            remove_clusters = [], min_shared_counts = min_counts, n_var_genes= n_genes)
            c2f.Cell2fate_DynamicalModel.setup_anndata(adata, spliced_label='spliced', unspliced_label='unspliced')    
            n_modules = c2f.utils.get_max_modules(adata)
            mod = c2f.Cell2fate_DynamicalModel(adata,
                                               n_modules = n_modules,
                                               activation_rate_hyp_prior={"mean_hyp_prior_mean": 1., "mean_hyp_prior_sd": 0.33,
                                               "sd_hyp_prior_mean": 0.33, "sd_hyp_prior_sd": 0.1},)   
            mod.train(max_epochs = 600)
            sample_kwarg = {"num_samples": 10, "batch_size" : adata.n_obs,
                 "use_gpu" : True, 'return_samples': False}
            adata = mod.export_posterior(adata, sample_kwargs = sample_kwarg)
            mod.compute_and_plot_total_velocity_scvelo(adata, save = False, delete = False)
            # Calculate performance metrics:
            file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
            ground_truth = pickle.load(file)
            metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
            cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                        for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
            if exists(save_dir + save_name + '_CBDC_fullBenchmark.csv'):
                tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
            else:
                c_names = ['CBDC']
                tab = pd.DataFrame(columns = c_names)
            tab.loc[model_index, 'CBDC'] = np.mean(cb_score)
            tab.to_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv')
tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
tab.loc['AVERAGE', 'CBDC'] = np.mean(tab['CBDC'])
tab.to_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv')
# Out:
# Global seed set to 0
# (Running UniTVelo 0.2.5)
# 2023-10-30 09:41:40
# 0
# 0
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 46616 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Epoch 600/600: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [38:28<00:00,  3.85s/it, v_num=1, elbo_train=2.18e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.60s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.77it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.0925193056410415, ('Blood progenitors 2', 'Erythroid1'): 0.6284994677878514, ('Erythroid1', 'Erythroid2'): 0.8042263415757254, ('Erythroid2', 'Erythroid3'): 0.7997523029864151}
# Total Mean: 0.5812493544977584
# # In-cluster Coherence
# {'Blood progenitors 1': 0.8298902, 'Blood progenitors 2': 0.8654342, 'Erythroid1': 0.932614, 'Erythroid2': 0.9041714, 'Erythroid3': 0.9659915}
# Total Mean: 0.8996202349662781
# 0
# 0
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 19641 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 600/600: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [13:23<00:00,  1.34s/it, v_num=1, elbo_train=6.93e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.51s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  4.48it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): -0.1632341964798107, ('Pre-endocrine', 'Alpha'): -0.7225924772999718, ('Pre-endocrine', 'Beta'): -0.6443870034697309, ('Pre-endocrine', 'Delta'): -0.4548110735354701, ('Pre-endocrine', 'Epsilon'): 0.04530443437043992}
# Total Mean: -0.38794406328290865
# # In-cluster Coherence
# {'Alpha': 0.9573007, 'Beta': 0.8696, 'Delta': 0.8685468, 'Ductal': 0.9872207, 'Epsilon': 0.9322783, 'Ngn3 high EP': 0.8933057, 'Ngn3 low EP': 0.96196944, 'Pre-endocrine': 0.89653397}
# Total Mean: 0.9208444356918335
# 0
# 0
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 9174 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 368 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 14
# Maximal Number of Modules: 16
# Epoch 600/600: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [12:34<00:00,  1.26s/it, v_num=1, elbo_train=3.86e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.14s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:01<00:00,  5.74it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.45240883600561527, ('Neuroblast', 'Granule immature'): 0.5799594888680625, ('Granule immature', 'Granule mature'): 0.08991425590595295, ('Radial Glia-like', 'Astrocytes'): 0.023954319591071572, ('OPC', 'OL'): 0.24373339474846273}
# Total Mean: 0.277994059023833
# # In-cluster Coherence
# {'Astrocytes': 0.730075, 'Cajal Retzius': 0.4741785, 'Cck-Tox': 0.8373101, 'Endothelial': 0.63203955, 'GABA': 0.7625694, 'Granule immature': 0.89826614, 'Granule mature': 0.97810113, 'Microglia': 0.9662652, 'Mossy': 0.74576724, 'Neuroblast': 0.8605052, 'OL': 0.7287913, 'OPC': 0.6415602, 'Radial Glia-like': 0.80340713, 'nIPC': 0.760172}
# Total Mean: 0.7727862596511841
# 0
# 0
# 2
# Keeping at most 1000000 cells per cluster
# Filtered out 19601 genes that are detected 10 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 600/600: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [11:15<00:00,  1.13s/it, v_num=1, elbo_train=3.7e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.78s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:01<00:00,  6.98it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.42087398041913004, ('progenitors', 'activating'): -0.7770248399274143}
# Total Mean: -0.5989494101732722
# # In-cluster Coherence
# {'B cell lineage': 0.7548792, 'activating': 0.84949124, 'dividing': 0.8081317, 'macrophages': 0.6961064, 'progenitors': 0.8628582}
# Total Mean: 0.7942932844161987
# 0
# 0
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 6962 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 312 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 10
# Maximal Number of Modules: 11
# Epoch 600/600: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [21:44<00:00,  2.17s/it, v_num=1, elbo_train=9.84e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.37s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.56it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): -0.5674337383407289, ('HSC_1', 'HSC_2'): 0.28606862150765433, ('Ery_1', 'Ery_2'): -0.7266143424164768}
# Total Mean: -0.33599315308318384
# # In-cluster Coherence
# {'CLP': 0.72637504, 'DCs': 0.9416121, 'Ery_1': 0.7749705, 'Ery_2': 0.9273418, 'HSC_1': 0.7709131, 'HSC_2': 0.67498106, 'Mega': 0.48953667, 'Mono_1': 0.8272477, 'Mono_2': 0.8557634, 'Precursors': 0.7493264}
# Total Mean: 0.7738067507743835
# 0
# 1
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 47456 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Sampling local variables, batch:   0%|                                                                                                                                                                                 | 0/1 [00:00<?, ?it/s]
# KeyboardInterrupt
