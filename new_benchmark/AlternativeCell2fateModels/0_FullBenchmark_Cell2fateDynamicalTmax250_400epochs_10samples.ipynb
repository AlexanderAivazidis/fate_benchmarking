# %%
import os
os.chdir('..')
os.chdir('..')
import scvelo as scv
import scanpy as sc
import cell2fate as c2f
import pickle as pickle
from eval_utils import cross_boundary_correctness
from datetime import datetime
import pandas as pd
import numpy as np
from os.path import exists
import matplotlib.pyplot as plt
import torch
import unitvelo as utv
method = 'Cell2fateDynamicalModelTmax250_400epochs_10samples'
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'
datasets = ['Pancreas_with_cc',  'DentateGyrus' , 'MouseBoneMarrow', 'MouseErythroid', 'HumanBoneMarrow']
n_genes_list = np.array((2000, 3000))
n_counts_list = np.array((10, 20))

for i in range(len(n_genes_list)):
    for j in range(len(n_counts_list)):
        for k in (3,0,1,2,4):
            print(i)
            print(j)
            print(k)
            dataset = datasets[k]
            n_genes = n_genes_list[i]
            min_counts = n_counts_list[j]
            model_index = str(i) + '-' + str(j) + '-' + str(k)
            save_name = method + '_'
            if exists(save_dir + save_name + '_CBDC_fullBenchmark.csv'):
                tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
                if model_index in tab.index:
                    continue
            adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
            adata = c2f.utils.get_training_data(adata, cells_per_cluster = 10**6, cluster_column = 'clusters',
                                            remove_clusters = [], min_shared_counts = min_counts, n_var_genes= n_genes)
            c2f.Cell2fate_DynamicalModel.setup_anndata(adata, spliced_label='spliced', unspliced_label='unspliced')    
            n_modules = c2f.utils.get_max_modules(adata)
            mod = c2f.Cell2fate_DynamicalModel(adata,
                                               n_modules = n_modules,
                                               Tmax_prior={"mean": 250., "sd": 50.})   
            mod.train(max_epochs = 400)
            sample_kwarg = {"num_samples": 10, "batch_size" : adata.n_obs,
                 "use_gpu" : True, 'return_samples': False}
            adata = mod.export_posterior(adata, sample_kwargs = sample_kwarg)
            mod.compute_and_plot_total_velocity_scvelo(adata, save = False, delete = False)
            # Calculate performance metrics:
            file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
            ground_truth = pickle.load(file)
            metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
            cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                        for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
            if exists(save_dir + save_name + '_CBDC_fullBenchmark.csv'):
                tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
            else:
                c_names = ['CBDC']
                tab = pd.DataFrame(columns = c_names)
            tab.loc[model_index, 'CBDC'] = np.mean(cb_score)
            tab.to_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv')
tab = pd.read_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv', index_col = 0)
tab.loc['AVERAGE', 'CBDC'] = np.mean(tab['CBDC'])
tab.to_csv(save_dir + save_name + '_CBDC_fullBenchmark.csv')
# Out:
# Global seed set to 0
# (Running UniTVelo 0.2.5)
# 2023-10-29 13:20:07
# 0
# 0
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 46616 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [15:02<00:00,  2.26s/it, v_num=1, elbo_train=2.19e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.93s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.74it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): -0.8508853615418847, ('Blood progenitors 2', 'Erythroid1'): -0.6964030139991562, ('Erythroid1', 'Erythroid2'): -0.7981265562009965, ('Erythroid2', 'Erythroid3'): -0.7890167690568265}
# Total Mean: -0.7836079251997159
# # In-cluster Coherence
# {'Blood progenitors 1': 0.98449934, 'Blood progenitors 2': 0.9297278, 'Erythroid1': 0.92422014, 'Erythroid2': 0.93502736, 'Erythroid3': 0.8236424}
# Total Mean: 0.9194234013557434
# 0
# 0
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 19641 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [07:23<00:00,  1.11s/it, v_num=1, elbo_train=6.97e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.61s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.58it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): -0.422803110698683, ('Pre-endocrine', 'Alpha'): -0.5974463866863425, ('Pre-endocrine', 'Beta'): -0.6806895183550262, ('Pre-endocrine', 'Delta'): -0.35272093204354427, ('Pre-endocrine', 'Epsilon'): -0.3589666819349324}
# Total Mean: -0.4825253259437057
# # In-cluster Coherence
# {'Alpha': 0.9845398, 'Beta': 0.9839963, 'Delta': 0.98539734, 'Ductal': 0.8894485, 'Epsilon': 0.95778644, 'Ngn3 high EP': 0.8884998, 'Ngn3 low EP': 0.876047, 'Pre-endocrine': 0.94696325}
# Total Mean: 0.9390847682952881
# 0
# 0
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 9174 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 368 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [05:53<00:00,  1.13it/s, v_num=1, elbo_train=3.92e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.96s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  4.37it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.1007123782217036, ('Neuroblast', 'Granule immature'): 0.39464404168930906, ('Granule immature', 'Granule mature'): 0.37914969379226066, ('Radial Glia-like', 'Astrocytes'): -0.20031856108068896, ('OPC', 'OL'): -0.04169752613647676}
# Total Mean: 0.1264980052972215
# # In-cluster Coherence
# {'Astrocytes': 0.6529732, 'Cajal Retzius': 0.31505615, 'Cck-Tox': 0.8666354, 'Endothelial': 0.59792596, 'GABA': 0.7021886, 'Granule immature': 0.90954405, 'Granule mature': 0.9135401, 'Microglia': 0.65544546, 'Mossy': 0.8928242, 'Neuroblast': 0.53410053, 'OL': 0.6366616, 'OPC': 0.49401745, 'Radial Glia-like': 0.66833085, 'nIPC': 0.42678797}
# Total Mean: 0.6618594527244568
# 0
# 0
# 2
# Keeping at most 1000000 cells per cluster
# Filtered out 19601 genes that are detected 10 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [04:31<00:00,  1.47it/s, v_num=1, elbo_train=3.75e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.23s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:01<00:00,  5.95it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): 0.7028845420373452, ('progenitors', 'activating'): 0.8132626502823821}
# Total Mean: 0.7580735961598637
# # In-cluster Coherence
# {'B cell lineage': 0.78549594, 'activating': 0.9113649, 'dividing': 0.9114513, 'macrophages': 0.81191635, 'progenitors': 0.9018}
# Total Mean: 0.8644057512283325
# 0
# 0
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 6962 genes that are detected 10 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 312 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 10
# Maximal Number of Modules: 11
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [10:22<00:00,  1.56s/it, v_num=1, elbo_train=9.84e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.98s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.66it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.27608379476087636, ('HSC_1', 'HSC_2'): 0.3704669150617223, ('Ery_1', 'Ery_2'): 0.5660796988833898}
# Total Mean: 0.4042101362353295
# # In-cluster Coherence
# {'CLP': 0.86673427, 'DCs': 0.670779, 'Ery_1': 0.7734076, 'Ery_2': 0.90715873, 'HSC_1': 0.8379137, 'HSC_2': 0.7798313, 'Mega': 0.8631631, 'Mono_1': 0.7649538, 'Mono_2': 0.7094533, 'Precursors': 0.66907835}
# Total Mean: 0.7842472791671753
# 0
# 1
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 47456 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [15:46<00:00,  2.37s/it, v_num=1, elbo_train=2.35e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.94s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.74it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): -0.6519039824051983, ('Blood progenitors 2', 'Erythroid1'): -0.6920743166998252, ('Erythroid1', 'Erythroid2'): -0.8001155788158704, ('Erythroid2', 'Erythroid3'): -0.8034542860410469}
# Total Mean: -0.7368870409904852
# # In-cluster Coherence
# {'Blood progenitors 1': 0.9925557, 'Blood progenitors 2': 0.97885394, 'Erythroid1': 0.9734716, 'Erythroid2': 0.9540588, 'Erythroid3': 0.9651108}
# Total Mean: 0.9728101491928101
# 0
# 1
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 20801 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [07:47<00:00,  1.17s/it, v_num=1, elbo_train=7.62e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.68s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.58it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.7398332970497914, ('Pre-endocrine', 'Alpha'): 0.44326415643130995, ('Pre-endocrine', 'Beta'): 0.6885498775806617, ('Pre-endocrine', 'Delta'): 0.39378654316425793, ('Pre-endocrine', 'Epsilon'): 0.42070832539892444}
# Total Mean: 0.5372284399249891
# # In-cluster Coherence
# {'Alpha': 0.9916519, 'Beta': 0.9915413, 'Delta': 0.9866517, 'Ductal': 0.9832172, 'Epsilon': 0.98387617, 'Ngn3 high EP': 0.9537785, 'Ngn3 low EP': 0.9792761, 'Pre-endocrine': 0.97720367}
# Total Mean: 0.9808995723724365
# 0
# 1
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 10340 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 327 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 14
# Maximal Number of Modules: 16
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [06:06<00:00,  1.09it/s, v_num=1, elbo_train=4.61e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  4.23it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.5799562530083836, ('Neuroblast', 'Granule immature'): 0.6423652914546412, ('Granule immature', 'Granule mature'): 0.18081344030231028, ('Radial Glia-like', 'Astrocytes'): -0.013493833063440807, ('OPC', 'OL'): 0.6569346086813502}
# Total Mean: 0.4093151520766489
# # In-cluster Coherence
# {'Astrocytes': 0.6960442, 'Cajal Retzius': 0.36293784, 'Cck-Tox': 0.8217683, 'Endothelial': 0.57403237, 'GABA': 0.8338035, 'Granule immature': 0.8685029, 'Granule mature': 0.86239994, 'Microglia': 0.6011862, 'Mossy': 0.8673585, 'Neuroblast': 0.81568694, 'OL': 0.6917539, 'OPC': 0.569916, 'Radial Glia-like': 0.6223139, 'nIPC': 0.61315525}
# Total Mean: 0.7000613808631897
# 0
# 1
# 2
# Keeping at most 1000000 cells per cluster
# Filtered out 20300 genes that are detected 20 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [04:24<00:00,  1.51it/s, v_num=1, elbo_train=2.87e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.49s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 12.25it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.7147050487813333, ('progenitors', 'activating'): -0.7177693570089592}
# Total Mean: -0.7162372028951463
# # In-cluster Coherence
# {'B cell lineage': 0.83537483, 'activating': 0.9346639, 'dividing': 0.8414922, 'macrophages': 0.87210864, 'progenitors': 0.88604206}
# Total Mean: 0.8739362955093384
# 0
# 1
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 7837 genes that are detected 20 counts (shared).
# Extracted 2000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 303 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 10
# Maximal Number of Modules: 11
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [10:20<00:00,  1.55s/it, v_num=1, elbo_train=1.09e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.02s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.65it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.2552318089981341, ('HSC_1', 'HSC_2'): 0.2884391646586286, ('Ery_1', 'Ery_2'): 0.5836210560338011}
# Total Mean: 0.3757640098968546
# # In-cluster Coherence
# {'CLP': 0.923203, 'DCs': 0.8589939, 'Ery_1': 0.8906317, 'Ery_2': 0.85010064, 'HSC_1': 0.7946524, 'HSC_2': 0.73117983, 'Mega': 0.851465, 'Mono_1': 0.8145442, 'Mono_2': 0.88463205, 'Precursors': 0.6359008}
# Total Mean: 0.8235303163528442
# 1
# 0
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 46616 genes that are detected 10 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [16:28<00:00,  2.47s/it, v_num=1, elbo_train=3.08e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.59s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:07<00:00,  1.19it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.3200875166074649, ('Blood progenitors 2', 'Erythroid1'): 0.7290849247877864, ('Erythroid1', 'Erythroid2'): 0.8170070178260724, ('Erythroid2', 'Erythroid3'): 0.8081405279295851}
# Total Mean: 0.6685799967877272
# # In-cluster Coherence
# {'Blood progenitors 1': 0.9117328, 'Blood progenitors 2': 0.93915856, 'Erythroid1': 0.96691483, 'Erythroid2': 0.96438503, 'Erythroid3': 0.9921626}
# Total Mean: 0.9548708200454712
# 1
# 0
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 19641 genes that are detected 10 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [08:08<00:00,  1.22s/it, v_num=1, elbo_train=1.04e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.31s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.50it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): -0.4848123327318878, ('Pre-endocrine', 'Alpha'): -0.6281918238161652, ('Pre-endocrine', 'Beta'): -0.7478748025188404, ('Pre-endocrine', 'Delta'): -0.35356065083579535, ('Pre-endocrine', 'Epsilon'): -0.4123700082208028}
# Total Mean: -0.5253619236246984
# # In-cluster Coherence
# {'Alpha': 0.9586936, 'Beta': 0.9588867, 'Delta': 0.9465669, 'Ductal': 0.9546734, 'Epsilon': 0.9520675, 'Ngn3 high EP': 0.87956226, 'Ngn3 low EP': 0.92176074, 'Pre-endocrine': 0.97056705}
# Total Mean: 0.9428472518920898
# 1
# 0
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 9174 genes that are detected 10 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 524 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [06:08<00:00,  1.09it/s, v_num=1, elbo_train=5.96e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.47s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.09it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.14159615542549386, ('Neuroblast', 'Granule immature'): 0.6501398988382665, ('Granule immature', 'Granule mature'): 0.08518973322629286, ('Radial Glia-like', 'Astrocytes'): -0.05658342698412686, ('OPC', 'OL'): -0.4844754299050228}
# Total Mean: 0.010534923949983167
# # In-cluster Coherence
# {'Astrocytes': 0.68564886, 'Cajal Retzius': 0.31158432, 'Cck-Tox': 0.9455955, 'Endothelial': 0.66568667, 'GABA': 0.84416604, 'Granule immature': 0.9254892, 'Granule mature': 0.9367106, 'Microglia': 0.7545751, 'Mossy': 0.9045006, 'Neuroblast': 0.7020571, 'OL': 0.7019646, 'OPC': 0.54316854, 'Radial Glia-like': 0.6653123, 'nIPC': 0.3782238}
# Total Mean: 0.7117629647254944
# 1
# 0
# 2
# Keeping at most 1000000 cells per cluster
# Filtered out 19601 genes that are detected 10 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [04:31<00:00,  1.48it/s, v_num=1, elbo_train=3.73e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.24s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:01<00:00,  5.93it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.614418118267522, ('progenitors', 'activating'): -0.7091640431470596}
# Total Mean: -0.6617910807072909
# # In-cluster Coherence
# {'B cell lineage': 0.84934443, 'activating': 0.9181058, 'dividing': 0.89279217, 'macrophages': 0.8805609, 'progenitors': 0.7627299}
# Total Mean: 0.860706627368927
# 1
# 0
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 6962 genes that are detected 10 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 453 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 11
# Maximal Number of Modules: 12
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [11:15<00:00,  1.69s/it, v_num=1, elbo_train=1.48e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.61s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.75it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.31499218880480884, ('HSC_1', 'HSC_2'): 0.39684617400174177, ('Ery_1', 'Ery_2'): 0.5884661748889256}
# Total Mean: 0.43343484589849207
# # In-cluster Coherence
# {'CLP': 0.78117675, 'DCs': 0.81853664, 'Ery_1': 0.739321, 'Ery_2': 0.7590469, 'HSC_1': 0.80415106, 'HSC_2': 0.7141117, 'Mega': 0.72608566, 'Mono_1': 0.6080863, 'Mono_2': 0.75110805, 'Precursors': 0.59361756}
# Total Mean: 0.7295241355895996
# 1
# 1
# 3
# Keeping at most 1000000 cells per cluster
# Filtered out 47456 genes that are detected 20 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 9
# Maximal Number of Modules: 10
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [16:31<00:00,  2.48s/it, v_num=1, elbo_train=3.28e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.29s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:07<00:00,  1.19it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): -0.8782703434637746, ('Blood progenitors 2', 'Erythroid1'): -0.6742083967101347, ('Erythroid1', 'Erythroid2'): -0.7932141004085449, ('Erythroid2', 'Erythroid3'): -0.7900549179756063}
# Total Mean: -0.783936939639515
# # In-cluster Coherence
# {'Blood progenitors 1': 0.978061, 'Blood progenitors 2': 0.94517416, 'Erythroid1': 0.97308433, 'Erythroid2': 0.96952945, 'Erythroid3': 0.8276256}
# Total Mean: 0.9386948347091675
# 1
# 1
# 0
# Keeping at most 1000000 cells per cluster
# Filtered out 20801 genes that are detected 20 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 13
# Maximal Number of Modules: 14
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [08:08<00:00,  1.22s/it, v_num=1, elbo_train=1.14e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.26s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.51it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): -0.2765927337429649, ('Pre-endocrine', 'Alpha'): -0.656907486554966, ('Pre-endocrine', 'Beta'): -0.7669401122951445, ('Pre-endocrine', 'Delta'): -0.3938450200477461, ('Pre-endocrine', 'Epsilon'): -0.16434521798272428}
# Total Mean: -0.4517261141247091
# # In-cluster Coherence
# {'Alpha': 0.939734, 'Beta': 0.93591493, 'Delta': 0.93576527, 'Ductal': 0.92773646, 'Epsilon': 0.9071778, 'Ngn3 high EP': 0.82598865, 'Ngn3 low EP': 0.8856671, 'Pre-endocrine': 0.9194645}
# Total Mean: 0.9096810817718506
# 1
# 1
# 1
# Keeping at most 1000000 cells per cluster
# Filtered out 10340 genes that are detected 20 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 507 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 14
# Maximal Number of Modules: 16
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [06:23<00:00,  1.04it/s, v_num=1, elbo_train=6.83e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.71s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.96it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.8034202179094434, ('Neuroblast', 'Granule immature'): 0.6056467989950354, ('Granule immature', 'Granule mature'): 0.050179847908943, ('Radial Glia-like', 'Astrocytes'): -0.5428378779478298, ('OPC', 'OL'): -0.38963008104433866}
# Total Mean: 0.10535578116425066
# # In-cluster Coherence
# {'Astrocytes': 0.6834668, 'Cajal Retzius': 0.76716506, 'Cck-Tox': 0.92314345, 'Endothelial': 0.61529666, 'GABA': 0.8995008, 'Granule immature': 0.91173786, 'Granule mature': 0.9176058, 'Microglia': 0.73617166, 'Mossy': 0.9141454, 'Neuroblast': 0.85605764, 'OL': 0.62355894, 'OPC': 0.43639523, 'Radial Glia-like': 0.6325857, 'nIPC': 0.83680177}
# Total Mean: 0.7681165933609009
# 1
# 1
# 2
# Keeping at most 1000000 cells per cluster
# Filtered out 20300 genes that are detected 20 counts (shared).
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 8
# Maximal Number of Modules: 9
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [04:25<00:00,  1.51it/s, v_num=1, elbo_train=2.87e+6]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.45s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 12.64it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.6471664441255136, ('progenitors', 'activating'): -0.6516735310565409}
# Total Mean: -0.6494199875910273
# # In-cluster Coherence
# {'B cell lineage': 0.81391466, 'activating': 0.9237657, 'dividing': 0.86600995, 'macrophages': 0.8779364, 'progenitors': 0.8785314}
# Total Mean: 0.872031569480896
# 1
# 1
# 4
# Keeping at most 1000000 cells per cluster
# Filtered out 7837 genes that are detected 20 counts (shared).
# Extracted 3000 highly variable genes.
# Leiden clustering ...
# WARNING: You’re trying to run this on 435 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 10
# Maximal Number of Modules: 11
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [10:46<00:00,  1.62s/it, v_num=1, elbo_train=1.62e+7]
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.43s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:04<00:00,  1.82it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.6224240722146801, ('HSC_1', 'HSC_2'): 0.07028469665219202, ('Ery_1', 'Ery_2'): 0.6025685958339508}
# Total Mean: 0.43175912156694096
# # In-cluster Coherence
# {'CLP': 0.89778024, 'DCs': 0.81167, 'Ery_1': 0.74376667, 'Ery_2': 0.8006796, 'HSC_1': 0.798776, 'HSC_2': 0.6721181, 'Mega': 0.7862957, 'Mono_1': 0.7782176, 'Mono_2': 0.79560727, 'Precursors': 0.6255229}
# Total Mean: 0.7710434198379517
