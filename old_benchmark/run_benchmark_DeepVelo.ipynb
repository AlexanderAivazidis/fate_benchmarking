# %%
import anndata
import numpy as np
import scvelo as scv
import scanpy as sc
import sys
import torch
import os.path
import deepvelo as dv
import pickle as pickle
import matplotlib.pyplot as plt
import pandas as pd
import unitvelo as utv
from os.path import exists
method = 'DeepVelo'
# Out:
# (Running UniTVelo 0.2.5)
# 2023-05-16 14:55:44

# %%
datasets = ['Pancreas_with_cc', 'DentateGyrus' , 'MouseBoneMarrow', 'MouseErythroid', 'HumanBoneMarrow', 'HumanDevelopingBrain']
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'

# %%
for dataset in datasets:
    print(dataset)
    adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
    scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=3000)
    scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
    trainer = dv.train(adata, dv.Constants.default_configs)
    scv.pp.neighbors(adata)
    scv.tl.velocity_graph(adata, vkey = 'velocity')
    scv.tl.velocity_embedding(adata, vkey = 'velocity')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_DeepVelo.svg')
    # Calculate performance metrics:
    file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
    ground_truth = pickle.load(file)
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_CBDC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_CBDC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(metrics['Cross-Boundary Direction Correctness (A->B)'].keys()) + ['Mean'],
                 index = [method])
    cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
    tab.loc[method,:] = cb_score + [np.mean(cb_score)]
    tab.to_csv(save_dir + dataset + '_CBDC_scores.csv')
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_ICC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_ICC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(np.unique(np.concatenate(ground_truth))) + ['Mean'],
                 index = [method])
    icc_score = [np.mean(metrics['In-cluster Coherence'][x]) for x in np.unique(np.concatenate(ground_truth))]
    tab.loc[method,:] = icc_score + [np.mean(icc_score)]
    tab.to_csv(save_dir + dataset + '_ICC_scores.csv')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_' + method + '.svg')
# Out:
# Pancreas_with_cc
# Filtered out 20801 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:11) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Config Warning: Set to use GPU, but GPU version of DGL is not installed. Reset to use CPU instead.
# Warning: logging configuration file is not found in logger/logger_config.json.
# building graph
# INFO:train:Beginning training of DeepVelo_Base ...
# velo data shape: torch.Size([3696, 3000])
# /nfs/team283/aa16/software/miniconda3/lib/python3.9/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /nfs/team283/aa16/software/miniconda3/lib/python3.9/site-packages/torch/utils/tensorboard/__init__.py:6: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   ) < LooseVersion("1.15"):
# INFO:trainer:    epoch          : 1
# INFO:trainer:    time:          : 10.626794576644897
# INFO:trainer:    loss           : 98578.53125
# INFO:trainer:    mse            : 2.556227922439575
# INFO:trainer:    epoch          : 2
# INFO:trainer:    time:          : 10.040715217590332
# INFO:trainer:    loss           : 18010.15625
# INFO:trainer:    mse            : 1.5266255140304565
# INFO:trainer:    epoch          : 3
# INFO:trainer:    time:          : 9.94972562789917
# INFO:trainer:    loss           : 9833.1630859375
# INFO:trainer:    mse            : 1.5814744234085083
# INFO:trainer:    epoch          : 4
# INFO:trainer:    time:          : 9.874797105789185
# INFO:trainer:    loss           : 6979.2314453125
# INFO:trainer:    mse            : 1.92239248752594
# INFO:trainer:    epoch          : 5
# INFO:trainer:    time:          : 10.059625625610352
# INFO:trainer:    loss           : 5580.23046875
# INFO:trainer:    mse            : 1.8335015773773193
# INFO:trainer:    epoch          : 6
# INFO:trainer:    time:          : 9.841925621032715
# INFO:trainer:    loss           : 4743.650390625
# INFO:trainer:    mse            : 1.8120900392532349
# INFO:trainer:    epoch          : 7
# INFO:trainer:    time:          : 9.923316717147827
# INFO:trainer:    loss           : 4231.99462890625
# INFO:trainer:    mse            : 1.8693063259124756
# INFO:trainer:    epoch          : 8
# INFO:trainer:    time:          : 10.100486755371094
# INFO:trainer:    loss           : 3846.919677734375
# INFO:trainer:    mse            : 1.6927350759506226
# INFO:trainer:    epoch          : 9
# INFO:trainer:    time:          : 10.082380056381226
# INFO:trainer:    loss           : 3567.511474609375
# INFO:trainer:    mse            : 1.6884067058563232
# INFO:trainer:    epoch          : 10
# INFO:trainer:    time:          : 10.078426361083984
# INFO:trainer:    loss           : 3362.182373046875
# INFO:trainer:    mse            : 1.4952465295791626
# INFO:trainer:    epoch          : 11
# INFO:trainer:    time:          : 9.942086219787598
# INFO:trainer:    loss           : 3202.06884765625
# INFO:trainer:    mse            : 1.530828833580017
# INFO:trainer:    epoch          : 12
# INFO:trainer:    time:          : 9.856013298034668
# INFO:trainer:    loss           : 3080.245849609375
# INFO:trainer:    mse            : 1.449488639831543
# INFO:trainer:    epoch          : 13
# INFO:trainer:    time:          : 10.085681200027466
# INFO:trainer:    loss           : 2981.967041015625
# INFO:trainer:    mse            : 1.4226322174072266
# INFO:trainer:    epoch          : 14
# INFO:trainer:    time:          : 10.089415550231934
# INFO:trainer:    loss           : 2893.532470703125
# INFO:trainer:    mse            : 1.279060959815979
# INFO:trainer:    epoch          : 15
# INFO:trainer:    time:          : 10.192854404449463
# INFO:trainer:    loss           : 2821.4033203125
# INFO:trainer:    mse            : 1.2200055122375488
# INFO:trainer:    epoch          : 16
# INFO:trainer:    time:          : 10.206044435501099
# INFO:trainer:    loss           : 2760.658203125
# INFO:trainer:    mse            : 1.1569980382919312
# INFO:trainer:    epoch          : 17
# INFO:trainer:    time:          : 10.19978952407837
# INFO:trainer:    loss           : 2720.713134765625
# INFO:trainer:    mse            : 1.1209685802459717
# INFO:trainer:    epoch          : 18
# INFO:trainer:    time:          : 9.886521100997925
# INFO:trainer:    loss           : 2665.6396484375
# INFO:trainer:    mse            : 1.1101878881454468
# INFO:trainer:    epoch          : 19
# INFO:trainer:    time:          : 9.95791745185852
# INFO:trainer:    loss           : 2632.837890625
# INFO:trainer:    mse            : 1.0778512954711914
# INFO:trainer:    epoch          : 20
# INFO:trainer:    time:          : 9.913798570632935
# INFO:trainer:    loss           : 2598.6083984375
# INFO:trainer:    mse            : 0.9857248663902283
# INFO:trainer:    epoch          : 21
# INFO:trainer:    time:          : 10.152320861816406
# INFO:trainer:    loss           : 2570.147705078125
# INFO:trainer:    mse            : 0.915824830532074
# INFO:trainer:    epoch          : 22
# INFO:trainer:    time:          : 10.08645486831665
# INFO:trainer:    loss           : 2535.32080078125
# INFO:trainer:    mse            : 0.8616043329238892
# INFO:trainer:    epoch          : 23
# INFO:trainer:    time:          : 9.984479665756226
# INFO:trainer:    loss           : 2506.0595703125
# INFO:trainer:    mse            : 0.8181087374687195
# INFO:trainer:    epoch          : 24
# INFO:trainer:    time:          : 9.888510704040527
# INFO:trainer:    loss           : 2481.45068359375
# INFO:trainer:    mse            : 0.7805532813072205
# INFO:trainer:    epoch          : 25
# INFO:trainer:    time:          : 9.9017915725708
# INFO:trainer:    loss           : 2464.811767578125
# INFO:trainer:    mse            : 0.7703129649162292
# INFO:trainer:    epoch          : 26
# INFO:trainer:    time:          : 9.877963066101074
# INFO:trainer:    loss           : 2445.18115234375
# INFO:trainer:    mse            : 0.7236897945404053
# INFO:trainer:    epoch          : 27
# INFO:trainer:    time:          : 9.910263776779175
# INFO:trainer:    loss           : 2418.650390625
# INFO:trainer:    mse            : 0.7200751900672913
# INFO:trainer:    epoch          : 28
# INFO:trainer:    time:          : 9.89862608909607
# INFO:trainer:    loss           : 2402.835693359375
# INFO:trainer:    mse            : 0.7056005001068115
# INFO:trainer:    epoch          : 29
# INFO:trainer:    time:          : 9.89406943321228
# INFO:trainer:    loss           : 2383.256103515625
# INFO:trainer:    mse            : 0.6636335849761963
# INFO:trainer:    epoch          : 30
# INFO:trainer:    time:          : 9.905909538269043
# INFO:trainer:    loss           : 2366.97119140625
# INFO:trainer:    mse            : 0.596975564956665
# INFO:trainer:    epoch          : 31
# INFO:trainer:    time:          : 9.930442810058594
# INFO:trainer:    loss           : 2344.45849609375
# INFO:trainer:    mse            : 0.6086918115615845
# INFO:trainer:    epoch          : 32
# INFO:trainer:    time:          : 9.846100330352783
# INFO:trainer:    loss           : 2333.05224609375
# INFO:trainer:    mse            : 0.5783957242965698
# INFO:trainer:    epoch          : 33
# INFO:trainer:    time:          : 9.900548934936523
# INFO:trainer:    loss           : 2322.11083984375
# INFO:trainer:    mse            : 0.5928357839584351
# INFO:trainer:    epoch          : 34
# INFO:trainer:    time:          : 9.92204475402832
# INFO:trainer:    loss           : 2310.28662109375
# INFO:trainer:    mse            : 0.5867685079574585
# INFO:trainer:    epoch          : 35
# INFO:trainer:    time:          : 9.906739711761475
# INFO:trainer:    loss           : 2296.586181640625
# INFO:trainer:    mse            : 0.5428544878959656
# INFO:trainer:    epoch          : 36
# INFO:trainer:    time:          : 9.801965713500977
# INFO:trainer:    loss           : 2282.22216796875
# INFO:trainer:    mse            : 0.5570364594459534
# INFO:trainer:    epoch          : 37
# INFO:trainer:    time:          : 9.924861907958984
# INFO:trainer:    loss           : 2270.906982421875
# INFO:trainer:    mse            : 0.5404335260391235
# INFO:trainer:    epoch          : 38
# INFO:trainer:    time:          : 9.900749444961548
# INFO:trainer:    loss           : 2256.905517578125
# INFO:trainer:    mse            : 0.530684769153595
# INFO:trainer:    epoch          : 39
# INFO:trainer:    time:          : 10.070940971374512
# INFO:trainer:    loss           : 2251.889892578125
# INFO:trainer:    mse            : 0.530292809009552
# INFO:trainer:    epoch          : 40
# INFO:trainer:    time:          : 10.046666622161865
# INFO:trainer:    loss           : 2238.111572265625
# INFO:trainer:    mse            : 0.5288232564926147
# INFO:trainer:    epoch          : 41
# INFO:trainer:    time:          : 10.01677393913269
# INFO:trainer:    loss           : 2230.870361328125
# INFO:trainer:    mse            : 0.5351672768592834
# INFO:trainer:    epoch          : 42
# INFO:trainer:    time:          : 10.1201012134552
# INFO:trainer:    loss           : 2224.52734375
# INFO:trainer:    mse            : 0.491735577583313
# INFO:trainer:    epoch          : 43
# INFO:trainer:    time:          : 10.051969051361084
# INFO:trainer:    loss           : 2219.3623046875
# INFO:trainer:    mse            : 0.48965513706207275
# INFO:trainer:    epoch          : 44
# INFO:trainer:    time:          : 10.045467376708984
# INFO:trainer:    loss           : 2212.611572265625
# INFO:trainer:    mse            : 0.4926551580429077
# INFO:trainer:    epoch          : 45
# INFO:trainer:    time:          : 10.014889001846313
# INFO:trainer:    loss           : 2202.308349609375
# INFO:trainer:    mse            : 0.49902263283729553
# INFO:trainer:    epoch          : 46
# INFO:trainer:    time:          : 10.278892278671265
# INFO:trainer:    loss           : 2193.9814453125
# INFO:trainer:    mse            : 0.49496251344680786
# INFO:trainer:    epoch          : 47
# INFO:trainer:    time:          : 10.020115375518799
# INFO:trainer:    loss           : 2188.856689453125
# INFO:trainer:    mse            : 0.4937421977519989
# INFO:trainer:    epoch          : 48
# INFO:trainer:    time:          : 10.10468053817749
# INFO:trainer:    loss           : 2184.750732421875
# INFO:trainer:    mse            : 0.49980148673057556
# INFO:trainer:    epoch          : 49
# INFO:trainer:    time:          : 10.039555549621582
# INFO:trainer:    loss           : 2073.707275390625
# INFO:trainer:    mse            : 0.42630037665367126
# INFO:trainer:    epoch          : 85
# INFO:trainer:    time:          : 10.337786674499512
# INFO:trainer:    loss           : 2075.701171875
# INFO:trainer:    mse            : 0.4460844099521637
# INFO:trainer:    epoch          : 86
# INFO:trainer:    time:          : 10.282583236694336
# INFO:trainer:    loss           : 2072.56103515625
# INFO:trainer:    mse            : 0.39354532957077026
# INFO:trainer:    epoch          : 87
# INFO:trainer:    time:          : 10.182904243469238
# INFO:trainer:    loss           : 2073.71142578125
# INFO:trainer:    mse            : 0.4196650981903076
# INFO:trainer:    epoch          : 88
# INFO:trainer:    time:          : 10.309855699539185
# INFO:trainer:    loss           : 2068.3837890625
# INFO:trainer:    mse            : 0.41546183824539185
# INFO:trainer:    epoch          : 89
# INFO:trainer:    time:          : 10.296083688735962
# INFO:trainer:    loss           : 2069.17529296875
# INFO:trainer:    mse            : 0.4080207347869873
# INFO:trainer:    epoch          : 90
# INFO:trainer:    time:          : 10.26360535621643
# INFO:trainer:    loss           : 2061.3251953125
# INFO:trainer:    mse            : 0.411354124546051
# INFO:trainer:    epoch          : 91
# INFO:trainer:    time:          : 10.213676929473877
# INFO:trainer:    loss           : 2069.15576171875
# INFO:trainer:    mse            : 0.41644808650016785
# INFO:trainer:    epoch          : 92
# INFO:trainer:    time:          : 10.339361190795898
# INFO:trainer:    loss           : 2064.906494140625
# INFO:trainer:    mse            : 0.4072343111038208
# INFO:trainer:    epoch          : 93
# INFO:trainer:    time:          : 10.25818133354187
# INFO:trainer:    loss           : 2066.50537109375
# INFO:trainer:    mse            : 0.39670413732528687
# INFO:trainer:    epoch          : 94
# INFO:trainer:    time:          : 10.228156805038452
# INFO:trainer:    loss           : 2063.4443359375
# INFO:trainer:    mse            : 0.44258496165275574
# INFO:trainer:    epoch          : 95
# INFO:trainer:    time:          : 10.234391689300537
# INFO:trainer:    loss           : 2060.35400390625
# INFO:trainer:    mse            : 0.40850692987442017
# INFO:trainer:    epoch          : 96
# INFO:trainer:    time:          : 10.333230257034302
# INFO:trainer:    loss           : 2062.2744140625
# INFO:trainer:    mse            : 0.41616734862327576
# INFO:trainer:    epoch          : 97
# INFO:trainer:    time:          : 10.241650819778442
# INFO:trainer:    loss           : 2057.4013671875
# INFO:trainer:    mse            : 0.40712857246398926
# INFO:trainer:    epoch          : 98
# INFO:trainer:    time:          : 10.265079021453857
# INFO:trainer:    loss           : 2061.523193359375
# INFO:trainer:    mse            : 0.4316595494747162
# INFO:trainer:    epoch          : 99
# INFO:trainer:    time:          : 10.238453149795532
# INFO:trainer:    loss           : 2057.51611328125
# INFO:trainer:    mse            : 0.39869260787963867
# INFO:trainer:    epoch          : 100
# INFO:trainer:    time:          : 10.181151151657104
# INFO:trainer:    loss           : 2054.281005859375
# INFO:trainer:    mse            : 0.4202422499656677
# velo_mat shape: (3696, 3000)
# --> added 'velocity' (adata.layers)
# --> added 'velocity_unspliced' (adata.layers)
# --> added 'cell_specific_beta' (adata.layers)
# --> added 'cell_specific_gamma' (adata.layers)
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/3696 [00:00<?, ?cells/s]
#     finished (0:00:21) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.7638681882592249, ('Pre-endocrine', 'Alpha'): 0.3553044939264237, ('Pre-endocrine', 'Beta'): 0.47253457128227305, ('Pre-endocrine', 'Delta'): -0.24480072462109212, ('Pre-endocrine', 'Epsilon'): -0.4735415508171434}
# Total Mean: 0.17467299560593724
# # In-cluster Coherence
# {'Alpha': 0.87884545, 'Beta': 0.8917102, 'Delta': 0.9379041, 'Ductal': 0.953963, 'Epsilon': 0.82792366, 'Ngn3 high EP': 0.94498867, 'Ngn3 low EP': 0.9526061, 'Pre-endocrine': 0.92413455}
# Total Mean: 0.9140094518661499
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.7638681882592249, ('Pre-endocrine', 'Alpha'): 0.3553044939264237, ('Pre-endocrine', 'Beta'): 0.47253457128227305, ('Pre-endocrine', 'Delta'): -0.24480072462109212, ('Pre-endocrine', 'Epsilon'): -0.4735415508171434}
# Total Mean: 0.17467299560593724
# # In-cluster Coherence
# {'Alpha': 0.87884545, 'Beta': 0.8917102, 'Delta': 0.9379041, 'Ductal': 0.953963, 'Epsilon': 0.82792366, 'Ngn3 high EP': 0.94498867, 'Ngn3 low EP': 0.9526061, 'Pre-endocrine': 0.92413455}
# Total Mean: 0.9140094518661499
# DentateGyrus
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Config Warning: Set to use GPU, but GPU version of DGL is not installed. Reset to use CPU instead.
# Warning: logging configuration file is not found in logger/logger_config.json.
# building graph
# INFO:train:Beginning training of DeepVelo_Base ...
# velo data shape: torch.Size([2930, 3000])
# INFO:trainer:    epoch          : 1
# INFO:trainer:    time:          : 7.987591028213501
# INFO:trainer:    loss           : 98339.65625
# INFO:trainer:    mse            : 0.045380014926195145
# INFO:trainer:    epoch          : 2
# INFO:trainer:    time:          : 7.982825994491577
# INFO:trainer:    loss           : 10450.41015625
# INFO:trainer:    mse            : 0.0556332990527153
# INFO:trainer:    epoch          : 3
# INFO:trainer:    time:          : 7.980865478515625
# INFO:trainer:    loss           : 5999.197265625
# INFO:trainer:    mse            : 0.07936916500329971
# INFO:trainer:    epoch          : 4
# INFO:trainer:    time:          : 8.041043281555176
# INFO:trainer:    loss           : 4370.6025390625
# INFO:trainer:    time:          : 8.025595664978027
# INFO:trainer:    loss           : 1720.194580078125
# INFO:trainer:    mse            : 0.22716298699378967
# INFO:trainer:    epoch          : 23
# INFO:trainer:    time:          : 8.070314407348633
# INFO:trainer:    loss           : 1698.43408203125
# INFO:trainer:    mse            : 0.22318066656589508
# INFO:trainer:    epoch          : 24
# INFO:trainer:    time:          : 8.061578750610352
# INFO:trainer:    loss           : 1679.2945556640625
# INFO:trainer:    mse            : 0.22045722603797913
# INFO:trainer:    epoch          : 25
# INFO:trainer:    time:          : 8.094466924667358
# INFO:trainer:    loss           : 1659.6439208984375
# INFO:trainer:    mse            : 0.20402935147285461
# INFO:trainer:    epoch          : 26
# INFO:trainer:    time:          : 8.05665397644043
# INFO:trainer:    loss           : 1641.903564453125
# INFO:trainer:    mse            : 0.20290033519268036
# INFO:trainer:    epoch          : 27
# INFO:trainer:    time:          : 7.988616943359375
# INFO:trainer:    loss           : 1620.0648193359375
# INFO:trainer:    mse            : 0.19290152192115784
# INFO:trainer:    epoch          : 28
# INFO:trainer:    time:          : 8.084147453308105
# INFO:trainer:    loss           : 1603.37109375
# INFO:trainer:    mse            : 0.18289369344711304
# INFO:trainer:    epoch          : 29
# INFO:trainer:    time:          : 8.07694149017334
# INFO:trainer:    loss           : 1593.6142578125
# INFO:trainer:    mse            : 0.18343965709209442
# INFO:trainer:    epoch          : 30
# INFO:trainer:    time:          : 7.998593330383301
# INFO:trainer:    loss           : 1578.2584228515625
# INFO:trainer:    mse            : 0.17474021017551422
# INFO:trainer:    epoch          : 31
# INFO:trainer:    time:          : 8.026070356369019
# INFO:trainer:    loss           : 1563.253173828125
# INFO:trainer:    mse            : 0.1676011085510254
# INFO:trainer:    epoch          : 32
# INFO:trainer:    time:          : 8.036294937133789
# INFO:trainer:    loss           : 1552.406982421875
# INFO:trainer:    mse            : 0.1616668403148651
# INFO:trainer:    epoch          : 33
# INFO:trainer:    time:          : 8.028264045715332
# INFO:trainer:    loss           : 1538.2861328125
# INFO:trainer:    mse            : 0.15445448458194733
# INFO:trainer:    epoch          : 34
# INFO:trainer:    time:          : 8.015375137329102
# INFO:trainer:    loss           : 1526.5452880859375
# INFO:trainer:    mse            : 0.1532573401927948
# INFO:trainer:    epoch          : 35
# INFO:trainer:    time:          : 8.026627540588379
# INFO:trainer:    loss           : 1517.0198974609375
# INFO:trainer:    mse            : 0.1491917222738266
# INFO:trainer:    epoch          : 36
# INFO:trainer:    time:          : 8.051443338394165
# INFO:trainer:    loss           : 1508.65478515625
# INFO:trainer:    mse            : 0.14449356496334076
# INFO:trainer:    epoch          : 37
# INFO:trainer:    time:          : 8.019874334335327
# INFO:trainer:    loss           : 1499.7569580078125
# INFO:trainer:    mse            : 0.14237335324287415
# INFO:trainer:    epoch          : 38
# INFO:trainer:    time:          : 8.055940628051758
# INFO:trainer:    loss           : 1493.6729736328125
# INFO:trainer:    mse            : 0.13655556738376617
# INFO:trainer:    epoch          : 39
# INFO:trainer:    time:          : 8.047639608383179
# INFO:trainer:    loss           : 1484.54638671875
# INFO:trainer:    mse            : 0.13576550781726837
# INFO:trainer:    epoch          : 40
# INFO:trainer:    time:          : 8.130403280258179
# INFO:trainer:    loss           : 1479.1180419921875
# INFO:trainer:    mse            : 0.12933751940727234
# INFO:trainer:    epoch          : 41
# INFO:trainer:    time:          : 8.045125722885132
# INFO:trainer:    loss           : 1471.304931640625
# INFO:trainer:    mse            : 0.12770940363407135
# INFO:trainer:    epoch          : 42
# INFO:trainer:    time:          : 7.994979381561279
# INFO:trainer:    loss           : 1468.7677001953125
# INFO:trainer:    mse            : 0.12684215605258942
# INFO:trainer:    epoch          : 43
# INFO:trainer:    time:          : 8.096826791763306
# INFO:trainer:    loss           : 1454.6390380859375
# INFO:trainer:    mse            : 0.12448208034038544
# INFO:trainer:    epoch          : 44
# INFO:trainer:    time:          : 8.058297634124756
# INFO:trainer:    loss           : 1446.5899658203125
# INFO:trainer:    mse            : 0.12235294282436371
# INFO:trainer:    epoch          : 45
# INFO:trainer:    time:          : 7.985539436340332
# INFO:trainer:    loss           : 1444.890869140625
# INFO:trainer:    mse            : 0.11898846179246902
# INFO:trainer:    epoch          : 46
# INFO:trainer:    time:          : 8.08238673210144
# INFO:trainer:    loss           : 1442.5430908203125
# INFO:trainer:    mse            : 0.11468503624200821
# INFO:trainer:    epoch          : 47
# INFO:trainer:    time:          : 8.062665939331055
# INFO:trainer:    loss           : 1439.594482421875
# INFO:trainer:    mse            : 0.1164957657456398
# INFO:trainer:    epoch          : 48
# INFO:trainer:    time:          : 8.165328025817871
# INFO:trainer:    loss           : 1429.4246826171875
# INFO:trainer:    mse            : 0.11153893172740936
# INFO:trainer:    epoch          : 49
# INFO:trainer:    time:          : 8.027870416641235
# INFO:trainer:    loss           : 1426.3585205078125
# INFO:trainer:    mse            : 0.11360487341880798
# INFO:trainer:    epoch          : 50
# INFO:trainer:    time:          : 7.9859559535980225
# INFO:trainer:    loss           : 1420.662353515625
# INFO:trainer:    mse            : 0.11304755508899689
# INFO:trainer:    epoch          : 51
# INFO:trainer:    time:          : 8.091214179992676
# INFO:trainer:    loss           : 1419.22900390625
# INFO:trainer:    mse            : 0.10974805057048798
# INFO:trainer:    epoch          : 52
# INFO:trainer:    time:          : 8.047660112380981
# INFO:trainer:    loss           : 1412.6727294921875
# INFO:trainer:    mse            : 0.10728516429662704
# INFO:trainer:    epoch          : 53
# INFO:trainer:    time:          : 8.066096544265747
# INFO:trainer:    loss           : 1409.997314453125
# INFO:trainer:    mse            : 0.10844968259334564
# INFO:trainer:    epoch          : 54
# INFO:trainer:    time:          : 8.013091087341309
# INFO:trainer:    loss           : 1403.9638671875
# INFO:trainer:    mse            : 0.10355234146118164
# INFO:trainer:    epoch          : 55
# INFO:trainer:    time:          : 7.989022254943848
# INFO:trainer:    loss           : 1407.18798828125
# INFO:trainer:    mse            : 0.10553421825170517
# INFO:trainer:    epoch          : 56
# INFO:trainer:    time:          : 8.08913779258728
# INFO:trainer:    loss           : 1404.3685302734375
# INFO:trainer:    mse            : 0.1000363752245903
# INFO:trainer:    epoch          : 57
# INFO:trainer:    time:          : 8.113177061080933
# INFO:trainer:    loss           : 1343.244140625
# INFO:trainer:    mse            : 0.0823085829615593
# INFO:trainer:    epoch          : 93
# INFO:trainer:    time:          : 7.992126226425171
# INFO:trainer:    loss           : 1345.1776123046875
# INFO:trainer:    mse            : 0.08402908593416214
# INFO:trainer:    epoch          : 94
# INFO:trainer:    time:          : 7.980906248092651
# INFO:trainer:    loss           : 1346.2110595703125
# INFO:trainer:    mse            : 0.0837990865111351
# INFO:trainer:    epoch          : 95
# INFO:trainer:    time:          : 8.090721607208252
# INFO:trainer:    loss           : 1342.6075439453125
# INFO:trainer:    mse            : 0.08251652121543884
# INFO:trainer:    epoch          : 96
# INFO:trainer:    time:          : 8.02039647102356
# INFO:trainer:    loss           : 1344.041015625
# INFO:trainer:    mse            : 0.08175431936979294
# INFO:trainer:    epoch          : 97
# INFO:trainer:    time:          : 8.075793266296387
# INFO:trainer:    loss           : 1342.9893798828125
# INFO:trainer:    mse            : 0.08398953825235367
# INFO:trainer:    epoch          : 98
# INFO:trainer:    time:          : 8.0603768825531
# INFO:trainer:    loss           : 1341.730712890625
# INFO:trainer:    mse            : 0.08190757036209106
# INFO:trainer:    epoch          : 99
# INFO:trainer:    time:          : 7.989881992340088
# INFO:trainer:    loss           : 1339.1116943359375
# INFO:trainer:    mse            : 0.07874976098537445
# INFO:trainer:    epoch          : 100
# INFO:trainer:    time:          : 8.035179853439331
# INFO:trainer:    loss           : 1338.6710205078125
# INFO:trainer:    mse            : 0.08227669447660446
# velo_mat shape: (2930, 3000)
# --> added 'velocity' (adata.layers)
# --> added 'velocity_unspliced' (adata.layers)
# --> added 'cell_specific_beta' (adata.layers)
# --> added 'cell_specific_gamma' (adata.layers)
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/2930 [00:00<?, ?cells/s]
#     finished (0:00:18) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.2063583893474332, ('Neuroblast', 'Granule immature'): 0.5803122016341171, ('Granule immature', 'Granule mature'): 0.2928744669680778, ('Radial Glia-like', 'Astrocytes'): -0.7277663400474056, ('OPC', 'OL'): 0.11593580564319025}
# Total Mean: 0.09354290470908258
# # In-cluster Coherence
# {'Astrocytes': 0.9158868, 'Cajal Retzius': 0.99141276, 'Cck-Tox': 0.9688492, 'Endothelial': 0.9218514, 'GABA': 0.95909286, 'Granule immature': 0.93300873, 'Granule mature': 0.8965042, 'Microglia': 0.9072363, 'Mossy': 0.9468922, 'Neuroblast': 0.9395334, 'OL': 0.98034024, 'OPC': 0.9475288, 'Radial Glia-like': 0.9166216, 'nIPC': 0.9162967}
# Total Mean: 0.9386467337608337
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.2063583893474332, ('Neuroblast', 'Granule immature'): 0.5803122016341171, ('Granule immature', 'Granule mature'): 0.2928744669680778, ('Radial Glia-like', 'Astrocytes'): -0.7277663400474056, ('OPC', 'OL'): 0.11593580564319025}
# Total Mean: 0.09354290470908258
# # In-cluster Coherence
# {'Astrocytes': 0.9158868, 'Cajal Retzius': 0.99141276, 'Cck-Tox': 0.9688492, 'Endothelial': 0.9218514, 'GABA': 0.95909286, 'Granule immature': 0.93300873, 'Granule mature': 0.8965042, 'Microglia': 0.9072363, 'Mossy': 0.9468922, 'Neuroblast': 0.9395334, 'OL': 0.98034024, 'OPC': 0.9475288, 'Radial Glia-like': 0.9166216, 'nIPC': 0.9162967}
# Total Mean: 0.9386467337608337
# MouseBoneMarrow
# Filtered out 20300 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Config Warning: Set to use GPU, but GPU version of DGL is not installed. Reset to use CPU instead.
# Warning: logging configuration file is not found in logger/logger_config.json.
# building graph
# INFO:train:Beginning training of DeepVelo_Base ...
# velo data shape: torch.Size([2600, 1252])
# INFO:trainer:    epoch          : 1
# INFO:trainer:    time:          : 2.621732234954834
# INFO:trainer:    loss           : 65928.84375
# INFO:trainer:    mse            : 56.59944152832031
# INFO:trainer:    epoch          : 2
# INFO:trainer:    time:          : 2.6145009994506836
# INFO:trainer:    loss           : 15385.1875
# INFO:trainer:    mse            : 20.875686645507812
# INFO:trainer:    epoch          : 3
# INFO:trainer:    time:          : 2.553560972213745
# INFO:trainer:    loss           : 8040.634765625
# INFO:trainer:    mse            : 6.42738151550293
# INFO:trainer:    epoch          : 4
# INFO:trainer:    time:          : 2.5921831130981445
# INFO:trainer:    loss           : 5812.0849609375
# INFO:trainer:    mse            : 2.9780197143554688
# INFO:trainer:    epoch          : 5
# INFO:trainer:    time:          : 2.5486016273498535
# INFO:trainer:    loss           : 4686.34033203125
# INFO:trainer:    mse            : 3.7621498107910156
# INFO:trainer:    epoch          : 6
# INFO:trainer:    time:          : 2.6166324615478516
# INFO:trainer:    loss           : 4010.297607421875
# INFO:trainer:    mse            : 6.598461627960205
# INFO:trainer:    epoch          : 7
# INFO:trainer:    time:          : 2.5740721225738525
# INFO:trainer:    loss           : 3494.74609375
# INFO:trainer:    mse            : 7.358460903167725
# INFO:trainer:    epoch          : 8
# INFO:trainer:    time:          : 2.548830270767212
# INFO:trainer:    loss           : 3064.33056640625
# INFO:trainer:    mse            : 6.249082088470459
# INFO:trainer:    epoch          : 9
# INFO:trainer:    time:          : 2.5734033584594727
# INFO:trainer:    loss           : 2700.142578125
# INFO:trainer:    mse            : 3.9057772159576416
# INFO:trainer:    epoch          : 10
# INFO:trainer:    time:          : 2.5796399116516113
# INFO:trainer:    loss           : 2466.895751953125
# INFO:trainer:    mse            : 2.554265260696411
# INFO:trainer:    epoch          : 11
# INFO:trainer:    time:          : 2.5495314598083496
# INFO:trainer:    loss           : 2270.221435546875
# INFO:trainer:    mse            : 1.3524951934814453
# INFO:trainer:    epoch          : 12
# INFO:trainer:    time:          : 2.6049294471740723
# INFO:trainer:    loss           : 2157.133056640625
# INFO:trainer:    mse            : 0.8954119086265564
# INFO:trainer:    epoch          : 13
# INFO:trainer:    time:          : 2.5830953121185303
# INFO:trainer:    loss           : 2058.626708984375
# INFO:trainer:    mse            : 0.7562663555145264
# ...
# INFO:trainer:    mse            : 0.3475530743598938
# INFO:trainer:    epoch          : 75
# INFO:trainer:    time:          : 2.496488094329834
# INFO:trainer:    loss           : 1105.0091552734375
# INFO:trainer:    mse            : 0.34669554233551025
# INFO:trainer:    epoch          : 76
# INFO:trainer:    time:          : 2.5445687770843506
# INFO:trainer:    loss           : 1108.4571533203125
# INFO:trainer:    mse            : 0.35516297817230225
# INFO:trainer:    epoch          : 77
# INFO:trainer:    time:          : 2.5384697914123535
# INFO:trainer:    loss           : 1109.973876953125
# INFO:trainer:    mse            : 0.35141804814338684
# INFO:trainer:    epoch          : 78
# INFO:trainer:    time:          : 2.590421676635742
# INFO:trainer:    loss           : 1106.4591064453125
# INFO:trainer:    mse            : 0.3417882025241852
# INFO:trainer:    epoch          : 79
# INFO:trainer:    time:          : 2.5569000244140625
# INFO:trainer:    loss           : 1108.792724609375
# INFO:trainer:    mse            : 0.31814128160476685
# INFO:trainer:    epoch          : 80
# INFO:trainer:    time:          : 2.554762601852417
# INFO:trainer:    loss           : 1097.829345703125
# INFO:trainer:    mse            : 0.3206692636013031
# INFO:trainer:    epoch          : 81
# INFO:trainer:    time:          : 2.5684897899627686
# INFO:trainer:    loss           : 1099.8104248046875
# INFO:trainer:    mse            : 0.3623071610927582
# INFO:trainer:    epoch          : 82
# INFO:trainer:    time:          : 2.508221387863159
# INFO:trainer:    loss           : 1098.70751953125
# INFO:trainer:    mse            : 0.34917151927948
# INFO:trainer:    epoch          : 83
# INFO:trainer:    time:          : 2.635546922683716
# INFO:trainer:    loss           : 1100.100830078125
# INFO:trainer:    mse            : 0.32994526624679565
# INFO:trainer:    epoch          : 84
# INFO:trainer:    time:          : 2.572922706604004
# INFO:trainer:    loss           : 1097.4146728515625
# INFO:trainer:    mse            : 0.3336526155471802
# INFO:trainer:    epoch          : 85
# INFO:trainer:    time:          : 2.56996750831604
# INFO:trainer:    loss           : 1097.474609375
# INFO:trainer:    mse            : 0.3151862323284149
# INFO:trainer:    epoch          : 86
# INFO:trainer:    time:          : 2.6212210655212402
# INFO:trainer:    loss           : 1098.372314453125
# INFO:trainer:    mse            : 0.3378569781780243
# INFO:trainer:    epoch          : 87
# INFO:trainer:    time:          : 2.5782554149627686
# INFO:trainer:    loss           : 1094.8271484375
# INFO:trainer:    mse            : 0.3218957483768463
# INFO:trainer:    epoch          : 88
# INFO:trainer:    time:          : 2.5552890300750732
# INFO:trainer:    loss           : 1094.0272216796875
# INFO:trainer:    mse            : 0.3132927119731903
# INFO:trainer:    epoch          : 89
# INFO:trainer:    time:          : 2.6170148849487305
# INFO:trainer:    loss           : 1094.7432861328125
# INFO:trainer:    mse            : 0.3345695436000824
# INFO:trainer:    epoch          : 90
# INFO:trainer:    time:          : 2.5774502754211426
# INFO:trainer:    loss           : 1093.2314453125
# INFO:trainer:    mse            : 0.3161280155181885
# INFO:trainer:    epoch          : 91
# INFO:trainer:    time:          : 2.5694808959960938
# INFO:trainer:    loss           : 1090.100341796875
# INFO:trainer:    mse            : 0.30593061447143555
# INFO:trainer:    epoch          : 92
# INFO:trainer:    time:          : 2.6121327877044678
# INFO:trainer:    loss           : 1089.62109375
# INFO:trainer:    mse            : 0.3184533715248108
# INFO:trainer:    epoch          : 93
# INFO:trainer:    time:          : 2.5678369998931885
# INFO:trainer:    loss           : 1089.2740478515625
# INFO:trainer:    mse            : 0.33888086676597595
# INFO:trainer:    epoch          : 94
# INFO:trainer:    time:          : 2.5930027961730957
# INFO:trainer:    loss           : 1088.739501953125
# INFO:trainer:    mse            : 0.33806827664375305
# INFO:trainer:    epoch          : 95
# INFO:trainer:    time:          : 2.5648820400238037
# INFO:trainer:    loss           : 1090.443115234375
# INFO:trainer:    mse            : 0.3231259286403656
# INFO:trainer:    epoch          : 96
# INFO:trainer:    time:          : 2.4780619144439697
# INFO:trainer:    loss           : 1088.298828125
# INFO:trainer:    mse            : 0.3148839473724365
# INFO:trainer:    epoch          : 97
# INFO:trainer:    time:          : 2.553821325302124
# INFO:trainer:    loss           : 1085.959228515625
# INFO:trainer:    mse            : 0.3236490488052368
# INFO:trainer:    epoch          : 98
# INFO:trainer:    time:          : 2.5430500507354736
# INFO:trainer:    loss           : 1089.1724853515625
# INFO:trainer:    mse            : 0.31697937846183777
# INFO:trainer:    epoch          : 99
# INFO:trainer:    time:          : 2.525329113006592
# INFO:trainer:    loss           : 1084.8388671875
# INFO:trainer:    mse            : 0.31969887018203735
# INFO:trainer:    epoch          : 100
# INFO:trainer:    time:          : 2.583289623260498
# INFO:trainer:    loss           : 1084.29345703125
# INFO:trainer:    mse            : 0.3591187596321106
# velo_mat shape: (2600, 1252)
# --> added 'velocity' (adata.layers)
# --> added 'velocity_unspliced' (adata.layers)
# --> added 'cell_specific_beta' (adata.layers)
# --> added 'cell_specific_gamma' (adata.layers)
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/2600 [00:00<?, ?cells/s]
#     finished (0:00:05) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.42908860070870725, ('progenitors', 'activating'): -0.5703333831148938}
# Total Mean: -0.4997109919118005
# # In-cluster Coherence
# {'B cell lineage': 0.8856354, 'activating': 0.8885332, 'dividing': 0.79850686, 'macrophages': 0.90042406, 'progenitors': 0.83670336}
# Total Mean: 0.8619605302810669
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.42908860070870725, ('progenitors', 'activating'): -0.5703333831148938}
# Total Mean: -0.4997109919118005
# # In-cluster Coherence
# {'B cell lineage': 0.8856354, 'activating': 0.8885332, 'dividing': 0.79850686, 'macrophages': 0.90042406, 'progenitors': 0.83670336}
# Total Mean: 0.8619605302810669
# MouseErythroid
# Filtered out 47456 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:14) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:02) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Config Warning: Set to use GPU, but GPU version of DGL is not installed. Reset to use CPU instead.
# Warning: logging configuration file is not found in logger/logger_config.json.
# building graph
# INFO:train:Beginning training of DeepVelo_Base ...
# velo data shape: torch.Size([9815, 3000])
# INFO:trainer:    epoch          : 1
# INFO:trainer:    time:          : 26.259074449539185
# INFO:trainer:    loss           : 163653.484375
# INFO:trainer:    mse            : 1185.632080078125
# INFO:trainer:    epoch          : 2
# INFO:trainer:    time:          : 26.435172080993652
# INFO:trainer:    loss           : 40205.65625
# INFO:trainer:    mse            : 410.6335754394531
# INFO:trainer:    epoch          : 3
# INFO:trainer:    time:          : 26.729791164398193
# INFO:trainer:    loss           : 41017.203125
# INFO:trainer:    mse            : 590.7056884765625
# INFO:trainer:    epoch          : 4
# INFO:trainer:    time:          : 26.711156368255615
# INFO:trainer:    loss           : 31551.3046875
# INFO:trainer:    mse            : 468.87152099609375
# INFO:trainer:    epoch          : 5
# INFO:trainer:    time:          : 26.6386399269104
# INFO:trainer:    loss           : 16632.234375
# INFO:trainer:    mse            : 214.6481170654297
# INFO:trainer:    epoch          : 6
# INFO:trainer:    time:          : 26.79296374320984
# INFO:trainer:    loss           : 7860.7041015625
# INFO:trainer:    mse            : 61.202144622802734
# INFO:trainer:    epoch          : 7
# INFO:trainer:    time:          : 26.913830518722534
# INFO:trainer:    loss           : 7330.1982421875
# INFO:trainer:    mse            : 55.49366760253906
# INFO:trainer:    epoch          : 8
# INFO:trainer:    time:          : 26.438015460968018
# INFO:trainer:    loss           : 10485.9306640625
# INFO:trainer:    mse            : 119.78704071044922
# INFO:trainer:    epoch          : 9
# INFO:trainer:    time:          : 26.69144558906555
# INFO:trainer:    loss           : 12176.3017578125
# INFO:trainer:    mse            : 156.38516235351562
# INFO:trainer:    epoch          : 10
# INFO:trainer:    time:          : 26.759891986846924
# INFO:trainer:    loss           : 10638.1064453125
# INFO:trainer:    mse            : 132.94601440429688
# INFO:trainer:    epoch          : 11
# INFO:trainer:    time:          : 26.662793159484863
# INFO:trainer:    loss           : 10114.3349609375
# INFO:trainer:    mse            : 127.76924896240234
# INFO:trainer:    epoch          : 12
# INFO:trainer:    time:          : 26.77606701850891
# INFO:trainer:    loss           : 7444.67578125
# INFO:trainer:    mse            : 82.21798706054688
# INFO:trainer:    epoch          : 13
# INFO:trainer:    time:          : 26.823675394058228
# INFO:trainer:    loss           : 5851.3583984375
# INFO:trainer:    mse            : 55.772884368896484
# INFO:trainer:    epoch          : 14
# INFO:trainer:    time:          : 26.703136205673218
# INFO:trainer:    loss           : 4191.50244140625
# INFO:trainer:    mse            : 27.238727569580078
# INFO:trainer:    epoch          : 15
# INFO:trainer:    time:          : 26.589367628097534
# INFO:trainer:    loss           : 4229.533203125
# INFO:trainer:    mse            : 29.94095230102539
# INFO:trainer:    epoch          : 16
# INFO:trainer:    time:          : 26.586565732955933
# INFO:trainer:    loss           : 4110.37890625
# INFO:trainer:    mse            : 29.966585159301758
# INFO:trainer:    epoch          : 17
# INFO:trainer:    time:          : 26.566272974014282
# INFO:trainer:    loss           : 4267.1435546875
# INFO:trainer:    mse            : 34.4256706237793
# INFO:trainer:    epoch          : 18
# INFO:trainer:    time:          : 26.596819400787354
# INFO:trainer:    loss           : 4303.16064453125
# INFO:trainer:    mse            : 36.29850387573242
# INFO:trainer:    epoch          : 19
# INFO:trainer:    time:          : 26.62409543991089
# INFO:trainer:    loss           : 4564.4111328125
# INFO:trainer:    mse            : 42.3267936706543
# INFO:trainer:    epoch          : 20
# INFO:trainer:    time:          : 26.470564126968384
# INFO:trainer:    loss           : 4438.7275390625
# INFO:trainer:    mse            : 41.34101104736328
# INFO:trainer:    epoch          : 21
# INFO:trainer:    time:          : 26.498408794403076
# INFO:trainer:    loss           : 4057.60302734375
# INFO:trainer:    mse            : 35.0075569152832
# INFO:trainer:    epoch          : 22
# INFO:trainer:    time:          : 26.530206203460693
# INFO:trainer:    loss           : 3789.420166015625
# INFO:trainer:    mse            : 30.85542869567871
# INFO:trainer:    epoch          : 23
# INFO:trainer:    time:          : 26.50287890434265
# INFO:trainer:    loss           : 3447.750732421875
# INFO:trainer:    mse            : 25.38106346130371
# INFO:trainer:    epoch          : 24
# INFO:trainer:    time:          : 26.8068687915802
# INFO:trainer:    loss           : 3202.5185546875
# INFO:trainer:    mse            : 21.156875610351562
# INFO:trainer:    epoch          : 25
# INFO:trainer:    time:          : 26.85926055908203
# INFO:trainer:    loss           : 2978.1474609375
# INFO:trainer:    mse            : 17.618574142456055
# INFO:trainer:    epoch          : 26
# INFO:trainer:    time:          : 26.809311151504517
# INFO:trainer:    loss           : 2814.265625
# INFO:trainer:    mse            : 15.035953521728516
# INFO:trainer:    epoch          : 27
# INFO:trainer:    time:          : 26.95503282546997
# INFO:trainer:    loss           : 2784.79345703125
# INFO:trainer:    mse            : 15.009061813354492
# INFO:trainer:    epoch          : 28
# INFO:trainer:    time:          : 26.623682737350464
# INFO:trainer:    loss           : 2797.546875
# INFO:trainer:    mse            : 15.719461441040039
# INFO:trainer:    epoch          : 29
# INFO:trainer:    time:          : 26.774605751037598
# INFO:trainer:    loss           : 2918.189208984375
# INFO:trainer:    mse            : 18.405029296875
# INFO:trainer:    epoch          : 30
# INFO:trainer:    time:          : 26.67852020263672
# INFO:trainer:    loss           : 2901.44677734375
# INFO:trainer:    mse            : 18.31315803527832
# INFO:trainer:    epoch          : 31
# INFO:trainer:    time:          : 26.480979204177856
# INFO:trainer:    loss           : 2896.064697265625
# INFO:trainer:    mse            : 18.693998336791992
# INFO:trainer:    epoch          : 32
# INFO:trainer:    time:          : 26.544952154159546
# INFO:trainer:    loss           : 2724.98583984375
# INFO:trainer:    mse            : 15.514925003051758
# INFO:trainer:    epoch          : 33
# INFO:trainer:    time:          : 26.55159878730774
# INFO:trainer:    loss           : 2684.68017578125
# INFO:trainer:    mse            : 15.021488189697266
# INFO:trainer:    epoch          : 34
# INFO:trainer:    time:          : 26.6415958404541
# INFO:trainer:    loss           : 2618.68408203125
# INFO:trainer:    mse            : 14.064704895019531
# INFO:trainer:    epoch          : 35
# INFO:trainer:    time:          : 26.71455454826355
# INFO:trainer:    loss           : 2587.9921875
# INFO:trainer:    mse            : 13.870600700378418
# INFO:trainer:    epoch          : 36
# INFO:trainer:    time:          : 26.847776889801025
# INFO:trainer:    loss           : 2580.297607421875
# INFO:trainer:    mse            : 13.678086280822754
# INFO:trainer:    epoch          : 37
# INFO:trainer:    time:          : 26.911454916000366
# INFO:trainer:    loss           : 2478.981689453125
# INFO:trainer:    mse            : 12.167768478393555
# INFO:trainer:    epoch          : 38
# INFO:trainer:    time:          : 26.709465980529785
# INFO:trainer:    loss           : 2347.07373046875
# INFO:trainer:    mse            : 9.983471870422363
# INFO:trainer:    epoch          : 39
# INFO:trainer:    time:          : 26.71725845336914
# INFO:trainer:    loss           : 2420.24951171875
# INFO:trainer:    mse            : 11.715205192565918
# INFO:trainer:    epoch          : 40
# INFO:trainer:    time:          : 26.696587085723877
# INFO:trainer:    epoch          : 41
# INFO:trainer:    time:          : 26.691656589508057
# INFO:trainer:    loss           : 2352.09228515625
# INFO:trainer:    mse            : 10.671544075012207
# INFO:trainer:    epoch          : 42
# INFO:trainer:    time:          : 26.623232126235962
# INFO:trainer:    loss           : 2294.676025390625
# INFO:trainer:    mse            : 9.738316535949707
# INFO:trainer:    epoch          : 43
# INFO:trainer:    time:          : 26.68261194229126
# INFO:trainer:    loss           : 2286.8466796875
# INFO:trainer:    mse            : 9.830914497375488
# INFO:trainer:    epoch          : 44
# INFO:trainer:    time:          : 26.627781629562378
# INFO:trainer:    loss           : 2396.504150390625
# INFO:trainer:    mse            : 11.932602882385254
# INFO:trainer:    epoch          : 45
# INFO:trainer:    time:          : 26.627253770828247
# INFO:trainer:    loss           : 2332.75390625
# INFO:trainer:    mse            : 11.012228965759277
# INFO:trainer:    epoch          : 46
# INFO:trainer:    time:          : 26.66788601875305
# INFO:trainer:    loss           : 2396.9052734375
# INFO:trainer:    mse            : 12.52389907836914

# %%
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_' + method + '.svg')
