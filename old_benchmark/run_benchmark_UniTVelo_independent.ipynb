# %%
import scvelo as scv
import scanpy as sc
import pickle as pickle
from eval_utils import cross_boundary_correctness, inner_cluster_coh
import pandas as pd
import numpy as np
from os.path import exists
import matplotlib.pyplot as plt
import unitvelo as utv
method = 'UniTVelo_independent'
# Out:
# (Running UniTVelo 0.2.5)
# 2023-05-17 11:36:19

# %%
datasets = ['Pancreas_with_cc', 'HumanDevelopingBrain', 'MouseErythroid', 'DentateGyrus', 'MouseBoneMarrow',  'HumanBoneMarrow']
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'

# %%
for dataset in datasets:
    print(dataset)
    # Load and setup data:
    adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
    adata.var['highly_variable'] = True
    scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=3000)
    scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
    velo = utv.config.Configuration()
    velo.N_TOP_GENES = 3000
    velo.R2_ADJUST = True
    velo.IROOT = None
    velo.FIT_OPTION = '2'
    velo.GPU = 0
    velo.vgenes = 'offset'
    scv.pp.neighbors(adata)
    adata = utv.run_model(adata, 'clusters', config_file=velo)
    scv.tl.velocity_graph(adata, vkey='velocity')
    scv.tl.velocity_embedding(adata, vkey='velocity')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax, legend_fontsize = 13)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_UniTVelo_independent.svg')
    # Calculate performance metrics:
    adata.layers['velocity'][pd.isna(adata.layers['velocity'])] = 0
    file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
    ground_truth = pickle.load(file)
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_CBDC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_CBDC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(metrics['Cross-Boundary Direction Correctness (A->B)'].keys()) + ['Mean'],
                 index = [method])
    cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
    tab.loc[method,:] = cb_score + [np.mean(cb_score)]
    tab.to_csv(save_dir + dataset + '_CBDC_scores.csv')
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_ICC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_ICC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(np.unique(np.concatenate(ground_truth))) + ['Mean'],
                 index = [method])
    icc_score = [np.mean(metrics['In-cluster Coherence'][x]) for x in np.unique(np.concatenate(ground_truth))]
    tab.loc[method,:] = icc_score + [np.mean(icc_score)]
    tab.to_csv(save_dir + dataset + '_ICC_scores.csv')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_' + method + '.svg')
# Out:
# Pancreas_with_cc
# Filtered out 20801 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:07) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# FIT_OPTION:	2
# DENSITY:	Raw
# REORDER_CELL:	Hard
# AGGREGATE_T:	False
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Filtered out 91 genes that are detected 20 counts (shared).
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize spliced as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize unspliced as it looks processed already. To enforce normalization, set `enforce=True`.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# Extracted 2909 highly variable genes.
# Computing moments for 2909 genes with n_neighbors: 30 and n_pcs: 30
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#
# # of velocity genes 1497 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 1311 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 1311 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 246.018, (Spliced): 128.185, (Unspliced): 117.833:  56%|████████████████████████████████████████████████████████████████████████▎                                                         | 6676/12000 [23:23<19:34,  4.53it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Loss (Total): 208.830, (Spliced): 102.654, (Unspliced): 106.176:  83%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▉                      | 9968/12000 [35:54<07:32,  4.49it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Loss (Total): 202.768, (Spliced): 98.718, (Unspliced): 104.051: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [43:36<00:00,  4.46it/s]
# Loss (Total): 202.768, (Spliced): 98.718, (Unspliced): 104.051: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [44:10<00:00,  4.53it/s]
# Total loss 202.768, vgene loss 202.768
#   0%|          | 0/3696 [00:00<?, ?cells/s]
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.6110537791062711, ('Pre-endocrine', 'Alpha'): 0.1506030683047938, ('Pre-endocrine', 'Beta'): 0.7544964423955483, ('Pre-endocrine', 'Delta'): 0.3993765223610694, ('Pre-endocrine', 'Epsilon'): 0.4973264414934037}
# Total Mean: 0.4825712507322173
# # In-cluster Coherence
# {'Alpha': 0.9791109, 'Beta': 0.96584386, 'Delta': 0.95786077, 'Ductal': 0.98109853, 'Epsilon': 0.9777299, 'Ngn3 high EP': 0.9857366, 'Ngn3 low EP': 0.9815127, 'Pre-endocrine': 0.98140967}
# Total Mean: 0.976287841796875
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.6110537791062711, ('Pre-endocrine', 'Alpha'): 0.1506030683047938, ('Pre-endocrine', 'Beta'): 0.7544964423955483, ('Pre-endocrine', 'Delta'): 0.3993765223610694, ('Pre-endocrine', 'Epsilon'): 0.4973264414934037}
# Total Mean: 0.4825712507322173
# # In-cluster Coherence
# {'Alpha': 0.9791109, 'Beta': 0.96584386, 'Delta': 0.95786077, 'Ductal': 0.98109853, 'Epsilon': 0.9777299, 'Ngn3 high EP': 0.9857366, 'Ngn3 low EP': 0.9815127, 'Pre-endocrine': 0.98140967}
# Total Mean: 0.976287841796875
# HumanDevelopingBrain
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# FIT_OPTION:	2
# DENSITY:	Raw
# REORDER_CELL:	Hard
# AGGREGATE_T:	False
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 2873 highly variable genes.
# Computing moments for 2873 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 533 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 401 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 401 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 1397.638, (Spliced): 572.037, (Unspliced): 825.601:   5%|██████▎                                                                                                                           | 584/12000 [01:24<21:33,  8.82it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Loss (Total): 112.148, (Spliced): 64.915, (Unspliced): 47.234:  33%|███████████████████████████████████████████                                                                                         | 3912/12000 [24:38<46:31,  2.90it/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): -0.06286168403620918, ('Blood progenitors 2', 'Erythroid1'): 0.10568071267321945, ('Erythroid1', 'Erythroid2'): -0.6776158840100983, ('Erythroid2', 'Erythroid3'): -0.6008254305989152}
# Total Mean: -0.3089055714930008
# # In-cluster Coherence
# {'Blood progenitors 1': 0.99610156, 'Blood progenitors 2': 0.9952664, 'Erythroid1': 0.9944912, 'Erythroid2': 0.9960428, 'Erythroid3': 0.99487495}
# Total Mean: 0.9953554272651672
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): -0.06286168403620918, ('Blood progenitors 2', 'Erythroid1'): 0.10568071267321945, ('Erythroid1', 'Erythroid2'): -0.6776158840100983, ('Erythroid2', 'Erythroid3'): -0.6008254305989152}
# Total Mean: -0.3089055714930008
# # In-cluster Coherence
# {'Blood progenitors 1': 0.99610156, 'Blood progenitors 2': 0.9952664, 'Erythroid1': 0.9944912, 'Erythroid2': 0.9960428, 'Erythroid3': 0.99487495}
# Total Mean: 0.9953554272651672
# DentateGyrus
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# FIT_OPTION:	2
# DENSITY:	Raw
# REORDER_CELL:	Hard
# AGGREGATE_T:	False
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 2725 highly variable genes.
# Computing moments for 2725 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 1211 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 1140 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 1128 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 73.120, (Spliced): 36.401, (Unspliced): 36.718: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [15:51<00:00, 12.61it/s]
# Loss (Total): 73.120, (Spliced): 36.401, (Unspliced): 36.718: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [16:18<00:00, 12.27it/s]
# Total loss 73.120, vgene loss 73.120
#   0%|          | 0/2930 [00:00<?, ?cells/s]
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.9000034739911786, ('Neuroblast', 'Granule immature'): 0.2989589571803295, ('Granule immature', 'Granule mature'): -0.0367478434117951, ('Radial Glia-like', 'Astrocytes'): 0.8457621790459381, ('OPC', 'OL'): 0.7963321170577918}
# Total Mean: 0.5608617767726887
# # In-cluster Coherence
# {'Astrocytes': 0.87868106, 'Cajal Retzius': 0.99023134, 'Cck-Tox': 0.9759212, 'Endothelial': 0.96070784, 'GABA': 0.9559441, 'Granule immature': 0.94351035, 'Granule mature': 0.93355536, 'Microglia': 0.9645056, 'Mossy': 0.9433848, 'Neuroblast': 0.8837244, 'OL': 0.97995925, 'OPC': 0.97107685, 'Radial Glia-like': 0.92324275, 'nIPC': 0.93707705}
# Total Mean: 0.9458230137825012
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.9000034739911786, ('Neuroblast', 'Granule immature'): 0.2989589571803295, ('Granule immature', 'Granule mature'): -0.0367478434117951, ('Radial Glia-like', 'Astrocytes'): 0.8457621790459381, ('OPC', 'OL'): 0.7963321170577918}
# Total Mean: 0.5608617767726887
# # In-cluster Coherence
# {'Astrocytes': 0.87868106, 'Cajal Retzius': 0.99023134, 'Cck-Tox': 0.9759212, 'Endothelial': 0.96070784, 'GABA': 0.9559441, 'Granule immature': 0.94351035, 'Granule mature': 0.93355536, 'Microglia': 0.9645056, 'Mossy': 0.9433848, 'Neuroblast': 0.8837244, 'OL': 0.97995925, 'OPC': 0.97107685, 'Radial Glia-like': 0.92324275, 'nIPC': 0.93707705}
# Total Mean: 0.9458230137825012
# MouseBoneMarrow
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# FIT_OPTION:	2
# DENSITY:	Raw
# REORDER_CELL:	Hard
# AGGREGATE_T:	False
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 1067 highly variable genes.
# Computing moments for 1067 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 464 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 439 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 439 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 51.514, (Spliced): 24.657, (Unspliced): 26.857: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [08:08<00:00, 23.88it/s]
# Loss (Total): 51.514, (Spliced): 24.657, (Unspliced): 26.857: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [08:18<00:00, 24.09it/s]
# Total loss 51.514, vgene loss 51.514
#   0%|          | 0/2600 [00:00<?, ?cells/s]
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): 0.5266904815175399, ('progenitors', 'activating'): 0.759179255154468}
# Total Mean: 0.642934868336004
# # In-cluster Coherence
# {'B cell lineage': 0.97952294, 'activating': 0.9718575, 'dividing': 0.96888167, 'macrophages': 0.97309875, 'progenitors': 0.9691491}
# Total Mean: 0.9725019335746765
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): 0.5266904815175399, ('progenitors', 'activating'): 0.759179255154468}
# Total Mean: 0.642934868336004
# # In-cluster Coherence
# {'B cell lineage': 0.97952294, 'activating': 0.9718575, 'dividing': 0.96888167, 'macrophages': 0.97309875, 'progenitors': 0.9691491}
# Total Mean: 0.9725019335746765
# HumanBoneMarrow
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# FIT_OPTION:	2
# DENSITY:	Raw
# REORDER_CELL:	Hard
# AGGREGATE_T:	False
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 2881 highly variable genes.
# Computing moments for 2881 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 671 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 573 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 572 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 622.450, (Spliced): 391.193, (Unspliced): 231.256:  32%|█████████████████████████████████████████                                                                                         | 3795/12000 [18:17<43:50,  3.12it/s]
