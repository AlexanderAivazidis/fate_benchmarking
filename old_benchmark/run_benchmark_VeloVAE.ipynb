# %%
import anndata
import numpy as np
import scvelo as scv
import scanpy as sc
import sys
import torch
import os.path
sys.path.append('/nfs/team283/aa16/VeloVAE/')
import velovae as vv
import pickle as pickle
from eval_utils import cross_boundary_correctness
import matplotlib.pyplot as plt
import pandas as pd
import unitvelo as utv
from os.path import exists
method = 'VeloVAE'
# Out:
# 2023-05-18 16:32:55.039244: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-18 16:33:26.976724: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /software/gcc-8.2.0/lib64/
# 2023-05-18 16:33:26.978990: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /software/gcc-8.2.0/lib64/
# 2023-05-18 16:33:26.979005: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (Running UniTVelo 0.2.5)
# 2023-05-18 15:34:06

# %%
datasets = ['Pancreas_with_cc', 'HumanBoneMarrow', 'HumanDevelopingBrain', 'DentateGyrus' , 'MouseBoneMarrow', 'MouseErythroid']
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'

# %%
for dataset in datasets:
    print(dataset)
    adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
    scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=3000)
    scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
    torch.manual_seed(2022)
    np.random.seed(2022)
    full_vb = vv.VAEFullVB(adata, tmax=20, dim_z=5, device='cuda:0')
    full_vb.train(adata, plot=True, embed="umap")
    scv.pp.neighbors(adata)
    scv.tl.velocity_graph(adata, vkey = 'velocity')
    scv.tl.velocity_embedding(adata, vkey = 'velocity')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_VeloVAE.svg')
    # Calculate performance metrics:
    file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
    ground_truth = pickle.load(file)
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_CBDC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_CBDC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(metrics['Cross-Boundary Direction Correctness (A->B)'].keys()) + ['Mean'],
                 index = [method])
    cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
    tab.loc[method,:] = cb_score + [np.mean(cb_score)]
    tab.to_csv(save_dir + dataset + '_CBDC_scores.csv')
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_ICC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_ICC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(np.unique(np.concatenate(ground_truth))) + ['Mean'],
                 index = [method])
    icc_score = [np.mean(metrics['In-cluster Coherence'][x]) for x in np.unique(np.concatenate(ground_truth))]
    tab.loc[method,:] = icc_score + [np.mean(icc_score)]
    tab.to_csv(save_dir + dataset + '_ICC_scores.csv')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_' + method + '.svg')
# Out:
# Pancreas_with_cc
# Filtered out 20801 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:02) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Initialization using the steady-state and dynamical models.
# Gaussian Prior.
# --------------------------- Train a VeloVAE ---------------------------
# *********        Creating Training/Validation Datasets        *********
# *********                      Finished.                      *********
# *********                 Creating optimizers                 *********
# *********                      Finished.                      *********
# *********                    Start training                   *********
# *********                      Stage  1                       *********
# Total Number of Iterations Per Epoch: 21, test iteration: 40
# Epoch 1: Train ELBO = -11456.624, Test ELBO = -271386.750, 	 Total Time =   0 h :  0 m :  4 s
# Epoch 100: Train ELBO = 2494.348, Test ELBO = 2479.693, 	 Total Time =   0 h :  0 m : 36 s
# Epoch 200: Train ELBO = 3229.354, Test ELBO = 3194.238, 	 Total Time =   0 h :  1 m :  8 s
# Epoch 300: Train ELBO = 3538.579, Test ELBO = 3486.992, 	 Total Time =   0 h :  1 m : 41 s
# Epoch 400: Train ELBO = 3660.862, Test ELBO = 3610.575, 	 Total Time =   0 h :  2 m : 13 s
# *********       Stage 1: Early Stop Triggered at epoch 465.       *********
# *********                      Stage  2                       *********
# Cell-wise KNN Estimation.
# Percentage of Invalid Sets: 0.013
# Average Set Size: 92
# Finished. Actual Time:   0 h :  0 m :  2 s
# Epoch 466: Train ELBO = 2794.077, Test ELBO = 2818.930, 	 Total Time =   0 h :  2 m : 37 s
# Epoch 500: Train ELBO = 3459.073, Test ELBO = 3407.540, 	 Total Time =   0 h :  2 m : 50 s
# Epoch 600: Train ELBO = 3511.267, Test ELBO = 3449.956, 	 Total Time =   0 h :  3 m : 27 s
# Epoch 700: Train ELBO = 3525.023, Test ELBO = 3473.449, 	 Total Time =   0 h :  4 m :  4 s
# Epoch 800: Train ELBO = 3559.739, Test ELBO = 3487.357, 	 Total Time =   0 h :  4 m : 42 s
# Epoch 900: Train ELBO = 3561.892, Test ELBO = 3512.025, 	 Total Time =   0 h :  5 m : 19 s
# Epoch 1000: Train ELBO = 3565.651, Test ELBO = 3534.937, 	 Total Time =   0 h :  5 m : 57 s
# *********       Stage 2: Early Stop Triggered at epoch 1018.       *********
# *********              Finished. Total Time =   0 h :  6 m :  3 s             *********
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocities
#     finished (0:00:01) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/3696 [00:00<?, ?cells/s]
#     finished (0:00:09) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.7548121836112325, ('Pre-endocrine', 'Alpha'): 0.7472064317422354, ('Pre-endocrine', 'Beta'): 0.8230331182765594, ('Pre-endocrine', 'Delta'): 0.525271277801291, ('Pre-endocrine', 'Epsilon'): -0.050905565492092235}
# Total Mean: 0.5598834891878453
# # In-cluster Coherence
# {'Alpha': 0.74785024, 'Beta': 0.7475013, 'Delta': 0.8006084, 'Ductal': 0.9700656, 'Epsilon': 0.8516652, 'Ngn3 high EP': 0.954702, 'Ngn3 low EP': 0.97477216, 'Pre-endocrine': 0.8249896}
# Total Mean: 0.8590192794799805
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.7548121836112325, ('Pre-endocrine', 'Alpha'): 0.7472064317422354, ('Pre-endocrine', 'Beta'): 0.8230331182765594, ('Pre-endocrine', 'Delta'): 0.525271277801291, ('Pre-endocrine', 'Epsilon'): -0.050905565492092235}
# Total Mean: 0.5598834891878453
# # In-cluster Coherence
# {'Alpha': 0.74785024, 'Beta': 0.7475013, 'Delta': 0.8006084, 'Ductal': 0.9700656, 'Epsilon': 0.8516652, 'Ngn3 high EP': 0.954702, 'Ngn3 low EP': 0.97477216, 'Pre-endocrine': 0.8249896}
# Total Mean: 0.8590192794799805
# HumanBoneMarrow
# Filtered out 7837 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:01) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Initialization using the steady-state and dynamical models.
# Gaussian Prior.
# --------------------------- Train a VeloVAE ---------------------------
# *********        Creating Training/Validation Datasets        *********
# *********                      Finished.                      *********
# *********                 Creating optimizers                 *********
# *********                      Finished.                      *********
# *********                    Start training                   *********
# *********                      Stage  1                       *********
# Total Number of Iterations Per Epoch: 32, test iteration: 62
# Epoch 1: Train ELBO = -33230.742, Test ELBO = -105208.016, 	 Total Time =   0 h :  0 m :  0 s
# Epoch 100: Train ELBO = 4341.698, Test ELBO = 4272.304, 	 Total Time =   0 h :  0 m : 49 s
# Epoch 200: Train ELBO = 5008.052, Test ELBO = 4965.147, 	 Total Time =   0 h :  1 m : 39 s
# Epoch 300: Train ELBO = 5183.169, Test ELBO = 5128.876, 	 Total Time =   0 h :  2 m : 28 s
# *********       Stage 1: Early Stop Triggered at epoch 320.       *********
# *********                      Stage  2                       *********
# Cell-wise KNN Estimation.
# Percentage of Invalid Sets: 0.046
# Average Set Size: 203
# Finished. Actual Time:   0 h :  0 m :  4 s
# Epoch 321: Train ELBO = 4200.551, Test ELBO = 2384.324, 	 Total Time =   0 h :  2 m : 43 s
# *********       Stage 2: Early Stop Triggered at epoch 379.       *********
# *********              Finished. Total Time =   0 h :  3 m : 15 s             *********
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocities
#     finished (0:00:01) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/5780 [00:00<?, ?cells/s]
#     finished (0:00:09) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): -0.8567777274000209, ('HSC_1', 'HSC_2'): -0.6839699164635008, ('Ery_1', 'Ery_2'): -0.8867338594018059}
# Total Mean: -0.8091605010884425
# # In-cluster Coherence
# {'CLP': 0.7796601, 'DCs': 0.92648524, 'Ery_1': 0.9244903, 'Ery_2': 0.96245855, 'HSC_1': 0.77700365, 'HSC_2': 0.8506395, 'Mega': 0.93734086, 'Mono_1': 0.8964683, 'Mono_2': 0.911337, 'Precursors': 0.895109}
# Total Mean: 0.8860992193222046
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): -0.8567777274000209, ('HSC_1', 'HSC_2'): -0.6839699164635008, ('Ery_1', 'Ery_2'): -0.8867338594018059}
# Total Mean: -0.8091605010884425
# # In-cluster Coherence
# {'CLP': 0.7796601, 'DCs': 0.92648524, 'Ery_1': 0.9244903, 'Ery_2': 0.96245855, 'HSC_1': 0.77700365, 'HSC_2': 0.8506395, 'Mega': 0.93734086, 'Mono_1': 0.8964683, 'Mono_2': 0.911337, 'Precursors': 0.895109}
# Total Mean: 0.8860992193222046
# HumanDevelopingBrain
# Filtered out 17336 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
#     finished (0:00:14) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:03) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Initialization using the steady-state and dynamical models.
# Gaussian Prior.
# --------------------------- Train a VeloVAE ---------------------------
# *********        Creating Training/Validation Datasets        *********
# *********                      Finished.                      *********
# *********                 Creating optimizers                 *********
# *********                      Finished.                      *********
# *********                    Start training                   *********
# *********                      Stage  1                       *********
# Total Number of Iterations Per Epoch: 52, test iteration: 102
# Epoch 1: Train ELBO = -1839.047, Test ELBO = -30253.189, 	 Total Time =   0 h :  0 m :  1 s
# Epoch 100: Train ELBO = 5580.769, Test ELBO = 5545.709, 	 Total Time =   0 h :  1 m : 18 s
# Epoch 200: Train ELBO = 5742.175, Test ELBO = 5706.321, 	 Total Time =   0 h :  2 m : 38 s
# *********       Stage 1: Early Stop Triggered at epoch 205.       *********
# *********                      Stage  2                       *********
# Cell-wise KNN Estimation.
# Percentage of Invalid Sets: 0.015
# Average Set Size: 309
# Finished. Actual Time:   0 h :  0 m :  7 s
# Epoch 206: Train ELBO = 5636.473, Test ELBO = 5452.002, 	 Total Time =   0 h :  2 m : 51 s
# *********       Stage 2: Early Stop Triggered at epoch 221.       *********
# *********              Finished. Total Time =   0 h :  3 m :  4 s             *********
# computing neighbors
#     finished (0:00:02) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocities
#     finished (0:00:02) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/9443 [00:00<?, ?cells/s]
#     finished (0:00:12) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('Radial Glia', 'Intermediate \n Progenitor'): 0.1737542737524497, ('Intermediate \n Progenitor', 'Newborn \n Excitatory Neuron'): 0.20577552702042293, ('Newborn \n Excitatory Neuron', 'Immature \n Excitatory Neuron'): -0.07682118364961112, ('Immature \n Excitatory Neuron', 'Mature \n Excitatory Neuron'): -0.4962850717335803}
# Total Mean: -0.04839411365257969
# # In-cluster Coherence
# {'Immature \n Excitatory Neuron': 0.7528221, 'Intermediate \n Progenitor': 0.8138644, 'Mature \n Excitatory Neuron': 0.7634914, 'Newborn \n Excitatory Neuron': 0.8205247, 'Radial Glia': 0.8316763}
# Total Mean: 0.7964757680892944
# # Cross-Boundary Direction Correctness (A->B)
# {('Radial Glia', 'Intermediate \n Progenitor'): 0.1737542737524497, ('Intermediate \n Progenitor', 'Newborn \n Excitatory Neuron'): 0.20577552702042293, ('Newborn \n Excitatory Neuron', 'Immature \n Excitatory Neuron'): -0.07682118364961112, ('Immature \n Excitatory Neuron', 'Mature \n Excitatory Neuron'): -0.4962850717335803}
# Total Mean: -0.04839411365257969
# # In-cluster Coherence
# {'Immature \n Excitatory Neuron': 0.7528221, 'Intermediate \n Progenitor': 0.8138644, 'Mature \n Excitatory Neuron': 0.7634914, 'Newborn \n Excitatory Neuron': 0.8205247, 'Radial Glia': 0.8316763}
# Total Mean: 0.7964757680892944
# DentateGyrus
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Initialization using the steady-state and dynamical models.
# Gaussian Prior.
# --------------------------- Train a VeloVAE ---------------------------
# *********        Creating Training/Validation Datasets        *********
# *********                      Finished.                      *********
# *********                 Creating optimizers                 *********
# *********                      Finished.                      *********
# *********                    Start training                   *********
# *********                      Stage  1                       *********
# Total Number of Iterations Per Epoch: 17, test iteration: 32
# Epoch 1: Train ELBO = -640485.938, Test ELBO = -2040021.125, 	 Total Time =   0 h :  0 m :  0 s
# Epoch 100: Train ELBO = -23307.297, Test ELBO = -25604.689, 	 Total Time =   0 h :  0 m : 27 s
# *********       Stage 1: Early Stop Triggered at epoch 100.       *********
# *********                      Stage  2                       *********
# Cell-wise KNN Estimation.
# Percentage of Invalid Sets: 0.076
# Average Set Size: 1
# Finished. Actual Time:   0 h :  0 m :  0 s
# Epoch 101: Train ELBO = -741629.750, Test ELBO = -736823.375, 	 Total Time =   0 h :  0 m : 28 s
# Epoch 200: Train ELBO = -1114.435, Test ELBO = -257.499, 	 Total Time =   0 h :  0 m : 56 s
# Epoch 300: Train ELBO = -34.405, Test ELBO = -28.975, 	 Total Time =   0 h :  1 m : 25 s
# Epoch 400: Train ELBO = 204.075, Test ELBO = 305.208, 	 Total Time =   0 h :  1 m : 53 s
# Epoch 500: Train ELBO = 752.042, Test ELBO = 1281.866, 	 Total Time =   0 h :  2 m : 22 s
# Epoch 600: Train ELBO = 431.895, Test ELBO = 1097.772, 	 Total Time =   0 h :  2 m : 50 s
# *********       Stage 2: Early Stop Triggered at epoch 660.       *********
# *********              Finished. Total Time =   0 h :  3 m :  7 s             *********
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/2930 [00:00<?, ?cells/s]
#     finished (0:00:04) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.9003700984438958, ('Neuroblast', 'Granule immature'): 0.58749646280691, ('Granule immature', 'Granule mature'): 0.02174907240346548, ('Radial Glia-like', 'Astrocytes'): 0.8546097796145873, ('OPC', 'OL'): -0.8340557374351435}
# Total Mean: 0.30603393516674304
# # In-cluster Coherence
# {'Astrocytes': 0.85087585, 'Cajal Retzius': 0.9856573, 'Cck-Tox': 0.9375297, 'Endothelial': 0.9448638, 'GABA': 0.910822, 'Granule immature': 0.83902454, 'Granule mature': 0.7975912, 'Microglia': 0.97058135, 'Mossy': 0.90160036, 'Neuroblast': 0.92450315, 'OL': 0.9506559, 'OPC': 0.9175724, 'Radial Glia-like': 0.8933756, 'nIPC': 0.9384544}
# Total Mean: 0.911650538444519
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.9003700984438958, ('Neuroblast', 'Granule immature'): 0.58749646280691, ('Granule immature', 'Granule mature'): 0.02174907240346548, ('Radial Glia-like', 'Astrocytes'): 0.8546097796145873, ('OPC', 'OL'): -0.8340557374351435}
# Total Mean: 0.30603393516674304
# # In-cluster Coherence
# {'Astrocytes': 0.85087585, 'Cajal Retzius': 0.9856573, 'Cck-Tox': 0.9375297, 'Endothelial': 0.9448638, 'GABA': 0.910822, 'Granule immature': 0.83902454, 'Granule mature': 0.7975912, 'Microglia': 0.97058135, 'Mossy': 0.90160036, 'Neuroblast': 0.92450315, 'OL': 0.9506559, 'OPC': 0.9175724, 'Radial Glia-like': 0.8933756, 'nIPC': 0.9384544}
# Total Mean: 0.911650538444519
# MouseBoneMarrow
# Filtered out 20300 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Initialization using the steady-state and dynamical models.
# Gaussian Prior.
# --------------------------- Train a VeloVAE ---------------------------
# *********        Creating Training/Validation Datasets        *********
# *********                      Finished.                      *********
# *********                 Creating optimizers                 *********
# *********                      Finished.                      *********
# *********                    Start training                   *********
# *********                      Stage  1                       *********
# Total Number of Iterations Per Epoch: 15, test iteration: 28
# Epoch 1: Train ELBO = -12441.779, Test ELBO = -539719.750, 	 Total Time =   0 h :  0 m :  0 s
# Epoch 100: Train ELBO = 1199.280, Test ELBO = 1165.358, 	 Total Time =   0 h :  0 m : 20 s
# Epoch 200: Train ELBO = 1469.045, Test ELBO = 1428.328, 	 Total Time =   0 h :  0 m : 40 s
# Epoch 300: Train ELBO = 1648.551, Test ELBO = 1611.199, 	 Total Time =   0 h :  1 m :  0 s
# Epoch 400: Train ELBO = 1757.869, Test ELBO = 1719.056, 	 Total Time =   0 h :  1 m : 20 s
# Epoch 500: Train ELBO = 1786.305, Test ELBO = 1759.139, 	 Total Time =   0 h :  1 m : 40 s
# Epoch 600: Train ELBO = 1825.537, Test ELBO = 1790.569, 	 Total Time =   0 h :  2 m :  0 s
# *********       Stage 1: Early Stop Triggered at epoch 676.       *********
# *********                      Stage  2                       *********
# Cell-wise KNN Estimation.
# Percentage of Invalid Sets: 0.028
# Average Set Size: 65
# Finished. Actual Time:   0 h :  0 m :  1 s
# Epoch 677: Train ELBO = 1787.301, Test ELBO = 1761.784, 	 Total Time =   0 h :  2 m : 17 s
# Epoch 700: Train ELBO = 1816.853, Test ELBO = 1783.715, 	 Total Time =   0 h :  2 m : 22 s
# *********       Stage 2: Early Stop Triggered at epoch 705.       *********
# *********              Finished. Total Time =   0 h :  2 m : 23 s             *********
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/2600 [00:00<?, ?cells/s]
#     finished (0:00:02) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): 0.4903427928977974, ('progenitors', 'activating'): 0.746371869635889}
# Total Mean: 0.6183573312668432
# # In-cluster Coherence
# {'B cell lineage': 0.7826184, 'activating': 0.6939748, 'dividing': 0.70322484, 'macrophages': 0.70824033, 'progenitors': 0.6754519}
# Total Mean: 0.7127020955085754
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): 0.4903427928977974, ('progenitors', 'activating'): 0.746371869635889}
# Total Mean: 0.6183573312668432
# # In-cluster Coherence
# {'B cell lineage': 0.7826184, 'activating': 0.6939748, 'dividing': 0.70322484, 'macrophages': 0.70824033, 'progenitors': 0.6754519}
# Total Mean: 0.7127020955085754
# MouseErythroid
# Filtered out 47456 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:02) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:02) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Initialization using the steady-state and dynamical models.
# Gaussian Prior.
# --------------------------- Train a VeloVAE ---------------------------
# *********        Creating Training/Validation Datasets        *********
# *********                      Finished.                      *********
# *********                 Creating optimizers                 *********
# *********                      Finished.                      *********
# *********                    Start training                   *********
# *********                      Stage  1                       *********
# Total Number of Iterations Per Epoch: 54, test iteration: 106
# Epoch 1: Train ELBO = -5198.990, Test ELBO = -710268.875, 	 Total Time =   0 h :  0 m :  1 s
# Epoch 100: Train ELBO = 2885.750, Test ELBO = 2849.776, 	 Total Time =   0 h :  1 m : 25 s
# Epoch 200: Train ELBO = 3022.861, Test ELBO = 3019.004, 	 Total Time =   0 h :  2 m : 51 s
# *********       Stage 1: Early Stop Triggered at epoch 236.       *********
# *********                      Stage  2                       *********
# Cell-wise KNN Estimation.
# Percentage of Invalid Sets: 0.004
# Average Set Size: 207
# Finished. Actual Time:   0 h :  0 m :  7 s
# Epoch 237: Train ELBO = 2910.209, Test ELBO = 2535.164, 	 Total Time =   0 h :  3 m : 29 s
# Epoch 300: Train ELBO = 3013.839, Test ELBO = 2988.081, 	 Total Time =   0 h :  4 m : 30 s
# *********       Stage 2: Early Stop Triggered at epoch 303.       *********
# *********              Finished. Total Time =   0 h :  4 m : 32 s             *********
# computing neighbors
#     finished (0:00:02) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocities
#     finished (0:00:02) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/64 cores)
#   0%|          | 0/9815 [00:00<?, ?cells/s]
#     finished (0:00:10) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.4143223510967928, ('Blood progenitors 2', 'Erythroid1'): 0.24962148183575375, ('Erythroid1', 'Erythroid2'): 0.2391521645082725, ('Erythroid2', 'Erythroid3'): -0.46603091358517107}
# Total Mean: 0.10926627096391199
# # In-cluster Coherence
# {'Blood progenitors 1': 0.80518085, 'Blood progenitors 2': 0.7254092, 'Erythroid1': 0.67482334, 'Erythroid2': 0.68407726, 'Erythroid3': 0.8362193}
# Total Mean: 0.7451419830322266
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.4143223510967928, ('Blood progenitors 2', 'Erythroid1'): 0.24962148183575375, ('Erythroid1', 'Erythroid2'): 0.2391521645082725, ('Erythroid2', 'Erythroid3'): -0.46603091358517107}
# Total Mean: 0.10926627096391199
# # In-cluster Coherence
# {'Blood progenitors 1': 0.80518085, 'Blood progenitors 2': 0.7254092, 'Erythroid1': 0.67482334, 'Erythroid2': 0.68407726, 'Erythroid3': 0.8362193}
# Total Mean: 0.7451419830322266
