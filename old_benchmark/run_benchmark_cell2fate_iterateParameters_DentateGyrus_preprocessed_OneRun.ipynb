# %%
import scvelo as scv
import scanpy as sc
import cell2fate as c2f
import pickle as pickle
from eval_utils import cross_boundary_correctness
from datetime import datetime
import pandas as pd
import numpy as np
from os.path import exists
import matplotlib.pyplot as plt
import torch
import unitvelo as utv
import torch
method = 'cell2fate'
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'
dataset = 'DentateGyrus'
n_genes_list = np.array((2000, 3000))
n_counts_list = np.array((20, 10))
# Model params:
mod_list = [0.5, 1, 1.5, 2.0]

def robust_optimization(mod, save_dir, max_epochs = [200, 400], lr = [0.01, 0.01], **model_kwargs):
    n_modules = mod.module.model.n_modules
    adata = mod.adata
    print('First optimization run.')
    mod.train(use_gpu=True, max_epochs = max_epochs[0], lr = lr[0])
    sample_kwarg = {"num_samples": 1, "batch_size" : 1000,
                     "use_gpu" : True, 'return_samples': False}
    mod.adata = mod.export_posterior(mod.adata, sample_kwargs=sample_kwarg)
    t_c = np.argsort(np.array(mod.samples['post_sample_means']['t_c']).flatten())/len(np.array(mod.samples['post_sample_means']['t_c']))
    t_c_reversed = -1*(t_c - np.max(t_c))
    print('Second optimization run.')
    del mod
    mod1 = c2f.Cell2fate_DynamicalModel_PreprocessedCounts(adata, n_modules = n_modules,
                                        init_vals = {'t_c': torch.tensor(t_c).reshape([len(t_c), 1, 1])},
                                       **model_kwargs)
    mod1.train(use_gpu=True, max_epochs = max_epochs[1], lr = lr[1])
    history1 = mod1.history
    mod1.save(save_dir+'c2f_model', overwrite=True)
    mod1.adata.write(save_dir+"c2f_model_anndata.h5ad")
    del mod1
    print('Third optimization run.')
    mod2 = c2f.Cell2fate_DynamicalModel_PreprocessedCounts(adata, n_modules = n_modules,
                                        init_vals = {'t_c': torch.tensor(t_c_reversed).reshape([len(t_c_reversed), 1, 1])},
                                        **model_kwargs)
    del adata
    mod2.train(use_gpu=True, max_epochs = max_epochs[1], lr = lr[1])
    history2 = mod2.history

    iter_start=0
    iter_end=-1

    fig, ax = plt.subplots(1,2, figsize = (15,5))

    iter_end = len(history1["elbo_train"])

    ax[0].plot(
        history1["elbo_train"].index[iter_start:iter_end],
        np.array(history1["elbo_train"].values.flatten())[iter_start:iter_end],
        label="Original Direction",
    )
    ax[0].plot(
        history2["elbo_train"].index[iter_start:iter_end],
        np.array(history2["elbo_train"].values.flatten())[iter_start:iter_end],
        label="Reversed Direction",
    )
    ax[0].legend()
    ax[0].set_xlim(0, len(history1["elbo_train"]))
    ax[0].set_xlabel("Training epochs")
    ax[0].set_ylabel("-ELBO loss")

    ax[1].plot(
        history1["elbo_train"].index[iter_start:iter_end],
        np.array(history1["elbo_train"].values.flatten())[iter_start:iter_end],
        label="Original Direction",
    )
    ax[1].plot(
        history2["elbo_train"].index[iter_start:iter_end],
        np.array(history2["elbo_train"].values.flatten())[iter_start:iter_end],
        label="Reversed Direction",
    )
    ax[1].legend()
    ax[1].set_xlim(np.round(0.8*len(history1["elbo_train"])), len(history1["elbo_train"]))
    ax[1].set_xlabel("Training epochs")
    ax[1].set_ylabel("-ELBO loss")
    plt.tight_layout()
    plt.show()
    
    print('-ELBO second run:', np.mean(np.array(history1['elbo_train'][-50:])))
    print('-ELBO third run:', np.mean(np.array(history2['elbo_train'][-50:])))
    
    if np.mean(np.array(history1['elbo_train'][-50:])) > np.mean(np.array(history2['elbo_train'][-50:])):
        return mod2
    else:
        del mod2
        adata = sc.read_h5ad(save_dir+"c2f_model_anndata.h5ad")
        mod1 = c2f.Cell2fate_DynamicalModel_PreprocessedCounts.load(save_dir+'c2f_model', adata)
        return mod1 

for i in range(len(n_genes_list)):
    for j in range(len(n_counts_list)):
        for k in range(len(mod_list)):
                print(i)
                print(j)
                print(k)
                n_genes = n_genes_list[i]
                min_counts = n_counts_list[j]
                model_index = str(i) + '-' + str(j) + '-' + str(k)
                save_name = method + '_' + dataset
                if exists(save_dir + save_name + '_CBDC_And_Posterior_withBatch_preprocessed_oneRun.csv'):
                    tab = pd.read_csv(save_dir + save_name + '_CBDC_And_Posterior_withBatch_preprocessed_oneRun.csv', index_col = 0)
                    if model_index in tab.index:
                        continue
                adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
                scv.pp.filter_and_normalize(adata, min_shared_counts=min_counts, n_top_genes=n_genes)
                scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
                c2f.Cell2fate_DynamicalModel_PreprocessedCounts.setup_anndata(adata, spliced_label='spliced', unspliced_label='unspliced')    
                n_modules = int(np.round(c2f.utils.get_max_modules(adata)*mod_list[k]))
                mod = c2f.Cell2fate_DynamicalModel_PreprocessedCounts(adata,
                                                   n_modules = n_modules)   
                mod.train()
                sample_kwarg = {"num_samples": 3, "batch_size" : adata.n_obs,
                     "use_gpu" : True, 'return_samples': False}
                adata = mod.export_posterior(adata, sample_kwargs = sample_kwarg)
                mod.compute_and_plot_total_velocity_scvelo(adata, save = False, delete = False)
                # Calculate performance metrics:
                file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
                ground_truth = pickle.load(file)
                metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
                cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                            for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
                if exists(save_dir + save_name + '_CBDC_And_Posterior_withBatch_preprocessed_oneRun.csv'):
                    tab = pd.read_csv(save_dir + save_name + '_CBDC_And_Posterior_withBatch_preprocessed_oneRun.csv', index_col = 0)
                else:
                    c_names = ['CBDC']
                    tab = pd.DataFrame(columns = c_names)
                tab.loc[model_index, 'CBDC'] = np.mean(cb_score)
                tab.loc[model_index, 'splicing_alpha'] = mod.samples['post_sample_means']['splicing_alpha']
                tab.loc[model_index, 'splicing_mean'] = mod.samples['post_sample_means']['splicing_mean']
                tab.loc[model_index, 'beta_g_mean'] = np.mean(mod.samples['post_sample_means']['beta_g'])
                tab.loc[model_index, 'beta_g_var'] = np.var(mod.samples['post_sample_means']['beta_g'])
                tab.loc[model_index, 'degredation_alpha'] = mod.samples['post_sample_means']['degredation_alpha']
                tab.loc[model_index, 'degredation_mean'] = mod.samples['post_sample_means']['degredation_mean']
                tab.loc[model_index, 'gamma_g_mean'] = np.mean(mod.samples['post_sample_means']['gamma_g'])
                tab.loc[model_index, 'gamma_g_var'] = np.var(mod.samples['post_sample_means']['gamma_g'])
                tab.loc[model_index, 'factor_level_g_mean'] = np.mean(mod.samples['post_sample_means']['factor_level_g'])
                tab.loc[model_index, 'factor_level_g_var'] = np.var(mod.samples['post_sample_means']['factor_level_g'])
                tab.loc[model_index, 'g_fg_mean'] = np.mean(mod.samples['post_sample_means']['g_fg'])
                tab.loc[model_index, 'g_fg_var'] = np.var(mod.samples['post_sample_means']['g_fg'])
                tab.loc[model_index, 'A_mgON_mean'] = np.mean(mod.samples['post_sample_means']['A_mgON'])
                tab.loc[model_index, 'A_mgON_var'] = np.var(mod.samples['post_sample_means']['A_mgON'])
                tab.loc[model_index, 'lam_mu'] = mod.samples['post_sample_means']['lam_mu']
                tab.loc[model_index, 'lam_sd'] = mod.samples['post_sample_means']['lam_sd']
                tab.loc[model_index, 'lam_m_mu_mean'] = np.mean(mod.samples['post_sample_means']['lam_m_mu'])
                tab.loc[model_index, 'lam_m_mu_var'] = np.var(mod.samples['post_sample_means']['lam_m_mu'])
                tab.loc[model_index, 'lam_mi_mean'] = np.mean(mod.samples['post_sample_means']['lam_mi'])
                tab.loc[model_index, 'lam_mi_var'] = np.var(mod.samples['post_sample_means']['lam_mi'])
                tab.loc[model_index, 'Tmax'] = mod.samples['post_sample_means']['Tmax']
                tab.loc[model_index, 't_c_loc'] = mod.samples['post_sample_means']['t_c_loc']
                tab.loc[model_index, 't_c_scale'] = mod.samples['post_sample_means']['t_c_scale']
                tab.loc[model_index, 'T_c_mean'] = np.mean(mod.samples['post_sample_means']['T_c'])
                tab.loc[model_index, 'T_c_var'] = np.var(mod.samples['post_sample_means']['T_c'])
                tab.loc[model_index, 't_delta_mean'] = np.mean(mod.samples['post_sample_means']['t_delta'])
                tab.loc[model_index, 't_delta_var'] = np.var(mod.samples['post_sample_means']['t_delta'])
                tab.loc[model_index, 'T_mON_mean'] = np.mean(mod.samples['post_sample_means']['T_mON'])
                tab.loc[model_index, 'T_mON_var'] = np.var(mod.samples['post_sample_means']['T_mON'])
                tab.loc[model_index, 'T_mON_mean'] = np.mean(mod.samples['post_sample_means']['T_mON'])
                tab.loc[model_index, 'T_mON_var'] = np.var(mod.samples['post_sample_means']['T_mON'])
                tab.loc[model_index, 'T_mOFF_mean'] = np.mean(mod.samples['post_sample_means']['T_mOFF'])
                tab.loc[model_index, 'T_mOFF_var'] = np.var(mod.samples['post_sample_means']['T_mOFF'])
                tab.loc[model_index, 'mu_expression_mean'] = np.mean(mod.samples['post_sample_means']['mu_expression'])
                tab.loc[model_index, 'mu_expression_var'] = np.var(mod.samples['post_sample_means']['mu_expression'])
                tab.to_csv(save_dir + save_name + '_CBDC_And_Posterior_withBatch_preprocessed_oneRun.csv')
# Out:
# Global seed set to 0
# (Running UniTVelo 0.2.5)
# 2023-10-19 09:37:30
# 0
# 0
# 0
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:10) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 500/500: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [05:43<00:00,  1.46it/s, v_num=1, elbo_train=4.5e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.15it/s]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  5.20it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.1987673722460474, ('Neuroblast', 'Granule immature'): -0.43080654092964565, ('Granule immature', 'Granule mature'): 0.2117821777960899, ('Radial Glia-like', 'Astrocytes'): 0.8357650501594425, ('OPC', 'OL'): 0.9740525234475114}
# Total Mean: 0.3579121165438891
# # In-cluster Coherence
# {'Astrocytes': 0.8788695, 'Cajal Retzius': 0.9354688, 'Cck-Tox': 0.9332211, 'Endothelial': 0.9793113, 'GABA': 0.6506381, 'Granule immature': 0.83217084, 'Granule mature': 0.93580586, 'Microglia': 0.97877765, 'Mossy': 0.9133934, 'Neuroblast': 0.95140284, 'OL': 0.8012322, 'OPC': 0.7496549, 'Radial Glia-like': 0.9604086, 'nIPC': 0.919823}
# Total Mean: 0.8871554732322693
# 0
# 0
# 1
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [09:05<00:00,  1.09s/it, v_num=1, elbo_train=4.53e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.17s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.74it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.9132707960673287, ('Neuroblast', 'Granule immature'): -0.4515380755065389, ('Granule immature', 'Granule mature'): 0.16281502477789722, ('Radial Glia-like', 'Astrocytes'): 0.7991785422060264, ('OPC', 'OL'): -0.5616740320602125}
# Total Mean: -0.19289786733003134
# # In-cluster Coherence
# {'Astrocytes': 0.9075474, 'Cajal Retzius': 0.17238343, 'Cck-Tox': 0.96546966, 'Endothelial': 0.5760414, 'GABA': 0.8801643, 'Granule immature': 0.84220034, 'Granule mature': 0.924671, 'Microglia': 0.93464446, 'Mossy': 0.89228374, 'Neuroblast': 0.7707144, 'OL': 0.96977335, 'OPC': 0.5056657, 'Radial Glia-like': 0.8406012, 'nIPC': 0.93043566}
# Total Mean: 0.793756902217865
# 0
# 0
# 2
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [12:35<00:00,  1.51s/it, v_num=1, elbo_train=4.51e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.49s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.94it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.8832219020441184, ('Neuroblast', 'Granule immature'): -0.3667546125005019, ('Granule immature', 'Granule mature'): 0.2089989543718318, ('Radial Glia-like', 'Astrocytes'): 0.6466311022540533, ('OPC', 'OL'): 0.08161718432459511}
# Total Mean: -0.06254585471882805
# # In-cluster Coherence
# {'Astrocytes': 0.8302678, 'Cajal Retzius': 0.6789571, 'Cck-Tox': 0.90127754, 'Endothelial': 0.8153256, 'GABA': 0.69787747, 'Granule immature': 0.8407571, 'Granule mature': 0.9080904, 'Microglia': 0.7220698, 'Mossy': 0.7717295, 'Neuroblast': 0.7371691, 'OL': 0.8295899, 'OPC': 0.77676666, 'Radial Glia-like': 0.72661316, 'nIPC': 0.78436613}
# Total Mean: 0.7872040867805481
# 0
# 0
# 3
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [15:51<00:00,  1.90s/it, v_num=1, elbo_train=4.54e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.74s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.48it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.6721393364297652, ('Neuroblast', 'Granule immature'): -0.4378800095308414, ('Granule immature', 'Granule mature'): 0.1383203827785249, ('Radial Glia-like', 'Astrocytes'): 0.71710326623262, ('OPC', 'OL'): 0.9257044506325173}
# Total Mean: 0.13422175073661108
# # In-cluster Coherence
# {'Astrocytes': 0.80513537, 'Cajal Retzius': 0.8565312, 'Cck-Tox': 0.9265571, 'Endothelial': 0.83319575, 'GABA': 0.9621274, 'Granule immature': 0.90201384, 'Granule mature': 0.9553069, 'Microglia': 0.9425679, 'Mossy': 0.9726728, 'Neuroblast': 0.7260784, 'OL': 0.8784449, 'OPC': 0.8207617, 'Radial Glia-like': 0.90899724, 'nIPC': 0.6629939}
# Total Mean: 0.868098795413971
# 0
# 1
# 0
# Filtered out 9174 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 17
# Maximal Number of Modules: 19
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [05:42<00:00,  1.46it/s, v_num=1, elbo_train=3.11e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.29it/s]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  5.24it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.12134841586962956, ('Neuroblast', 'Granule immature'): -0.5142450567832778, ('Granule immature', 'Granule mature'): 0.1711466284955175, ('Radial Glia-like', 'Astrocytes'): 0.8101995075051355, ('OPC', 'OL'): -0.6186961794858666}
# Total Mean: -0.05458870322762419
# # In-cluster Coherence
# {'Astrocytes': 0.9659303, 'Cajal Retzius': 0.9594167, 'Cck-Tox': 0.80685645, 'Endothelial': 0.79747736, 'GABA': 0.6607477, 'Granule immature': 0.83717346, 'Granule mature': 0.93126845, 'Microglia': 0.9353654, 'Mossy': 0.75769955, 'Neuroblast': 0.88732713, 'OL': 0.98861414, 'OPC': 0.93516153, 'Radial Glia-like': 0.98719984, 'nIPC': 0.5399531}
# Total Mean: 0.8564421534538269
# 0
# 1
# 1
# Filtered out 9174 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 17
# Maximal Number of Modules: 19
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [08:50<00:00,  1.06s/it, v_num=1, elbo_train=3.06e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.14s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.97it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.3336353683525254, ('Neuroblast', 'Granule immature'): 0.3553057870762185, ('Granule immature', 'Granule mature'): 0.14281003931407696, ('Radial Glia-like', 'Astrocytes'): 0.538608105541866, ('OPC', 'OL'): 0.9151715249328071}
# Total Mean: 0.45710616504349877
# # In-cluster Coherence
# {'Astrocytes': 0.95175666, 'Cajal Retzius': 0.9705133, 'Cck-Tox': 0.85110086, 'Endothelial': 0.7401371, 'GABA': 0.6482403, 'Granule immature': 0.64919907, 'Granule mature': 0.8492217, 'Microglia': 0.7156315, 'Mossy': 0.8340272, 'Neuroblast': 0.46157065, 'OL': 0.93488556, 'OPC': 0.7752731, 'Radial Glia-like': 0.89429057, 'nIPC': 0.9870909}
# Total Mean: 0.8044956922531128
# 0
# 1
# 2
# Filtered out 9174 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 17
# Maximal Number of Modules: 19
# Epoch 500/500: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [11:55<00:00,  1.43s/it, v_num=1, elbo_train=3.1e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.43s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.07it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.896586325512164, ('Neuroblast', 'Granule immature'): -0.4917553786639203, ('Granule immature', 'Granule mature'): 0.2042083062295984, ('Radial Glia-like', 'Astrocytes'): 0.7949264489675587, ('OPC', 'OL'): -0.4535066580774532}
# Total Mean: -0.16854272141127602
# # In-cluster Coherence
# {'Astrocytes': 0.9293633, 'Cajal Retzius': 0.301906, 'Cck-Tox': 0.8973833, 'Endothelial': 0.7600501, 'GABA': 0.6237596, 'Granule immature': 0.78823227, 'Granule mature': 0.7984147, 'Microglia': 0.8681601, 'Mossy': 0.6993377, 'Neuroblast': 0.7616934, 'OL': 0.9734204, 'OPC': 0.6981474, 'Radial Glia-like': 0.6188721, 'nIPC': 0.67054707}
# Total Mean: 0.7420920133590698
# 0
# 1
# 3
# Filtered out 9174 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 17
# Maximal Number of Modules: 19
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [15:02<00:00,  1.81s/it, v_num=1, elbo_train=3.14e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.69s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.58it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.6976801887589614, ('Neuroblast', 'Granule immature'): 0.4592072952403358, ('Granule immature', 'Granule mature'): -0.14051867661699685, ('Radial Glia-like', 'Astrocytes'): 0.8143998468768044, ('OPC', 'OL'): -0.7957092096647107}
# Total Mean: -0.07206018658470574
# # In-cluster Coherence
# {'Astrocytes': 0.8406208, 'Cajal Retzius': 0.9442787, 'Cck-Tox': 0.91585463, 'Endothelial': 0.5519962, 'GABA': 0.8433283, 'Granule immature': 0.92708546, 'Granule mature': 0.94256675, 'Microglia': 0.8488826, 'Mossy': 0.92344475, 'Neuroblast': 0.96290934, 'OL': 0.5101162, 'OPC': 0.57074386, 'Radial Glia-like': 0.9293777, 'nIPC': 0.79861647}
# Total Mean: 0.8221301436424255
# 1
# 0
# 0
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [05:46<00:00,  1.44it/s, v_num=1, elbo_train=5.62e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.22s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.70it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): 0.0751276037857888, ('Neuroblast', 'Granule immature'): -0.4526703441854559, ('Granule immature', 'Granule mature'): 0.19460153010077208, ('Radial Glia-like', 'Astrocytes'): 0.6824093368620714, ('OPC', 'OL'): 0.9541830047313747}
# Total Mean: 0.2907302262589102
# # In-cluster Coherence
# {'Astrocytes': 0.8551355, 'Cajal Retzius': 0.8975884, 'Cck-Tox': 0.8955051, 'Endothelial': 0.954951, 'GABA': 0.6743707, 'Granule immature': 0.88242686, 'Granule mature': 0.9357398, 'Microglia': 0.9833457, 'Mossy': 0.8800396, 'Neuroblast': 0.9400269, 'OL': 0.9731058, 'OPC': 0.65778315, 'Radial Glia-like': 0.629462, 'nIPC': 0.7105865}
# Total Mean: 0.8478619456291199
# 1
# 0
# 1
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [09:12<00:00,  1.11s/it, v_num=1, elbo_train=5.64e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.69s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.65it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.914378229574403, ('Neuroblast', 'Granule immature'): -0.45516394799248083, ('Granule immature', 'Granule mature'): 0.20867128114615, ('Radial Glia-like', 'Astrocytes'): 0.7877009122557816, ('OPC', 'OL'): -0.34892094859531725}
# Total Mean: -0.1444181865520539
# # In-cluster Coherence
# {'Astrocytes': 0.9181068, 'Cajal Retzius': 0.9337202, 'Cck-Tox': 0.86320657, 'Endothelial': 0.6918415, 'GABA': 0.65279394, 'Granule immature': 0.7462375, 'Granule mature': 0.7726428, 'Microglia': 0.9185595, 'Mossy': 0.75508565, 'Neuroblast': 0.7848537, 'OL': 0.9895211, 'OPC': 0.29639676, 'Radial Glia-like': 0.8837785, 'nIPC': 0.8417949}
# Total Mean: 0.7891813516616821
# 1
# 0
# 2
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [12:41<00:00,  1.52s/it, v_num=1, elbo_train=5.74e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.13s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.07it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.9118308987761404, ('Neuroblast', 'Granule immature'): -0.4379945227695684, ('Granule immature', 'Granule mature'): 0.20047949771240434, ('Radial Glia-like', 'Astrocytes'): 0.7921403704686085, ('OPC', 'OL'): -0.13603416574483682}
# Total Mean: -0.09864794382190659
# # In-cluster Coherence
# {'Astrocytes': 0.8390181, 'Cajal Retzius': 0.36807138, 'Cck-Tox': 0.7815189, 'Endothelial': 0.8906307, 'GABA': 0.8435237, 'Granule immature': 0.9249479, 'Granule mature': 0.9707069, 'Microglia': 0.7033506, 'Mossy': 0.7467106, 'Neuroblast': 0.72363645, 'OL': 0.94454795, 'OPC': 0.32704994, 'Radial Glia-like': 0.8547673, 'nIPC': 0.94112486}
# Total Mean: 0.7756862044334412
# 1
# 0
# 3
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [15:55<00:00,  1.91s/it, v_num=1, elbo_train=5.73e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.52s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.74it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.31396659080885003, ('Neuroblast', 'Granule immature'): -0.41944759015522176, ('Granule immature', 'Granule mature'): 0.20377749585125318, ('Radial Glia-like', 'Astrocytes'): 0.6700647969436183, ('OPC', 'OL'): -0.960189590808279}
# Total Mean: -0.16395229579549586
# # In-cluster Coherence
# {'Astrocytes': 0.93770814, 'Cajal Retzius': 0.87761694, 'Cck-Tox': 0.9464084, 'Endothelial': 0.7167066, 'GABA': 0.7933749, 'Granule immature': 0.92515427, 'Granule mature': 0.96849763, 'Microglia': 0.90863997, 'Mossy': 0.8241082, 'Neuroblast': 0.84269017, 'OL': 0.2842735, 'OPC': 0.59519887, 'Radial Glia-like': 0.8728043, 'nIPC': 0.78339314}
# Total Mean: 0.8054696321487427
# 1
# 1
# 0
# Filtered out 9174 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [05:46<00:00,  1.44it/s, v_num=1, elbo_train=3.61e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.22s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.70it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.5193154614555683, ('Neuroblast', 'Granule immature'): -0.5503881438838905, ('Granule immature', 'Granule mature'): 0.17987651065288995, ('Radial Glia-like', 'Astrocytes'): 0.864779854795553, ('OPC', 'OL'): -0.7186871296301542}
# Total Mean: -0.148746873904234
# # In-cluster Coherence
# {'Astrocytes': 0.9622434, 'Cajal Retzius': 0.9759324, 'Cck-Tox': 0.7852346, 'Endothelial': 0.9913903, 'GABA': 0.8052478, 'Granule immature': 0.9234736, 'Granule mature': 0.9817817, 'Microglia': 0.98526, 'Mossy': 0.8062379, 'Neuroblast': 0.95363843, 'OL': 0.91969657, 'OPC': 0.99156326, 'Radial Glia-like': 0.9837885, 'nIPC': 0.45652705}
# Total Mean: 0.894429624080658
# 1
# 1
# 1
# Filtered out 9174 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [09:17<00:00,  1.11s/it, v_num=1, elbo_train=3.59e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.68s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.64it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.8724325272620798, ('Neuroblast', 'Granule immature'): -0.5523133002889863, ('Granule immature', 'Granule mature'): 0.17404643867986044, ('Radial Glia-like', 'Astrocytes'): 0.8566038877111062, ('OPC', 'OL'): -0.3542947673559894}
# Total Mean: -0.1496780537032178
# # In-cluster Coherence
# {'Astrocytes': 0.9230461, 'Cajal Retzius': 0.77165717, 'Cck-Tox': 0.9428847, 'Endothelial': 0.6759462, 'GABA': 0.7736031, 'Granule immature': 0.7701648, 'Granule mature': 0.8448054, 'Microglia': 0.9635977, 'Mossy': 0.78836685, 'Neuroblast': 0.784248, 'OL': 0.9867756, 'OPC': 0.4961617, 'Radial Glia-like': 0.87474006, 'nIPC': 0.864614}
# Total Mean: 0.8186150789260864
# 1
# 1
# 2
# Filtered out 9174 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [12:42<00:00,  1.52s/it, v_num=1, elbo_train=3.57e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.11s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.10it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.8985606160317539, ('Neuroblast', 'Granule immature'): -0.527238783692963, ('Granule immature', 'Granule mature'): 0.1668064723972214, ('Radial Glia-like', 'Astrocytes'): 0.751967275216863, ('OPC', 'OL'): 0.6106950669333768}
# Total Mean: 0.020733882964548856
# # In-cluster Coherence
# {'Astrocytes': 0.7576758, 'Cajal Retzius': 0.8592417, 'Cck-Tox': 0.7747463, 'Endothelial': 0.9007579, 'GABA': 0.8695682, 'Granule immature': 0.8460297, 'Granule mature': 0.9060442, 'Microglia': 0.8562906, 'Mossy': 0.7999062, 'Neuroblast': 0.74550986, 'OL': 0.64498216, 'OPC': 0.7198512, 'Radial Glia-like': 0.9158147, 'nIPC': 0.7543216}
# Total Mean: 0.8107671737670898
# 1
# 1
# 3
# Filtered out 9174 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# Leiden clustering ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of Leiden Clusters: 18
# Maximal Number of Modules: 20
# Epoch 500/500: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [15:55<00:00,  1.91s/it, v_num=1, elbo_train=3.64e+6]
# sample_kwargs['batch_size'] 2930
# Sampling local variables, batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.56s/it]
# Sampling global variables, sample: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.73it/s]
# Computing total RNAvelocity ...
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.6998234709076095, ('Neuroblast', 'Granule immature'): -0.4349357311828953, ('Granule immature', 'Granule mature'): 0.18529857134863248, ('Radial Glia-like', 'Astrocytes'): 0.7325645358849666, ('OPC', 'OL'): -0.9555854582050674}
# Total Mean: -0.2344963106123946
# # In-cluster Coherence
# {'Astrocytes': 0.55442184, 'Cajal Retzius': 0.8334152, 'Cck-Tox': 0.6773057, 'Endothelial': 0.5699482, 'GABA': 0.68481445, 'Granule immature': 0.8579153, 'Granule mature': 0.87329036, 'Microglia': 0.67986435, 'Mossy': 0.68991107, 'Neuroblast': 0.7963436, 'OL': 0.5847889, 'OPC': 0.5065341, 'Radial Glia-like': 0.64242584, 'nIPC': 0.44180673}
# Total Mean: 0.6709132194519043
