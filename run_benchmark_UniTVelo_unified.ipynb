# %%
import scvelo as scv
import scanpy as sc
import pickle as pickle
from eval_utils import cross_boundary_correctness, inner_cluster_coh
import pandas as pd
import numpy as np
from os.path import exists
import matplotlib.pyplot as plt
import unitvelo as utv
method = 'UniTVelo_unified'
# Out:
# (Running UniTVelo 0.2.5)
# 2022-12-21 13:18:22

# %%
datasets = ['MouseBoneMarrow',  'HumanBoneMarrow', 'MouseErythroid', 'HumanDevelopingBrain', 'DentateGyrus', 'Pancreas_with_cc']
data_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_datasets/'
save_dir = '/nfs/team283/aa16/data/fate_benchmarking/benchmarking_results/'

# %%
for dataset in datasets:
    print(dataset)
    # Load and setup data:
    adata = sc.read_h5ad(data_dir + dataset + '/' + dataset + '_anndata.h5ad')
    adata.var['highly_variable'] = True
    scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=3000)
    scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
    velo = utv.config.Configuration()
    velo.N_TOP_GENES = 3000
    velo.R2_ADJUST = True
    velo.IROOT = None
    velo.FIT_OPTION = '1'
    velo.GPU = 0
    scv.pp.neighbors(adata)
    adata = utv.run_model(adata, 'clusters', config_file=velo)
    scv.tl.velocity_graph(adata, vkey='velocity')
    scv.tl.velocity_embedding(adata, vkey='velocity')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax, legend_fontsize = 13)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_UniTVelo_unified.png')
    # Calculate performance metrics:
    adata.layers['velocity'][pd.isna(adata.layers['velocity'])] = 0
    file = open(data_dir + dataset + '/' + dataset + '_groundTruth.pickle' ,'rb')
    ground_truth = pickle.load(file)
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_CBDC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_CBDC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(metrics['Cross-Boundary Direction Correctness (A->B)'].keys()) + ['Mean'],
                 index = [method])
    cb_score = [np.mean(metrics['Cross-Boundary Direction Correctness (A->B)'][x])
                for x in metrics['Cross-Boundary Direction Correctness (A->B)'].keys()]
    tab.loc[method,:] = cb_score + [np.mean(cb_score)]
    tab.to_csv(save_dir + dataset + '_CBDC_scores.csv')
    metrics = utv.evaluate(adata, ground_truth, 'clusters', 'velocity')
    if exists(save_dir + dataset + '_ICC_scores.csv'):
        tab = pd.read_csv(save_dir + dataset + '_ICC_scores.csv', index_col = 0)
    else:
        tab = pd.DataFrame(columns = list(np.unique(np.concatenate(ground_truth))) + ['Mean'],
                 index = [method])
    icc_score = [np.mean(metrics['In-cluster Coherence'][x]) for x in np.unique(np.concatenate(ground_truth))]
    tab.loc[method,:] = icc_score + [np.mean(icc_score)]
    tab.to_csv(save_dir + dataset + '_ICC_scores.csv')
    fix, ax = plt.subplots(1, 1, figsize = (8, 6))
    scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity',
                                     show = False, ax = ax)
    plt.savefig(save_dir + 'UMAPs/' + dataset + '_UMAP_' + method + '.png')
# Out:
# MouseBoneMarrow
# Filtered out 20300 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
#     finished (0:00:06) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Filtered out 185 genes that are detected 20 counts (shared).
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize spliced as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize unspliced as it looks processed already. To enforce normalization, set `enforce=True`.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# Extracted 1067 highly variable genes.
# Computing moments for 1067 genes with n_neighbors: 30 and n_pcs: 30
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#
# # of velocity genes 464 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 439 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 439 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 488.135, (Spliced): 205.065, (Unspliced): 283.070: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [05:11<00:00, 32.14it/s]
# Loss (Total): 488.135, (Spliced): 205.065, (Unspliced): 283.070: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [05:20<00:00, 37.39it/s]
# Total loss 464.100, vgene loss 488.135
#   0%|          | 0/2600 [00:00<?, ?cells/s]
#   0%|          | 0/2600 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.8635466616534402, ('progenitors', 'activating'): -0.783345282909811}
# Total Mean: -0.8234459722816256
# # In-cluster Coherence
# {'B cell lineage': 0.9378242, 'activating': 0.96356153, 'dividing': 0.90082085, 'macrophages': 0.9420989, 'progenitors': 0.76997405}
# Total Mean: 0.9028558731079102
# # Cross-Boundary Direction Correctness (A->B)
# {('dividing', 'progenitors'): -0.8635466616534402, ('progenitors', 'activating'): -0.783345282909811}
# Total Mean: -0.8234459722816256
# # In-cluster Coherence
# {'B cell lineage': 0.9378242, 'activating': 0.96356153, 'dividing': 0.90082085, 'macrophages': 0.9420989, 'progenitors': 0.76997405}
# Total Mean: 0.9028558731079102
# HumanBoneMarrow
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 2881 highly variable genes.
# Computing moments for 2881 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 671 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 573 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 572 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 7414.498, (Spliced): 3545.639, (Unspliced): 3868.858: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [29:48<00:00,  4.98it/s]
# Loss (Total): 7414.498, (Spliced): 3545.639, (Unspliced): 3868.858: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [30:38<00:00,  6.53it/s]
# Total loss 7414.498, vgene loss 7414.498
#   0%|          | 0/5780 [00:00<?, ?cells/s]
#   0%|          | 0/5780 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.882813248853817, ('HSC_1', 'HSC_2'): 0.6717953872590254, ('Ery_1', 'Ery_2'): 0.8758547669687282}
# Total Mean: 0.8101544676938568
# # In-cluster Coherence
# {'CLP': 0.99671733, 'DCs': 0.9928915, 'Ery_1': 0.9746536, 'Ery_2': 0.9939953, 'HSC_1': 0.9451415, 'HSC_2': 0.9720577, 'Mega': 0.99063945, 'Mono_1': 0.9675217, 'Mono_2': 0.98115367, 'Precursors': 0.9552781}
# Total Mean: 0.9770050048828125
# # Cross-Boundary Direction Correctness (A->B)
# {('HSC_1', 'Ery_1'): 0.882813248853817, ('HSC_1', 'HSC_2'): 0.6717953872590254, ('Ery_1', 'Ery_2'): 0.8758547669687282}
# Total Mean: 0.8101544676938568
# # In-cluster Coherence
# {'CLP': 0.99671733, 'DCs': 0.9928915, 'Ery_1': 0.9746536, 'Ery_2': 0.9939953, 'HSC_1': 0.9451415, 'HSC_2': 0.9720577, 'Mega': 0.99063945, 'Mono_1': 0.9675217, 'Mono_2': 0.98115367, 'Precursors': 0.9552781}
# Total Mean: 0.9770050048828125
# MouseErythroid
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 2921 highly variable genes.
# Computing moments for 2921 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 575 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 557 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 553 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 6182.873, (Spliced): 1797.559, (Unspliced): 4385.314: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [29:33<00:00,  5.59it/s]
# Loss (Total): 6182.873, (Spliced): 1797.559, (Unspliced): 4385.314: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [30:59<00:00,  6.45it/s]
# Total loss 5992.716, vgene loss 6182.873
#   0%|          | 0/9815 [00:00<?, ?cells/s]
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.9261037386801, ('Blood progenitors 2', 'Erythroid1'): 0.7627917434376565, ('Erythroid1', 'Erythroid2'): 0.8253265341893447, ('Erythroid2', 'Erythroid3'): 0.8299912385363917}
# Total Mean: 0.8360533137108732
# # In-cluster Coherence
# {'Blood progenitors 1': 0.99997294, 'Blood progenitors 2': 0.9978738, 'Erythroid1': 0.82882315, 'Erythroid2': 0.99988985, 'Erythroid3': 0.9999852}
# Total Mean: 0.9653089642524719
# # Cross-Boundary Direction Correctness (A->B)
# {('Blood progenitors 1', 'Blood progenitors 2'): 0.9261037386801, ('Blood progenitors 2', 'Erythroid1'): 0.7627917434376565, ('Erythroid1', 'Erythroid2'): 0.8253265341893447, ('Erythroid2', 'Erythroid3'): 0.8299912385363917}
# Total Mean: 0.8360533137108732
# # In-cluster Coherence
# {'Blood progenitors 1': 0.99997294, 'Blood progenitors 2': 0.9978738, 'Erythroid1': 0.82882315, 'Erythroid2': 0.99988985, 'Erythroid3': 0.9999852}
# Total Mean: 0.9653089642524719
# HumanDevelopingBrain
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 2873 highly variable genes.
# Computing moments for 2873 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 533 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 401 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 401 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 564.451, (Spliced): 340.469, (Unspliced): 223.983:  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████             | 10801/12000 [24:18<02:29,  8.04it/s]
# Loss (Total): 564.451, (Spliced): 340.469, (Unspliced): 223.983:  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████             | 10801/12000 [25:36<02:50,  7.03it/s]
# Total loss 505.375, vgene loss 564.451
#   0%|          | 0/9443 [00:00<?, ?cells/s]
#   0%|          | 0/9443 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Radial Glia', 'Intermediate \n Progenitor'): -0.37651673589908136, ('Intermediate \n Progenitor', 'Newborn \n Excitatory Neuron'): -0.5108405749603696, ('Newborn \n Excitatory Neuron', 'Immature \n Excitatory Neuron'): 0.21688949231256746, ('Immature \n Excitatory Neuron', 'Mature \n Excitatory Neuron'): 0.8116856602823477}
# Total Mean: 0.035304460433866036
# # In-cluster Coherence
# {'Immature \n Excitatory Neuron': 0.9665887, 'Intermediate \n Progenitor': 0.97267264, 'Mature \n Excitatory Neuron': 0.91772616, 'Newborn \n Excitatory Neuron': 0.9927158, 'Radial Glia': 0.87086177}
# Total Mean: 0.9441129565238953
# # Cross-Boundary Direction Correctness (A->B)
# {('Radial Glia', 'Intermediate \n Progenitor'): -0.37651673589908136, ('Intermediate \n Progenitor', 'Newborn \n Excitatory Neuron'): -0.5108405749603696, ('Newborn \n Excitatory Neuron', 'Immature \n Excitatory Neuron'): 0.21688949231256746, ('Immature \n Excitatory Neuron', 'Mature \n Excitatory Neuron'): 0.8116856602823477}
# Total Mean: 0.035304460433866036
# # In-cluster Coherence
# {'Immature \n Excitatory Neuron': 0.9665887, 'Intermediate \n Progenitor': 0.97267264, 'Mature \n Excitatory Neuron': 0.91772616, 'Newborn \n Excitatory Neuron': 0.9927158, 'Radial Glia': 0.87086177}
# Total Mean: 0.9441129565238953
# DentateGyrus
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 2725 highly variable genes.
# Computing moments for 2725 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 1211 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 1140 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 1128 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 1609.654, (Spliced): 804.336, (Unspliced): 805.318: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11998/12000 [10:38<00:00, 16.81it/s]
# Kat2b
# Loss (Total): 1609.654, (Spliced): 804.336, (Unspliced): 805.318: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [11:07<00:00, 17.96it/s]
# Total loss 1595.739, vgene loss 1609.654
#   0%|          | 0/2930 [00:00<?, ?cells/s]
#   0%|          | 0/2930 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.8974511038363696, ('Neuroblast', 'Granule immature'): -0.5622758528961367, ('Granule immature', 'Granule mature'): 0.18384997274094964, ('Radial Glia-like', 'Astrocytes'): 0.8208152845016846, ('OPC', 'OL'): 0.8098255328493484}
# Total Mean: 0.07095276667189528
# # In-cluster Coherence
# {'Astrocytes': 0.99767613, 'Cajal Retzius': 0.9988899, 'Cck-Tox': 0.9872986, 'Endothelial': 0.99662054, 'GABA': 0.9940111, 'Granule immature': 0.9636683, 'Granule mature': 0.9363552, 'Microglia': 0.9977191, 'Mossy': 0.9809599, 'Neuroblast': 0.98412603, 'OL': 0.99740165, 'OPC': 0.9884719, 'Radial Glia-like': 0.9991324, 'nIPC': 0.99887395}
# Total Mean: 0.9872288703918457
# # Cross-Boundary Direction Correctness (A->B)
# {('nIPC', 'Neuroblast'): -0.8974511038363696, ('Neuroblast', 'Granule immature'): -0.5622758528961367, ('Granule immature', 'Granule mature'): 0.18384997274094964, ('Radial Glia-like', 'Astrocytes'): 0.8208152845016846, ('OPC', 'OL'): 0.8098255328493484}
# Total Mean: 0.07095276667189528
# # In-cluster Coherence
# {'Astrocytes': 0.99767613, 'Cajal Retzius': 0.9988899, 'Cck-Tox': 0.9872986, 'Endothelial': 0.99662054, 'GABA': 0.9940111, 'Granule immature': 0.9636683, 'Granule mature': 0.9363552, 'Microglia': 0.9977191, 'Mossy': 0.9809599, 'Neuroblast': 0.98412603, 'OL': 0.99740165, 'OPC': 0.9884719, 'Radial Glia-like': 0.9991324, 'nIPC': 0.99887395}
# Total Mean: 0.9872288703918457
# Pancreas_with_cc
# ------> Manully Specified Parameters <------
# N_TOP_GENES:	3000
# ------> Model Configuration Settings <------
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /nfs/team283/aa16/fate_benchmarking.
# Results will be stored in res folder
# Extracted 2909 highly variable genes.
# Computing moments for 2909 genes with n_neighbors: 30 and n_pcs: 30
#
# # of velocity genes 1497 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 1311 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 1311 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 3011.289, (Spliced): 1477.038, (Unspliced): 1534.251: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11998/12000 [11:39<00:00, 14.41it/s]
# Loss (Total): 3011.289, (Spliced): 1477.038, (Unspliced): 1534.251: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 11999/12000 [12:16<00:00, 16.29it/s]
# Total loss 2973.603, vgene loss 3011.289
#   0%|          | 0/3696 [00:00<?, ?cells/s]
#   0%|          | 0/3696 [00:00<?, ?cells/s]
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.738413507003304, ('Pre-endocrine', 'Alpha'): 0.7688626049532291, ('Pre-endocrine', 'Beta'): 0.828286198748149, ('Pre-endocrine', 'Delta'): 0.4264468070530355, ('Pre-endocrine', 'Epsilon'): -0.014511983060739907}
# Total Mean: 0.5494994269393955
# # In-cluster Coherence
# {'Alpha': 0.9962782, 'Beta': 0.998199, 'Delta': 0.9951236, 'Ductal': 0.99908864, 'Epsilon': 0.99634135, 'Ngn3 high EP': 0.95878947, 'Ngn3 low EP': 0.99797094, 'Pre-endocrine': 0.99480873}
# Total Mean: 0.9920749664306641
# # Cross-Boundary Direction Correctness (A->B)
# {('Ngn3 high EP', 'Pre-endocrine'): 0.738413507003304, ('Pre-endocrine', 'Alpha'): 0.7688626049532291, ('Pre-endocrine', 'Beta'): 0.828286198748149, ('Pre-endocrine', 'Delta'): 0.4264468070530355, ('Pre-endocrine', 'Epsilon'): -0.014511983060739907}
# Total Mean: 0.5494994269393955
# # In-cluster Coherence
# {'Alpha': 0.9962782, 'Beta': 0.998199, 'Delta': 0.9951236, 'Ductal': 0.99908864, 'Epsilon': 0.99634135, 'Ngn3 high EP': 0.95878947, 'Ngn3 low EP': 0.99797094, 'Pre-endocrine': 0.99480873}
# Total Mean: 0.9920749664306641
